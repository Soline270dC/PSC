# %%
from time_series_gan.GAN import GAN
import numpy as np
import pandas as pd
from time_series_gan.metrics import dWasserstein, dFrechet, ONND, score
from Optimisation_MH import generer_resultats, Metropolis_Hasting

# %%
data = pd.read_csv("data/data_genhack.csv")
archi = Metropolis_Hasting(0.1, data, GAN, ite = 1000, metrique=score, nom_de_la_métrique = "score")
# Out:
# fit took 22.264278 seconds
# MH étape : 0
# suppression d'une couche du discriminator
# fit took 17.480480 seconds
# succes
# 136.20221567415427 ->  133.00645863778294
#
# {'lr_g': 0.001, 'lr_d': 0.001, 'epochs': 100, 'batch_size': 32, 'latent_dim': 20}
# generator : [4]        ReLU
# discriminator : [25, 1]        ReLU
#
#
# MH étape : 1
# ajout d'une couche au discriminator
# fit took 15.036504 seconds
# echec
#
#
# MH étape : 2
# modification des paramètres
# fit took 9.871195 seconds
# echec
#
#
# MH étape : 3
# suppression d'une couche du discriminator
# fit took 12.946068 seconds
# echec
#
#
# MH étape : 4
# modification des paramètres
# fit took 25.958337 seconds
# echec
#
#
# MH étape : 5
# suppression d'une couche du discriminator
# fit took 16.107913 seconds
# succes
# 133.00645863778294 ->  123.63593226550185
#
# {'lr_g': 0.001, 'lr_d': 0.001, 'epochs': 100, 'batch_size': 32, 'latent_dim': 20}
# generator : [4]        ReLU
# discriminator : [1]        ReLU
#
#
# MH étape : 6
# modification des paramètres
# fit took 11.343784 seconds
# succes
# 123.63593226550185 ->  114.87275640873568
#
# {'lr_g': 0.002001, 'lr_d': 0.001642, 'epochs': 83, 'batch_size': 52, 'latent_dim': 8}
# generator : [4]        ReLU
# discriminator : [1]        ReLU
#
#
# MH étape : 7
# ajout d'une couche au generator
# fit took 12.388319 seconds
# succes
# 114.87275640873568 ->  45.579421388660236
#
# {'lr_g': 0.002001, 'lr_d': 0.001642, 'epochs': 83, 'batch_size': 52, 'latent_dim': 8}
# generator : [74, 4]        ReLU
# discriminator : [1]        ReLU
#
#
# MH étape : 8
# ajout d'une couche au discriminator
# fit took 21.147341 seconds
# succes
# 45.579421388660236 ->  28.11666155012241
#
# {'lr_g': 0.002001, 'lr_d': 0.001642, 'epochs': 83, 'batch_size': 52, 'latent_dim': 8}
# generator : [74, 4]        ReLU
# discriminator : [73, 1]        ReLU
#
#
# MH étape : 9
# modification des paramètres
# fit took 15.878069 seconds
# succes
# 28.11666155012241 ->  22.125793204388568
#
# {'lr_g': 0.002827, 'lr_d': 0.001998, 'epochs': 34, 'batch_size': 52, 'latent_dim': 5}
# generator : [74, 4]        ReLU
# discriminator : [73, 1]        ReLU
#
#
# MH étape : 10
# ajout d'une couche au discriminator
# fit took 17.311660 seconds
# succes
# 22.125793204388568 ->  13.711778593078108
#
# {'lr_g': 0.002827, 'lr_d': 0.001998, 'epochs': 34, 'batch_size': 52, 'latent_dim': 5}
# generator : [74, 4]        ReLU
# discriminator : [66, 73, 1]        ReLU
#
#
# MH étape : 11
# modification des paramètres
# fit took 21.279923 seconds
# echec
#
#
# MH étape : 12
# ajout d'une couche au generator
# fit took 11.321363 seconds
# echec
#
#
# MH étape : 13
# suppression d'une couche du generator
# fit took 19.651975 seconds
# echec
#
#
# MH étape : 14
# modification des paramètres
# fit took 21.230289 seconds
# echec
#
#
# MH étape : 15
# ajout d'une couche au discriminator
# fit took 21.511015 seconds
# echec
#
#
# MH étape : 16
# modification des paramètres
# fit took 18.131239 seconds
# echec
#
#
# MH étape : 17
# ajout d'une couche au generator
# fit took 21.448180 seconds
# echec
#
#
# MH étape : 18
# modification des paramètres
# fit took 17.903329 seconds
# echec
#
#
# MH étape : 19
# modification de la fonction d'activation du generator
# fit took 20.148581 seconds
# echec
#
#
# MH étape : 20
# ajout d'une couche au generator
# fit took 20.918047 seconds
# echec
#
#
# MH étape : 21
# modification des paramètres
# fit took 20.623483 seconds
# echec
#
#
# MH étape : 22
# modification des paramètres
# fit took 19.911793 seconds
# echec
#
#
# MH étape : 23
# modification des paramètres
# fit took 18.742304 seconds
# echec
#
#
# MH étape : 24
# ajout d'une couche au generator
# fit took 20.524300 seconds
# echec
#
#
# MH étape : 25
# suppression d'une couche du generator
# fit took 19.682798 seconds
# echec
#
#
# MH étape : 26
# modification des paramètres
# fit took 19.161047 seconds
# echec
#
#
# MH étape : 27
# ajout d'une couche au generator
# fit took 19.062661 seconds
# echec
#
#
# MH étape : 28
# modification des paramètres
# fit took 15.970037 seconds
# echec
#
#
# MH étape : 29
# suppression d'une couche du discriminator
# fit took 16.122125 seconds
# echec
#
#
# MH étape : 30
# modification des paramètres
# fit took 18.472863 seconds
# echec
#
#
# MH étape : 31
# ajout d'une couche au generator
# fit took 20.353759 seconds
# echec
#
#
# MH étape : 32
# modification des paramètres
# fit took 25.497481 seconds
# echec
#
#
# MH étape : 33
# ajout d'une couche au discriminator
# fit took 20.108718 seconds
# echec
#
#
# MH étape : 34
# modification de la fonction d'activation du discriminator
# fit took 21.297594 seconds
# echec
#
#
# MH étape : 35
# ajout d'une couche au discriminator
# fit took 22.698105 seconds
# echec
#
#
# MH étape : 36
# modification des paramètres
# fit took 18.924095 seconds
# echec
#
#
# MH étape : 37
# modification des paramètres
# fit took 18.491559 seconds
# echec
#
#
# MH étape : 38
# modification des paramètres
# fit took 23.119431 seconds
# echec
#
#
# MH étape : 39
# ajout d'une couche au discriminator
# fit took 21.744574 seconds
# echec
#
#
# MH étape : 40
# suppression d'une couche du discriminator
# fit took 18.515259 seconds
# echec
#
#
# MH étape : 41
# suppression d'une couche du generator
# fit took 20.072809 seconds
# echec
#
#
# MH étape : 42
# modification de la fonction d'activation du discriminator
# fit took 20.273621 seconds
# echec
#
#
# MH étape : 43
# suppression d'une couche du discriminator
# fit took 19.649728 seconds
# echec
#
#
# MH étape : 44
# ajout d'une couche au discriminator
# fit took 21.275730 seconds
# echec
#
#
# MH étape : 45
# suppression d'une couche du generator
# fit took 19.752416 seconds
# echec
#
#
# MH étape : 46
# modification des paramètres
# fit took 22.771013 seconds
# echec
#
#
# MH étape : 47
# ajout d'une couche au generator
# fit took 20.465113 seconds
# echec
#
#
# MH étape : 48
# ajout d'une couche au generator
# fit took 21.043507 seconds
# echec
#
#
# MH étape : 49
# modification des paramètres
# fit took 29.791684 seconds
# echec
#
#
# MH étape : 50
# ajout d'une couche au generator
# fit took 21.258635 seconds
# echec
#
#
# MH étape : 51
# suppression d'une couche du discriminator
# fit took 18.398001 seconds
# echec
#
#
# MH étape : 52
# suppression d'une couche du discriminator
# fit took 21.927930 seconds
# echec
#
#
# MH étape : 53
# modification des paramètres
# fit took 25.468865 seconds
# succes
# 13.711778593078108 ->  12.689941905857584
#
# {'lr_g': 0.001128, 'lr_d': 0.001511, 'epochs': 69, 'batch_size': 37, 'latent_dim': 9}
# generator : [74, 4]        ReLU
# discriminator : [66, 73, 1]        ReLU
#
#
# MH étape : 54
# ajout d'une couche au generator
# fit took 25.527022 seconds
# echec
#
#
# MH étape : 55
# ajout d'une couche au discriminator
# fit took 27.558219 seconds
# succes
# 12.689941905857584 ->  9.045117742922553
#
# {'lr_g': 0.001128, 'lr_d': 0.001511, 'epochs': 69, 'batch_size': 37, 'latent_dim': 9}
# generator : [74, 4]        ReLU
# discriminator : [72, 66, 73, 1]        ReLU
#
#
# MH étape : 56
# suppression d'une couche du generator
# fit took 26.402551 seconds
# echec
#
#
# MH étape : 57
# ajout d'une couche au generator
# fit took 29.257953 seconds
# echec
#
#
# MH étape : 58
# modification des paramètres
# fit took 31.361705 seconds
# echec
#
#
# MH étape : 59
# modification des paramètres
# fit took 23.992965 seconds
# echec
#
#
# MH étape : 60
# modification des paramètres
# fit took 27.269109 seconds
# echec
#
#
# MH étape : 61
# suppression d'une couche du discriminator
# fit took 25.564949 seconds
# echec
#
#
# MH étape : 62
# modification des paramètres
# fit took 50.855900 seconds
# echec
#
#
# MH étape : 63
# modification des paramètres
# fit took 23.887785 seconds
# echec
#
#
# MH étape : 64
# modification des paramètres
# fit took 38.437626 seconds
# echec
#
#
# MH étape : 65
# modification des paramètres
# fit took 18.921486 seconds
# echec
#
#
# MH étape : 66
# modification des paramètres
# fit took 32.867142 seconds
# echec
#
#
# MH étape : 67
# ajout d'une couche au discriminator
# fit took 29.707896 seconds
# echec
#
#
# MH étape : 68
# suppression d'une couche du generator
# fit took 26.342665 seconds
# echec
#
#
# MH étape : 69
# ajout d'une couche au discriminator
# fit took 30.824439 seconds
# echec
#
#
# MH étape : 70
# modification des paramètres
# fit took 21.516460 seconds
# echec
#
#
# MH étape : 71
# ajout d'une couche au discriminator
# fit took 28.896943 seconds
# echec
#
#
# MH étape : 72
# modification des paramètres
# fit took 22.109501 seconds
# echec
#
#
# MH étape : 73
# modification des paramètres
# fit took 26.039010 seconds
# echec
#
#
# MH étape : 74
# modification des paramètres
# fit took 12.350018 seconds
# echec
#
#
# MH étape : 75
# modification des paramètres
# fit took 12.150290 seconds
# echec
#
#
# MH étape : 76
# ajout d'une couche au generator
# fit took 15.693752 seconds
# echec
#
#
# MH étape : 77
# ajout d'une couche au discriminator
# fit took 15.566990 seconds
# echec
#
#
# MH étape : 78
# suppression d'une couche du discriminator
# fit took 14.054492 seconds
# echec
#
#
# MH étape : 79
# modification des paramètres
# fit took 12.791772 seconds
# echec
#
#
# MH étape : 80
# modification des paramètres
# fit took 34.658933 seconds
# echec
#
#
# MH étape : 81
# ajout d'une couche au generator
# fit took 24.354324 seconds
# echec
#
#
# MH étape : 82
# suppression d'une couche du generator
# fit took 23.042525 seconds
# echec
#
#
# MH étape : 83
# ajout d'une couche au discriminator
# fit took 25.502275 seconds
# echec
#
#
# MH étape : 84
# modification des paramètres
# fit took 15.878201 seconds
# echec
#
#
# MH étape : 85
# modification des paramètres
# fit took 17.978795 seconds
# succes
# 9.045117742922553 ->  9.055769826613847
#
# {'lr_g': 0.001328, 'lr_d': 0.002557, 'epochs': 38, 'batch_size': 65, 'latent_dim': 10}
# generator : [74, 4]        ReLU
# discriminator : [72, 66, 73, 1]        ReLU
#
#
# MH étape : 86
# modification des paramètres
# fit took 14.281430 seconds
# echec
#
#
# MH étape : 87
# modification des paramètres
# fit took 17.725749 seconds
# echec
#
#
# MH étape : 88
# suppression d'une couche du discriminator
# fit took 13.734675 seconds
# echec
#
#
# MH étape : 89
# modification des paramètres
# fit took 21.758938 seconds
# succes
# 9.055769826613847 ->  8.370909722017661
#
# {'lr_g': 0.0005642, 'lr_d': 0.003666, 'epochs': 90, 'batch_size': 103, 'latent_dim': 15}
# generator : [74, 4]        ReLU
# discriminator : [72, 66, 73, 1]        ReLU
#
#
# MH étape : 90
# modification des paramètres
# fit took 19.140814 seconds
# echec
#
#
# MH étape : 91
# modification des paramètres
# fit took 17.285866 seconds
# echec
#
#
# MH étape : 92
# modification des paramètres
# fit took 22.063524 seconds
# echec
#
#
# MH étape : 93
# modification des paramètres
# fit took 28.311817 seconds
# echec
#
#
# MH étape : 94
# modification des paramètres
# fit took 20.398726 seconds
# echec
#
#
# MH étape : 95
# suppression d'une couche du generator
# fit took 26.608324 seconds
# echec
#
#
# MH étape : 96
# modification des paramètres
# fit took 36.055529 seconds
# echec
#
#
# MH étape : 97
# suppression d'une couche du generator
# fit took 25.823450 seconds
# echec
#
#
# MH étape : 98
# suppression d'une couche du generator
# fit took 28.006147 seconds
# echec
#
#
# MH étape : 99
# ajout d'une couche au discriminator
# fit took 25.376775 seconds
# echec
#
#
# MH étape : 100
# modification des paramètres
# fit took 23.148899 seconds
# echec
#
#
# MH étape : 101
# modification des paramètres
# fit took 12.747659 seconds
# echec
#
#
# MH étape : 102
# modification des paramètres
# fit took 13.482970 seconds
# echec
#
#
# MH étape : 103
# ajout d'une couche au generator
# fit took 18.069360 seconds
# echec
#
#
# MH étape : 104
# suppression d'une couche du discriminator
# fit took 15.470515 seconds
# echec
#
#
# MH étape : 105
# suppression d'une couche du generator
# fit took 15.204332 seconds
# echec
#
#
# MH étape : 106
# modification des paramètres
# fit took 19.564904 seconds
# echec
#
#
# MH étape : 107
# modification des paramètres
# fit took 21.812833 seconds
# echec
#
#
# MH étape : 108
# suppression d'une couche du generator
# fit took 15.218493 seconds
# echec
#
#
# MH étape : 109
# modification de la fonction d'activation du generator
# fit took 16.241826 seconds
# echec
#
#
# MH étape : 110
# suppression d'une couche du generator
# fit took 15.498313 seconds
# echec
#
#
# MH étape : 111
# ajout d'une couche au discriminator
# fit took 17.907002 seconds
# echec
#
#
# MH étape : 112
# modification des paramètres
# fit took 21.629422 seconds
# echec
#
#
# MH étape : 113
# modification des paramètres
# fit took 10.962377 seconds
# echec
#
#
# MH étape : 114
# modification des paramètres
# fit took 16.336204 seconds
# echec
#
#
# MH étape : 115
# modification des paramètres
# fit took 14.164742 seconds
# echec
#
#
# MH étape : 116
# ajout d'une couche au discriminator
# fit took 17.396949 seconds
# echec
#
#
# MH étape : 117
# ajout d'une couche au generator
# fit took 16.984113 seconds
# echec
#
#
# MH étape : 118
# suppression d'une couche du discriminator
# fit took 14.869343 seconds
# succes
# 8.370909722017661 ->  8.26505130194445
#
# {'lr_g': 0.0005642, 'lr_d': 0.003666, 'epochs': 90, 'batch_size': 103, 'latent_dim': 15}
# generator : [74, 4]        ReLU
# discriminator : [72, 66, 1]        ReLU
#
#
# MH étape : 119
# modification des paramètres
# fit took 13.015131 seconds
# echec
#
#
# MH étape : 120
# ajout d'une couche au discriminator
# fit took 15.485978 seconds
# echec
#
#
# MH étape : 121
# ajout d'une couche au discriminator
# fit took 14.421851 seconds
# succes
# 8.26505130194445 ->  7.89011925799765
#
# {'lr_g': 0.0005642, 'lr_d': 0.003666, 'epochs': 90, 'batch_size': 103, 'latent_dim': 15}
# generator : [74, 4]        ReLU
# discriminator : [72, 14, 66, 1]        ReLU
#
#
# MH étape : 122
# ajout d'une couche au generator
# fit took 15.760216 seconds
# echec
#
#
# MH étape : 123
# modification des paramètres
# fit took 10.285807 seconds
# echec
#
#
# MH étape : 124
# suppression d'une couche du generator
# fit took 13.617043 seconds
# echec
#
#
# MH étape : 125
# suppression d'une couche du generator
# fit took 15.907056 seconds
# echec
#
#
# MH étape : 126
# suppression d'une couche du generator
# fit took 14.990103 seconds
# echec
#
#
# MH étape : 127
# suppression d'une couche du discriminator
# fit took 13.994451 seconds
# echec
#
#
# MH étape : 128
# modification des paramètres
# fit took 11.044050 seconds
# echec
#
#
# MH étape : 129
# suppression d'une couche du discriminator
# fit took 13.459190 seconds
# echec
#
#
# MH étape : 130
# suppression d'une couche du generator
# fit took 13.725115 seconds
# echec
#
#
# MH étape : 131
# ajout d'une couche au discriminator
# fit took 16.751007 seconds
# echec
#
#
# MH étape : 132
# modification des paramètres
# fit took 11.974133 seconds
# echec
#
#
# MH étape : 133
# modification des paramètres
# fit took 19.517292 seconds
# echec
#
#
# MH étape : 134
# suppression d'une couche du generator
# fit took 13.593761 seconds
# echec
#
#
# MH étape : 135
# modification des paramètres
# fit took 12.321809 seconds
# echec
#
#
# MH étape : 136
# ajout d'une couche au discriminator
# fit took 16.413801 seconds
# echec
#
#
# MH étape : 137
# ajout d'une couche au discriminator
# fit took 15.977659 seconds
# echec
#
#
# MH étape : 138
# ajout d'une couche au generator
# fit took 14.889775 seconds
# echec
#
#
# MH étape : 139
# modification des paramètres
# fit took 10.553078 seconds
# echec
#
#
# MH étape : 140
# ajout d'une couche au discriminator
# fit took 15.282848 seconds
# echec
#
#
# MH étape : 141
# modification des paramètres
# fit took 19.973703 seconds
# echec
#
#
# MH étape : 142
# ajout d'une couche au discriminator
# fit took 15.078249 seconds
# echec
#
#
# MH étape : 143
# ajout d'une couche au generator
# fit took 15.715950 seconds
# echec
#
#
# MH étape : 144
# modification des paramètres
# fit took 13.555689 seconds
# echec
#
#
# MH étape : 145
# suppression d'une couche du discriminator
# fit took 13.633442 seconds
# echec
#
#
# MH étape : 146
# ajout d'une couche au discriminator
# fit took 15.106531 seconds
# echec
#
#
# MH étape : 147
# modification de la fonction d'activation du generator
# fit took 14.287769 seconds
# echec
#
#
# MH étape : 148
# suppression d'une couche du discriminator
# fit took 14.267398 seconds
# echec
#
#
# MH étape : 149
# suppression d'une couche du generator
# fit took 14.392080 seconds
# echec
#
#
# MH étape : 150
# suppression d'une couche du discriminator
# fit took 15.629699 seconds
# echec
#
#
# MH étape : 151
# ajout d'une couche au discriminator
# fit took 23.523752 seconds
# echec
#
#
# MH étape : 152
# modification des paramètres
# fit took 19.169072 seconds
# echec
#
#
# MH étape : 153
# modification des paramètres
# fit took 14.236684 seconds
# echec
#
#
# MH étape : 154
# modification des paramètres
# fit took 18.682520 seconds
# echec
#
#
# MH étape : 155
# ajout d'une couche au generator
# fit took 15.084226 seconds
# echec
#
#
# MH étape : 156
# ajout d'une couche au generator
# fit took 15.885136 seconds
# echec
#
#
# MH étape : 157
# modification des paramètres
# fit took 14.905807 seconds
# echec
#
#
# MH étape : 158
# suppression d'une couche du generator
# fit took 13.627128 seconds
# echec
#
#
# MH étape : 159
# ajout d'une couche au generator
# fit took 16.706194 seconds
# echec
#
#
# MH étape : 160
# modification des paramètres
# fit took 16.051226 seconds
# echec
#
#
# MH étape : 161
# modification des paramètres
# fit took 12.208710 seconds
# echec
#
#
# MH étape : 162
# ajout d'une couche au discriminator
# fit took 16.996486 seconds
# echec
#
#
# MH étape : 163
# ajout d'une couche au generator
# fit took 15.403486 seconds
# echec
#
#
# MH étape : 164
# suppression d'une couche du generator
# fit took 14.415830 seconds
# echec
#
#
# MH étape : 165
# modification de la fonction d'activation du discriminator
# fit took 13.954836 seconds
# echec
#
#
# MH étape : 166
# modification des paramètres
# fit took 13.856645 seconds
# echec
#
#
# MH étape : 167
# modification des paramètres
# fit took 17.838300 seconds
# echec
#
#
# MH étape : 168
# modification de la fonction d'activation du discriminator
# fit took 14.342543 seconds
# echec
#
#
# MH étape : 169
# ajout d'une couche au discriminator
# fit took 15.990035 seconds
# echec
#
#
# MH étape : 170
# modification des paramètres
# fit took 20.769180 seconds
# echec
#
#
# MH étape : 171
# suppression d'une couche du discriminator
# fit took 13.179194 seconds
# echec
#
#
# MH étape : 172
# modification des paramètres
# fit took 10.577269 seconds
# echec
#
#
# MH étape : 173
# modification des paramètres
# fit took 13.337896 seconds
# echec
#
#
# MH étape : 174
# ajout d'une couche au discriminator
# fit took 15.851622 seconds
# echec
#
#
# MH étape : 175
# modification des paramètres
# fit took 16.038260 seconds
# echec
#
#
# MH étape : 176
# suppression d'une couche du generator
# fit took 13.238890 seconds
# echec
#
#
# MH étape : 177
# suppression d'une couche du generator
# fit took 13.687164 seconds
# echec
#
#
# MH étape : 178
# modification des paramètres
# fit took 11.787422 seconds
# echec
#
#
# MH étape : 179
# modification des paramètres
# fit took 13.487098 seconds
# echec
#
#
# MH étape : 180
# modification des paramètres
# fit took 18.521793 seconds
# echec
#
#
# MH étape : 181
# modification des paramètres
# fit took 10.929387 seconds
# echec
#
#
# MH étape : 182
# modification des paramètres
# fit took 15.004263 seconds
# echec
#
#
# MH étape : 183
# suppression d'une couche du discriminator
# fit took 13.127661 seconds
# echec
#
#
# MH étape : 184
# ajout d'une couche au generator
# fit took 16.250701 seconds
# echec
#
#
# MH étape : 185
# suppression d'une couche du discriminator
# fit took 14.017550 seconds
# echec
#
#
# MH étape : 186
# modification des paramètres
# fit took 14.701459 seconds
# echec
#
#
# MH étape : 187
# modification des paramètres
# fit took 19.607495 seconds
# echec
#
#
# MH étape : 188
# suppression d'une couche du generator
# fit took 13.608165 seconds
# echec
#
#
# MH étape : 189
# suppression d'une couche du discriminator
# fit took 13.068919 seconds
# echec
#
#
# MH étape : 190
# ajout d'une couche au generator
# fit took 14.735185 seconds
# echec
#
#
# MH étape : 191
# modification des paramètres
# fit took 18.594308 seconds
# echec
#
#
# MH étape : 192
# ajout d'une couche au generator
# fit took 15.752602 seconds
# echec
#
#
# MH étape : 193
# modification des paramètres
# fit took 10.635861 seconds
# echec
#
#
# MH étape : 194
# modification des paramètres
# fit took 12.438346 seconds
# echec
#
#
# MH étape : 195
# modification des paramètres
# fit took 14.008876 seconds
# echec
#
#
# MH étape : 196
# suppression d'une couche du generator
# fit took 15.234715 seconds
# echec
#
#
# MH étape : 197
# modification des paramètres
# fit took 12.712559 seconds
# echec
#
#
# MH étape : 198
# ajout d'une couche au generator
# fit took 20.509521 seconds
# echec
#
#
# MH étape : 199
# ajout d'une couche au discriminator
# fit took 17.816794 seconds
# echec
#
#
# MH étape : 200
# modification des paramètres
# fit took 13.837369 seconds
# echec
#
#
# MH étape : 201
# modification des paramètres
# fit took 17.469418 seconds
# echec
#
#
# MH étape : 202
# modification des paramètres
# fit took 15.135998 seconds
# echec
#
#
# MH étape : 203
# ajout d'une couche au generator
# fit took 16.973428 seconds
# echec
#
#
# MH étape : 204
# modification des paramètres
# fit took 13.117333 seconds
# echec
#
#
# MH étape : 205
# ajout d'une couche au discriminator
# fit took 16.854591 seconds
# echec
#
#
# MH étape : 206
# suppression d'une couche du discriminator
# fit took 13.620587 seconds
# echec
#
#
# MH étape : 207
# modification des paramètres
# fit took 15.642864 seconds
# echec
#
#
# MH étape : 208
# suppression d'une couche du generator
# fit took 14.291870 seconds
# echec
#
#
# MH étape : 209
# modification des paramètres
# fit took 12.369128 seconds
# echec
#
#
# MH étape : 210
# modification des paramètres
# fit took 19.365901 seconds
# echec
#
#
# MH étape : 211
# suppression d'une couche du generator
# fit took 13.626868 seconds
# echec
#
#
# MH étape : 212
# modification des paramètres
# fit took 15.425765 seconds
# echec
#
#
# MH étape : 213
# ajout d'une couche au discriminator
# fit took 15.251200 seconds
# echec
#
#
# MH étape : 214
# modification des paramètres
# fit took 14.453048 seconds
# echec
#
#
# MH étape : 215
# modification des paramètres
# fit took 19.088295 seconds
# echec
#
#
# MH étape : 216
# suppression d'une couche du discriminator
# fit took 15.397484 seconds
# echec
#
#
# MH étape : 217
# suppression d'une couche du generator
# fit took 13.699721 seconds
# echec
#
#
# MH étape : 218
# ajout d'une couche au generator
# fit took 15.377544 seconds
# echec
#
#
# MH étape : 219
# ajout d'une couche au generator
# fit took 14.873914 seconds
# echec
#
#
# MH étape : 220
# modification des paramètres
# fit took 15.102797 seconds
# echec
#
#
# MH étape : 221
# suppression d'une couche du generator
# fit took 13.804047 seconds
# echec
#
#
# MH étape : 222
# modification des paramètres
# fit took 11.829572 seconds
# echec
#
#
# MH étape : 223
# modification des paramètres
# fit took 18.738903 seconds
# echec
#
#
# MH étape : 224
# ajout d'une couche au discriminator
# fit took 17.313110 seconds
# echec
#
#
# MH étape : 225
# suppression d'une couche du generator
# fit took 13.816430 seconds
# echec
#
#
# MH étape : 226
# suppression d'une couche du discriminator
# fit took 14.523479 seconds
# echec
#
#
# MH étape : 227
# ajout d'une couche au discriminator
# fit took 17.303090 seconds
# echec
#
#
# MH étape : 228
# suppression d'une couche du generator
# fit took 13.823542 seconds
# echec
#
#
# MH étape : 229
# suppression d'une couche du generator
# fit took 14.253816 seconds
# echec
#
#
# MH étape : 230
# modification des paramètres
# fit took 10.133840 seconds
# echec
#
#
# MH étape : 231
# suppression d'une couche du generator
# fit took 14.022674 seconds
# echec
#
#
# MH étape : 232
# modification des paramètres
# fit took 18.132391 seconds
# echec
#
#
# MH étape : 233
# suppression d'une couche du generator
# fit took 13.845078 seconds
# echec
#
#
# MH étape : 234
# suppression d'une couche du discriminator
# fit took 14.741366 seconds
# echec
#
#
# MH étape : 235
# ajout d'une couche au discriminator
# fit took 16.537791 seconds
# echec
#
#
# MH étape : 236
# suppression d'une couche du discriminator
# fit took 13.679338 seconds
# echec
#
#
# MH étape : 237
# modification des paramètres
# fit took 17.753511 seconds
# echec
#
#
# MH étape : 238
# modification des paramètres
# fit took 12.295490 seconds
# echec
#
#
# MH étape : 239
# modification des paramètres
# fit took 12.015414 seconds
# echec
#
#
# MH étape : 240
# ajout d'une couche au discriminator
# fit took 16.963810 seconds
# echec
#
#
# MH étape : 241
# ajout d'une couche au discriminator
# fit took 16.029522 seconds
# echec
#
#
# MH étape : 242
# modification des paramètres
# fit took 19.524191 seconds
# echec
#
#
# MH étape : 243
# suppression d'une couche du discriminator
# fit took 13.543833 seconds
# echec
#
#
# MH étape : 244
# modification des paramètres
# fit took 17.957832 seconds
# echec
#
#
# MH étape : 245
# suppression d'une couche du discriminator
# fit took 14.459455 seconds
# echec
#
#
# MH étape : 246
# modification des paramètres
# fit took 21.009059 seconds
# echec
#
#
# MH étape : 247
# modification des paramètres
# fit took 11.770163 seconds
# echec
#
#
# MH étape : 248
# modification des paramètres
# fit took 10.429733 seconds
# echec
#
#
# MH étape : 249
# suppression d'une couche du discriminator
# fit took 14.565904 seconds
# echec
#
#
# MH étape : 250
# modification des paramètres
# fit took 13.410690 seconds
# echec
#
#
# MH étape : 251
# modification des paramètres
# fit took 16.799068 seconds
# echec
#
#
# MH étape : 252
# ajout d'une couche au generator
# fit took 16.317184 seconds
# echec
#
#
# MH étape : 253
# ajout d'une couche au generator
# fit took 16.448098 seconds
# echec
#
#
# MH étape : 254
# ajout d'une couche au generator
# fit took 15.968284 seconds
# echec
#
#
# MH étape : 255
# modification des paramètres
# fit took 18.182333 seconds
# echec
#
#
# MH étape : 256
# modification des paramètres
# fit took 11.526197 seconds
# echec
#
#
# MH étape : 257
# modification des paramètres
# fit took 15.123827 seconds
# echec
#
#
# MH étape : 258
# suppression d'une couche du discriminator
# fit took 13.550523 seconds
# echec
#
#
# MH étape : 259
# modification des paramètres
# fit took 19.323853 seconds
# echec
#
#
# MH étape : 260
# modification des paramètres
# fit took 10.470176 seconds
# echec
#
#
# MH étape : 261
# modification des paramètres
# fit took 10.145220 seconds
# echec
#
#
# MH étape : 262
# ajout d'une couche au generator
# fit took 15.100400 seconds
# echec
#
#
# MH étape : 263
# modification des paramètres
# fit took 15.991382 seconds
# echec
#
#
# MH étape : 264
# modification des paramètres
# fit took 17.174408 seconds
# echec
#
#
# MH étape : 265
# suppression d'une couche du generator
# fit took 13.665507 seconds
# echec
#
#
# MH étape : 266
# modification des paramètres
# fit took 11.289902 seconds
# echec
#
#
# MH étape : 267
# modification de la fonction d'activation du discriminator
# fit took 14.361638 seconds
# echec
#
#
# MH étape : 268
# modification des paramètres
# fit took 16.064387 seconds
# echec
#
#
# MH étape : 269
# suppression d'une couche du discriminator
# fit took 14.445002 seconds
# echec
#
#
# MH étape : 270
# ajout d'une couche au generator
# fit took 16.211197 seconds
# echec
#
#
# MH étape : 271
# ajout d'une couche au discriminator
# fit took 16.553030 seconds
# echec
#
#
# MH étape : 272
# modification de la fonction d'activation du generator
# fit took 14.644685 seconds
# echec
#
#
# MH étape : 273
# modification des paramètres
# fit took 12.557854 seconds
# echec
#
#
# MH étape : 274
# modification des paramètres
# fit took 10.169073 seconds
# echec
#
#
# MH étape : 275
# ajout d'une couche au discriminator
# fit took 17.234137 seconds
# echec
#
#
# MH étape : 276
# modification des paramètres
# fit took 16.783010 seconds
# echec
#
#
# MH étape : 277
# suppression d'une couche du discriminator
# fit took 14.070254 seconds
# echec
#
#
# MH étape : 278
# modification des paramètres
# fit took 10.748029 seconds
# echec
#
#
# MH étape : 279
# modification des paramètres
# fit took 11.154998 seconds
# echec
#
#
# MH étape : 280
# modification des paramètres
# fit took 19.073489 seconds
# echec
#
#
# MH étape : 281
# ajout d'une couche au generator
# fit took 16.091871 seconds
# echec
#
#
# MH étape : 282
# modification des paramètres
# fit took 13.829254 seconds
# echec
#
#
# MH étape : 283
# ajout d'une couche au discriminator
# fit took 15.172989 seconds
# echec
#
#
# MH étape : 284
# suppression d'une couche du discriminator
# fit took 15.938395 seconds
# echec
#
#
# MH étape : 285
# modification des paramètres
# fit took 15.741795 seconds
# echec
#
#
# MH étape : 286
# ajout d'une couche au generator
# fit took 16.722582 seconds
# echec
#
#
# MH étape : 287
# ajout d'une couche au generator
# fit took 14.830321 seconds
# echec
#
#
# MH étape : 288
# modification des paramètres
# fit took 10.775847 seconds
# echec
#
#
# MH étape : 289
# modification des paramètres
# fit took 10.176814 seconds
# echec
#
#
# MH étape : 290
# modification des paramètres
# fit took 13.204545 seconds
# echec
#
#
# MH étape : 291
# modification des paramètres
# fit took 20.034611 seconds
# echec
#
#
# MH étape : 292
# modification des paramètres
# fit took 15.884946 seconds
# echec
#
#
# MH étape : 293
# ajout d'une couche au generator
# fit took 16.192984 seconds
# echec
#
#
# MH étape : 294
# modification des paramètres
# fit took 19.057730 seconds
# echec
#
#
# MH étape : 295
# modification des paramètres
# fit took 11.097611 seconds
# echec
#
#
# MH étape : 296
# suppression d'une couche du generator
# fit took 13.759262 seconds
# echec
#
#
# MH étape : 297
# modification des paramètres
# fit took 19.908266 seconds
# echec
#
#
# MH étape : 298
# ajout d'une couche au generator
# fit took 16.104790 seconds
# echec
#
#
# MH étape : 299
# modification des paramètres
# fit took 12.106553 seconds
# echec
#
#
# MH étape : 300
# ajout d'une couche au discriminator
# fit took 16.213079 seconds
# succes
# 7.89011925799765 ->  7.795355799301805
#
# {'lr_g': 0.0005642, 'lr_d': 0.003666, 'epochs': 90, 'batch_size': 103, 'latent_dim': 15}
# generator : [74, 4]        ReLU
# discriminator : [72, 55, 14, 66, 1]        ReLU
#
#
# MH étape : 301
# modification des paramètres
# fit took 18.927401 seconds
# echec
#
#
# MH étape : 302
# suppression d'une couche du generator
# fit took 15.488330 seconds
# echec
#
#
# MH étape : 303
# suppression d'une couche du discriminator
# fit took 14.842012 seconds
# echec
#
#
# MH étape : 304
# modification des paramètres
# fit took 16.071126 seconds
# echec
#
#
# MH étape : 305
# suppression d'une couche du generator
# fit took 16.412647 seconds
# echec
#
#
# MH étape : 306
# modification des paramètres
# fit took 18.660537 seconds
# echec
#
#
# MH étape : 307
# modification des paramètres
# fit took 18.511152 seconds
# echec
#
#
# MH étape : 308
# suppression d'une couche du discriminator
# fit took 15.432053 seconds
# echec
#
#
# MH étape : 309
# modification des paramètres
# fit took 18.465597 seconds
# echec
#
#
# MH étape : 310
# ajout d'une couche au generator
# fit took 17.460337 seconds
# echec
#
#
# MH étape : 311
# modification des paramètres
# fit took 11.152366 seconds
# echec
#
#
# MH étape : 312
# ajout d'une couche au discriminator
# fit took 17.178163 seconds
# echec
#
#
# MH étape : 313
# suppression d'une couche du generator
# fit took 16.281521 seconds
# echec
#
#
# MH étape : 314
# modification des paramètres
# fit took 22.144730 seconds
# echec
#
#
# MH étape : 315
# modification des paramètres
# fit took 11.926177 seconds
# echec
#
#
# MH étape : 316
# modification des paramètres
# fit took 11.852040 seconds
# echec
#
#
# MH étape : 317
# ajout d'une couche au generator
# fit took 16.993520 seconds
# echec
#
#
# MH étape : 318
# modification des paramètres
# fit took 18.040862 seconds
# echec
#
#
# MH étape : 319
# modification des paramètres
# fit took 12.805023 seconds
# echec
#
#
# MH étape : 320
# suppression d'une couche du discriminator
# fit took 14.387226 seconds
# echec
#
#
# MH étape : 321
# modification des paramètres
# fit took 14.101259 seconds
# echec
#
#
# MH étape : 322
# modification de la fonction d'activation du generator
# fit took 16.207835 seconds
# echec
#
#
# MH étape : 323
# modification des paramètres
# fit took 22.198224 seconds
# echec
#
#
# MH étape : 324
# modification des paramètres
# fit took 14.609737 seconds
# echec
#
#
# MH étape : 325
# modification des paramètres
# fit took 21.853852 seconds
# echec
#
#
# MH étape : 326
# suppression d'une couche du generator
# fit took 15.551013 seconds
# echec
#
#
# MH étape : 327
# ajout d'une couche au generator
# fit took 16.961382 seconds
# echec
#
#
# MH étape : 328
# suppression d'une couche du generator
# fit took 15.593444 seconds
# echec
#
#
# MH étape : 329
# suppression d'une couche du discriminator
# fit took 15.771076 seconds
# echec
#
#
# MH étape : 330
# suppression d'une couche du discriminator
# fit took 14.345948 seconds
# echec
#
#
# MH étape : 331
# suppression d'une couche du generator
# fit took 15.514530 seconds
# echec
#
#
# MH étape : 332
# suppression d'une couche du generator
# fit took 15.395176 seconds
# echec
#
#
# MH étape : 333
# modification des paramètres
# fit took 22.067759 seconds
# echec
#
#
# MH étape : 334
# modification de la fonction d'activation du generator
# fit took 16.373716 seconds
# echec
#
#
# MH étape : 335
# modification des paramètres
# fit took 18.716237 seconds
# echec
#
#
# MH étape : 336
# modification des paramètres
# fit took 14.069512 seconds
# echec
#
#
# MH étape : 337
# ajout d'une couche au discriminator
# fit took 17.104821 seconds
# echec
#
#
# MH étape : 338
# suppression d'une couche du generator
# fit took 15.782163 seconds
# echec
#
#
# MH étape : 339
# modification de la fonction d'activation du generator
# fit took 16.181153 seconds
# echec
#
#
# MH étape : 340
# modification des paramètres
# fit took 10.948854 seconds
# echec
#
#
# MH étape : 341
# modification des paramètres
# fit took 15.655411 seconds
# echec
#
#
# MH étape : 342
# suppression d'une couche du discriminator
# fit took 14.456769 seconds
# echec
#
#
# MH étape : 343
# modification des paramètres
# fit took 21.104404 seconds
# echec
#
#
# MH étape : 344
# suppression d'une couche du generator
# fit took 15.740623 seconds
# echec
#
#
# MH étape : 345
# ajout d'une couche au discriminator
# fit took 17.506898 seconds
# echec
#
#
# MH étape : 346
# modification des paramètres
# fit took 21.886248 seconds
# echec
#
#
# MH étape : 347
# ajout d'une couche au discriminator
# fit took 17.329167 seconds
# echec
#
#
# MH étape : 348
# modification des paramètres
# fit took 12.711704 seconds
# echec
#
#
# MH étape : 349
# suppression d'une couche du discriminator
# fit took 15.274040 seconds
# echec
#
#
# MH étape : 350
# suppression d'une couche du generator
# fit took 15.549096 seconds
# echec
#
#
# MH étape : 351
# modification des paramètres
# fit took 12.028878 seconds
# echec
#
#
# MH étape : 352
# modification des paramètres
# fit took 18.266718 seconds
# echec
#
#
# MH étape : 353
# ajout d'une couche au discriminator
# fit took 17.699776 seconds
# echec
#
#
# MH étape : 354
# suppression d'une couche du discriminator
# fit took 14.670408 seconds
# echec
#
#
# MH étape : 355
# ajout d'une couche au discriminator
# fit took 17.053765 seconds
# echec
#
#
# MH étape : 356
# modification des paramètres
# fit took 21.964397 seconds
# echec
#
#
# MH étape : 357
# suppression d'une couche du generator
# fit took 15.740329 seconds
# echec
#
#
# MH étape : 358
# ajout d'une couche au generator
# fit took 17.206699 seconds
# echec
#
#
# MH étape : 359
# ajout d'une couche au discriminator
# fit took 17.304749 seconds
# echec
#
#
# MH étape : 360
# modification des paramètres
# fit took 10.757401 seconds
# echec
#
#
# MH étape : 361
# modification des paramètres
# fit took 12.453922 seconds
# echec
#
#
# MH étape : 362
# suppression d'une couche du generator
# fit took 15.511336 seconds
# echec
#
#
# MH étape : 363
# ajout d'une couche au discriminator
# fit took 17.204003 seconds
# echec
#
#
# MH étape : 364
# ajout d'une couche au generator
# fit took 16.837357 seconds
# echec
#
#
# MH étape : 365
# modification des paramètres
# fit took 18.688428 seconds
# echec
#
#
# MH étape : 366
# ajout d'une couche au discriminator
# fit took 17.452523 seconds
# echec
#
#
# MH étape : 367
# modification de la fonction d'activation du discriminator
# fit took 16.145282 seconds
# echec
#
#
# MH étape : 368
# modification des paramètres
# fit took 21.993926 seconds
# echec
#
#
# MH étape : 369
# modification des paramètres
# fit took 22.002338 seconds
# echec
#
#
# MH étape : 370
# modification des paramètres
# fit took 11.982358 seconds
# echec
#
#
# MH étape : 371
# suppression d'une couche du discriminator
# fit took 15.272037 seconds
# echec
#
#
# MH étape : 372
# ajout d'une couche au generator
# fit took 16.873222 seconds
# echec
#
#
# MH étape : 373
# modification des paramètres
# fit took 21.934884 seconds
# echec
#
#
# MH étape : 374
# modification des paramètres
# fit took 13.874826 seconds
# echec
#
#
# MH étape : 375
# ajout d'une couche au discriminator
# fit took 17.101568 seconds
# echec
#
#
# MH étape : 376
# ajout d'une couche au discriminator
# fit took 17.272687 seconds
# echec
#
#
# MH étape : 377
# modification des paramètres
# fit took 21.959553 seconds
# echec
#
#
# MH étape : 378
# modification des paramètres
# fit took 15.675552 seconds
# echec
#
#
# MH étape : 379
# suppression d'une couche du discriminator
# fit took 15.212800 seconds
# echec
#
#
# MH étape : 380
# suppression d'une couche du generator
# fit took 15.479169 seconds
# echec
#
#
# MH étape : 381
# modification des paramètres
# fit took 11.918840 seconds
# echec
#
#
# MH étape : 382
# modification des paramètres
# fit took 13.025853 seconds
# echec
#
#
# MH étape : 383
# ajout d'une couche au generator
# fit took 16.973138 seconds
# echec
#
#
# MH étape : 384
# modification de la fonction d'activation du generator
# fit took 16.283023 seconds
# echec
#
#
# MH étape : 385
# ajout d'une couche au discriminator
# fit took 17.407700 seconds
# echec
#
#
# MH étape : 386
# modification des paramètres
# fit took 21.261508 seconds
# echec
#
#
# MH étape : 387
# suppression d'une couche du generator
# fit took 15.470505 seconds
# echec
#
#
# MH étape : 388
# modification des paramètres
# fit took 12.128795 seconds
# echec
#
#
# MH étape : 389
# ajout d'une couche au discriminator
# fit took 17.632397 seconds
# echec
#
#
# MH étape : 390
# modification des paramètres
# fit took 13.507209 seconds
# echec
#
#
# MH étape : 391
# suppression d'une couche du generator
# fit took 15.563102 seconds
# echec
#
#
# MH étape : 392
# ajout d'une couche au generator
# fit took 17.024536 seconds
# echec
#
#
# MH étape : 393
# modification des paramètres
# fit took 13.989759 seconds
# echec
#
#
# MH étape : 394
# modification de la fonction d'activation du generator
# fit took 16.636284 seconds
# echec
#
#
# MH étape : 395
# suppression d'une couche du generator
# fit took 16.056186 seconds
# echec
#
#
# MH étape : 396
# ajout d'une couche au generator
# fit took 17.146443 seconds
# echec
#
#
# MH étape : 397
# modification des paramètres
# fit took 12.802143 seconds
# echec
#
#
# MH étape : 398
# suppression d'une couche du generator
# fit took 15.761634 seconds
# echec
#
#
# MH étape : 399
# suppression d'une couche du discriminator
# fit took 15.495871 seconds
# echec
#
#
# MH étape : 400
# ajout d'une couche au discriminator
# fit took 17.305886 seconds
# echec
#
#
# MH étape : 401
# suppression d'une couche du generator
# fit took 16.630995 seconds
# echec
#
#
# MH étape : 402
# suppression d'une couche du discriminator
# fit took 15.534551 seconds
# echec
#
#
# MH étape : 403
# modification des paramètres
# fit took 19.468517 seconds
# echec
#
#
# MH étape : 404
# suppression d'une couche du discriminator
# fit took 14.299815 seconds
# echec
#
#
# MH étape : 405
# modification des paramètres
# fit took 11.480507 seconds
# echec
#
#
# MH étape : 406
# ajout d'une couche au generator
# fit took 16.675698 seconds
# echec
#
#
# MH étape : 407
# modification des paramètres
# fit took 13.531065 seconds
# echec
#
#
# MH étape : 408
# modification des paramètres
# fit took 11.937160 seconds
# echec
#
#
# MH étape : 409
# ajout d'une couche au generator
# fit took 17.084034 seconds
# echec
#
#
# MH étape : 410
# modification des paramètres
# fit took 12.746873 seconds
# echec
#
#
# MH étape : 411
# suppression d'une couche du discriminator
# fit took 14.391892 seconds
# echec
#
#
# MH étape : 412
# modification des paramètres
# fit took 10.772833 seconds
# echec
#
#
# MH étape : 413
# modification des paramètres
# fit took 11.486004 seconds
# echec
#
#
# MH étape : 414
# modification des paramètres
# fit took 14.811689 seconds
# echec
#
#
# MH étape : 415
# ajout d'une couche au generator
# fit took 17.309479 seconds
# echec
#
#
# MH étape : 416
# ajout d'une couche au generator
# fit took 16.868095 seconds
# echec
#
#
# MH étape : 417
# ajout d'une couche au generator
# fit took 16.961414 seconds
# echec
#
#
# MH étape : 418
# modification des paramètres
# fit took 22.032798 seconds
# echec
#
#
# MH étape : 419
# modification des paramètres
# fit took 12.949434 seconds
# echec
#
#
# MH étape : 420
# modification des paramètres
# fit took 16.363358 seconds
# echec
#
#
# MH étape : 421
# modification de la fonction d'activation du discriminator
# fit took 16.266404 seconds
# succes
# 7.795355799301805 ->  7.730323092574521
#
# {'lr_g': 0.0005642, 'lr_d': 0.003666, 'epochs': 90, 'batch_size': 103, 'latent_dim': 15}
# generator : [74, 4]        ReLU
# discriminator : [72, 55, 14, 66, 1]        Sigmoid()
#
#
# MH étape : 422
# suppression d'une couche du discriminator
# fit took 14.343025 seconds
# echec
#
#
# MH étape : 423
# ajout d'une couche au discriminator
# fit took 17.400373 seconds
# echec
#
#
# MH étape : 424
# suppression d'une couche du discriminator
# fit took 14.295227 seconds
# echec
#
#
# MH étape : 425
# suppression d'une couche du generator
# fit took 15.643239 seconds
# echec
#
#
# MH étape : 426
# modification des paramètres
# fit took 21.014544 seconds
# echec
#
#
# MH étape : 427
# ajout d'une couche au generator
# fit took 17.238278 seconds
# echec
#
#
# MH étape : 428
# modification des paramètres
# fit took 14.562073 seconds
# echec
#
#
# MH étape : 429
# modification des paramètres
# fit took 17.237485 seconds
# echec
#
#
# MH étape : 430
# ajout d'une couche au discriminator
# fit took 17.457187 seconds
# echec
#
#
# MH étape : 431
# modification des paramètres
# fit took 13.125340 seconds
# echec
#
#
# MH étape : 432
# modification des paramètres
# fit took 13.727590 seconds
# echec
#
#
# MH étape : 433
# modification de la fonction d'activation du discriminator
# fit took 16.299843 seconds
# echec
#
#
# MH étape : 434
# modification des paramètres
# fit took 11.711731 seconds
# echec
#
#
# MH étape : 435
# modification des paramètres
# fit took 20.159778 seconds
# echec
#
#
# MH étape : 436
# modification des paramètres
# fit took 14.766168 seconds
# echec
#
#
# MH étape : 437
# modification des paramètres
# fit took 11.124321 seconds
# echec
#
#
# MH étape : 438
# suppression d'une couche du generator
# fit took 15.515705 seconds
# echec
#
#
# MH étape : 439
# modification des paramètres
# fit took 21.563233 seconds
# echec
#
#
# MH étape : 440
# modification des paramètres
# fit took 15.076197 seconds
# echec
#
#
# MH étape : 441
# modification des paramètres
# fit took 17.132432 seconds
# echec
#
#
# MH étape : 442
# suppression d'une couche du discriminator
# fit took 15.386735 seconds
# echec
#
#
# MH étape : 443
# ajout d'une couche au discriminator
# fit took 18.481064 seconds
# echec
#
#
# MH étape : 444
# modification de la fonction d'activation du generator
# fit took 16.396285 seconds
# echec
#
#
# MH étape : 445
# modification de la fonction d'activation du discriminator
# fit took 16.349447 seconds
# echec
#
#
# MH étape : 446
# suppression d'une couche du discriminator
# fit took 15.353277 seconds
# echec
#
#
# MH étape : 447
# modification des paramètres
# fit took 12.152439 seconds
# echec
#
#
# MH étape : 448
# modification des paramètres
# fit took 21.826828 seconds
# echec
#
#
# MH étape : 449
# modification des paramètres
# fit took 13.564798 seconds
# echec
#
#
# MH étape : 450
# modification des paramètres
# fit took 14.273376 seconds
# echec
#
#
# MH étape : 451
# modification des paramètres
# fit took 17.659035 seconds
# echec
#
#
# MH étape : 452
# modification des paramètres
# fit took 22.255902 seconds
# echec
#
#
# MH étape : 453
# modification des paramètres
# fit took 13.012010 seconds
# echec
#
#
# MH étape : 454
# modification des paramètres
# fit took 10.946973 seconds
# echec
#
#
# MH étape : 455
# modification des paramètres
# fit took 18.882514 seconds
# echec
#
#
# MH étape : 456
# modification des paramètres
# fit took 12.367944 seconds
# echec
#
#
# MH étape : 457
# modification des paramètres
# fit took 19.400666 seconds
# echec
#
#
# MH étape : 458
# modification des paramètres
# fit took 15.551272 seconds
# echec
#
#
# MH étape : 459
# suppression d'une couche du generator
# fit took 15.650154 seconds
# echec
#
#
# MH étape : 460
# suppression d'une couche du generator
# fit took 15.543276 seconds
# echec
#
#
# MH étape : 461
# modification des paramètres
# fit took 18.644315 seconds
# echec
#
#
# MH étape : 462
# suppression d'une couche du generator
# fit took 15.460274 seconds
# echec
#
#
# MH étape : 463
# suppression d'une couche du discriminator
# fit took 15.494648 seconds
# echec
#
#
# MH étape : 464
# modification des paramètres
# fit took 21.653120 seconds
# echec
#
#
# MH étape : 465
# modification des paramètres
# fit took 15.408766 seconds
# echec
#
#
# MH étape : 466
# modification des paramètres
# fit took 10.840624 seconds
# echec
#
#
# MH étape : 467
# suppression d'une couche du generator
# fit took 15.494330 seconds
# echec
#
#
# MH étape : 468
# modification des paramètres
# fit took 12.782791 seconds
# echec
#
#
# MH étape : 469
# suppression d'une couche du generator
# fit took 15.401584 seconds
# echec
#
#
# MH étape : 470
# suppression d'une couche du discriminator
# fit took 14.426768 seconds
# echec
#
#
# MH étape : 471
# ajout d'une couche au discriminator
# fit took 16.068647 seconds
# echec
#
#
# MH étape : 472
# modification des paramètres
# fit took 22.030315 seconds
# echec
#
#
# MH étape : 473
# modification des paramètres
# fit took 10.773728 seconds
# echec
#
#
# MH étape : 474
# ajout d'une couche au generator
# fit took 17.622216 seconds
# echec
#
#
# MH étape : 475
# modification des paramètres
# fit took 21.817022 seconds
# echec
#
#
# MH étape : 476
# suppression d'une couche du discriminator
# fit took 14.451587 seconds
# echec
#
#
# MH étape : 477
# modification des paramètres
# fit took 21.763527 seconds
# echec
#
#
# MH étape : 478
# modification des paramètres
# fit took 17.560314 seconds
# echec
#
#
# MH étape : 479
# suppression d'une couche du discriminator
# fit took 14.437891 seconds
# echec
#
#
# MH étape : 480
# modification des paramètres
# fit took 21.239433 seconds
# echec
#
#
# MH étape : 481
# modification des paramètres
# fit took 21.933838 seconds
# echec
#
#
# MH étape : 482
# modification des paramètres
# fit took 19.487016 seconds
# echec
#
#
# MH étape : 483
# suppression d'une couche du discriminator
# fit took 15.399278 seconds
# echec
#
#
# MH étape : 484
# modification des paramètres
# fit took 11.163576 seconds
# echec
#
#
# MH étape : 485
# suppression d'une couche du discriminator
# fit took 14.354978 seconds
# echec
#
#
# MH étape : 486
# suppression d'une couche du discriminator
# fit took 15.374038 seconds
# echec
#
#
# MH étape : 487
# modification des paramètres
# fit took 22.053438 seconds
# echec
#
#
# MH étape : 488
# modification des paramètres
# fit took 19.009675 seconds
# echec
#
#
# MH étape : 489
# modification des paramètres
# fit took 11.835898 seconds
# echec
#
#
# MH étape : 490
# modification des paramètres
# fit took 11.122323 seconds
# echec
#
#
# MH étape : 491
# modification des paramètres
# fit took 14.725764 seconds
# echec
#
#
# MH étape : 492
# modification des paramètres
# fit took 22.068485 seconds
# echec
#
#
# MH étape : 493
# suppression d'une couche du discriminator
# fit took 14.310658 seconds
# echec
#
#
# MH étape : 494
# modification des paramètres
# fit took 19.025060 seconds
# echec
#
#
# MH étape : 495
# ajout d'une couche au discriminator
# fit took 17.345823 seconds
# echec
#
#
# MH étape : 496
# suppression d'une couche du generator
# fit took 15.557844 seconds
# echec
#
#
# MH étape : 497
# modification des paramètres
# fit took 10.991580 seconds
# echec
#
#
# MH étape : 498
# modification des paramètres
# fit took 12.333242 seconds
# echec
#
#
# MH étape : 499
# modification des paramètres
# fit took 17.049514 seconds
# echec
#
#
# MH étape : 500
# suppression d'une couche du discriminator
# fit took 15.398966 seconds
# succes
# 7.730323092574521 ->  7.9624978370950386
#
# {'lr_g': 0.0005642, 'lr_d': 0.003666, 'epochs': 90, 'batch_size': 103, 'latent_dim': 15}
# generator : [74, 4]        ReLU
# discriminator : [72, 55, 66, 1]        Sigmoid()
#
#
# MH étape : 501
# modification des paramètres
# fit took 10.839523 seconds
# echec
#
#
# MH étape : 502
# suppression d'une couche du discriminator
# fit took 14.277126 seconds
# echec
#
#
# MH étape : 503
# modification des paramètres
# fit took 19.387606 seconds
# echec
#
#
# MH étape : 504
# modification des paramètres
# fit took 12.665562 seconds
# echec
#
#
# MH étape : 505
# suppression d'une couche du generator
# fit took 14.618351 seconds
# echec
#
#
# MH étape : 506
# modification des paramètres
# fit took 14.460356 seconds
# echec
#
#
# MH étape : 507
# modification des paramètres
# fit took 19.236430 seconds
# echec
#
#
# MH étape : 508
# ajout d'une couche au discriminator
# fit took 16.567041 seconds
# echec
#
#
# MH étape : 509
# suppression d'une couche du generator
# fit took 14.837106 seconds
# echec
#
#
# MH étape : 510
# suppression d'une couche du generator
# fit took 14.714963 seconds
# echec
#
#
# MH étape : 511
# ajout d'une couche au generator
# fit took 16.031688 seconds
# echec
#
#
# MH étape : 512
# suppression d'une couche du generator
# fit took 14.743380 seconds
# echec
#
#
# MH étape : 513
# modification des paramètres
# fit took 17.284331 seconds
# echec
#
#
# MH étape : 514
# modification des paramètres
# fit took 14.885173 seconds
# echec
#
#
# MH étape : 515
# modification des paramètres
# fit took 19.276767 seconds
# echec
#
#
# MH étape : 516
# modification des paramètres
# fit took 11.122394 seconds
# echec
#
#
# MH étape : 517
# ajout d'une couche au discriminator
# fit took 16.597806 seconds
# echec
#
#
# MH étape : 518
# ajout d'une couche au generator
# fit took 16.080648 seconds
# echec
#
#
# MH étape : 519
# suppression d'une couche du generator
# fit took 14.755227 seconds
# echec
#
#
# MH étape : 520
# modification des paramètres
# fit took 19.206755 seconds
# echec
#
#
# MH étape : 521
# modification des paramètres
# fit took 18.181175 seconds
# echec
#
#
# MH étape : 522
# modification des paramètres
# fit took 11.185986 seconds
# echec
#
#
# MH étape : 523
# modification des paramètres
# fit took 11.564547 seconds
# echec
#
#
# MH étape : 524
# ajout d'une couche au generator
# fit took 16.253001 seconds
# echec
#
#
# MH étape : 525
# modification des paramètres
# fit took 13.323195 seconds
# echec
#
#
# MH étape : 526
# suppression d'une couche du generator
# fit took 14.933837 seconds
# echec
#
#
# MH étape : 527
# ajout d'une couche au discriminator
# fit took 16.590565 seconds
# echec
#
#
# MH étape : 528
# modification des paramètres
# fit took 15.943866 seconds
# echec
#
#
# MH étape : 529
# modification des paramètres
# fit took 20.465510 seconds
# succes
# 7.9624978370950386 ->  8.108575683506787
#
# {'lr_g': 0.0003059, 'lr_d': 0.004094, 'epochs': 150, 'batch_size': 38, 'latent_dim': 25}
# generator : [74, 4]        ReLU
# discriminator : [72, 55, 66, 1]        Sigmoid()
#
#
# MH étape : 530
# ajout d'une couche au generator
# fit took 22.622127 seconds
# succes
# 8.108575683506787 ->  8.17120259603852
#
# {'lr_g': 0.0003059, 'lr_d': 0.004094, 'epochs': 150, 'batch_size': 38, 'latent_dim': 25}
# generator : [74, 63, 4]        ReLU
# discriminator : [72, 55, 66, 1]        Sigmoid()
#
#
# MH étape : 531
# suppression d'une couche du generator
# fit took 20.795197 seconds
# echec
#
#
# MH étape : 532
# modification des paramètres
# fit took 21.981094 seconds
# succes
# ...
# fit took 20.288090 seconds
# echec
#
#
# MH étape : 808
# suppression d'une couche du generator
# fit took 20.595284 seconds
# echec
#
#
# MH étape : 809
# modification des paramètres
# fit took 20.848165 seconds
# echec
#
#
# MH étape : 810
# ajout d'une couche au discriminator
# fit took 24.343408 seconds
# echec
#
#
# MH étape : 811
# ajout d'une couche au generator
# fit took 23.544287 seconds
# echec
#
#
# MH étape : 812
# modification des paramètres
# fit took 22.279329 seconds
# echec
#
#
# MH étape : 813
# suppression d'une couche du discriminator
# fit took 20.297107 seconds
# echec
#
#
# MH étape : 814
# ajout d'une couche au generator
# fit took 23.416634 seconds
# echec
#
#
# MH étape : 815
# modification des paramètres
# fit took 21.991259 seconds
# echec
#
#
# MH étape : 816
# modification des paramètres
# fit took 17.288780 seconds
# echec
#
#
# MH étape : 817
# suppression d'une couche du generator
# fit took 20.799841 seconds
# echec
#
#
# MH étape : 818
# modification des paramètres
# fit took 16.008060 seconds
# echec
#
#
# MH étape : 819
# modification des paramètres
# fit took 22.090507 seconds
# echec
#
#
# MH étape : 820
# modification des paramètres
# fit took 25.580371 seconds
# echec
#
#
# MH étape : 821
# modification des paramètres
# fit took 14.293483 seconds
# echec
#
#
# MH étape : 822
# suppression d'une couche du discriminator
# fit took 20.037223 seconds
# echec
#
#
# MH étape : 823
# suppression d'une couche du generator
# fit took 20.737666 seconds
# echec
#
#
# MH étape : 824
# ajout d'une couche au discriminator
# fit took 23.604987 seconds
# echec
#
#
# MH étape : 825
# modification de la fonction d'activation du generator
# fit took 22.051643 seconds
# echec
#
#
# MH étape : 826
# suppression d'une couche du generator
# fit took 20.794717 seconds
# echec
#
#
# MH étape : 827
# suppression d'une couche du generator
# fit took 21.064407 seconds
# echec
#
#
# MH étape : 828
# ajout d'une couche au generator
# fit took 22.667406 seconds
# echec
#
#
# MH étape : 829
# modification des paramètres
# fit took 21.948546 seconds
# echec
#
#
# MH étape : 830
# ajout d'une couche au generator
# fit took 23.339953 seconds
# echec
#
#
# MH étape : 831
# modification des paramètres
# fit took 22.101353 seconds
# echec
#
#
# MH étape : 832
# modification des paramètres
# fit took 14.931101 seconds
# echec
#
#
# MH étape : 833
# modification des paramètres
# fit took 17.315808 seconds
# echec
#
#
# MH étape : 834
# suppression d'une couche du generator
# fit took 20.887453 seconds
# echec
#
#
# MH étape : 835
# modification des paramètres
# fit took 14.273015 seconds
# echec
#
#
# MH étape : 836
# modification de la fonction d'activation du generator
# fit took 22.027781 seconds
# echec
#
#
# MH étape : 837
# modification des paramètres
# fit took 21.963348 seconds
# echec
#
#
# MH étape : 838
# modification des paramètres
# fit took 21.874186 seconds
# echec
#
#
# MH étape : 839
# ajout d'une couche au generator
# fit took 22.992232 seconds
# echec
#
#
# MH étape : 840
# modification des paramètres
# fit took 22.179286 seconds
# echec
#
#
# MH étape : 841
# ajout d'une couche au generator
# fit took 23.382535 seconds
# echec
#
#
# MH étape : 842
# modification des paramètres
# fit took 21.933301 seconds
# echec
#
#
# MH étape : 843
# ajout d'une couche au generator
# fit took 23.288267 seconds
# echec
#
#
# MH étape : 844
# modification des paramètres
# fit took 22.097627 seconds
# echec
#
#
# MH étape : 845
# modification de la fonction d'activation du discriminator
# fit took 22.047137 seconds
# echec
#
#
# MH étape : 846
# modification des paramètres
# fit took 22.219346 seconds
# echec
#
#
# MH étape : 847
# modification des paramètres
# fit took 20.627536 seconds
# echec
#
#
# MH étape : 848
# modification des paramètres
# fit took 16.657338 seconds
# echec
#
#
# MH étape : 849
# modification des paramètres
# fit took 14.576899 seconds
# echec
#
#
# MH étape : 850
# modification des paramètres
# fit took 19.994987 seconds
# echec
#
#
# MH étape : 851
# suppression d'une couche du generator
# fit took 20.851735 seconds
# echec
#
#
# MH étape : 852
# modification des paramètres
# fit took 22.008501 seconds
# echec
#
#
# MH étape : 853
# modification des paramètres
# fit took 16.104430 seconds
# echec
#
#
# MH étape : 854
# modification des paramètres
# fit took 21.920177 seconds
# echec
#
#
# MH étape : 855
# suppression d'une couche du generator
# fit took 20.838928 seconds
# echec
#
#
# MH étape : 856
# ajout d'une couche au generator
# fit took 23.296458 seconds
# echec
#
#
# MH étape : 857
# ajout d'une couche au discriminator
# fit took 23.708336 seconds
# echec
#
#
# MH étape : 858
# suppression d'une couche du discriminator
# fit took 20.223732 seconds
# echec
#
#
# MH étape : 859
# ajout d'une couche au generator
# fit took 23.162282 seconds
# echec
#
#
# MH étape : 860
# modification de la fonction d'activation du generator
# fit took 22.091078 seconds
# echec
#
#
# MH étape : 861
# modification des paramètres
# fit took 22.303602 seconds
# echec
#
#
# MH étape : 862
# ajout d'une couche au generator
# fit took 23.012917 seconds
# echec
#
#
# MH étape : 863
# modification des paramètres
# fit took 20.556457 seconds
# echec
#
#
# MH étape : 864
# ajout d'une couche au generator
# fit took 23.717939 seconds
# echec
#
#
# MH étape : 865
# modification des paramètres
# fit took 22.529189 seconds
# echec
#
#
# MH étape : 866
# modification des paramètres
# fit took 17.537301 seconds
# echec
#
#
# MH étape : 867
# modification des paramètres
# fit took 22.096143 seconds
# echec
#
#
# MH étape : 868
# suppression d'une couche du discriminator
# fit took 20.841344 seconds
# echec
#
#
# MH étape : 869
# modification des paramètres
# fit took 16.215449 seconds
# echec
#
#
# MH étape : 870
# modification des paramètres
# fit took 22.026236 seconds
# echec
#
#
# MH étape : 871
# ajout d'une couche au generator
# fit took 23.363398 seconds
# echec
#
#
# MH étape : 872
# modification de la fonction d'activation du discriminator
# fit took 22.025099 seconds
# echec
#
#
# MH étape : 873
# suppression d'une couche du generator
# fit took 20.552710 seconds
# echec
#
#
# MH étape : 874
# modification des paramètres
# fit took 20.014077 seconds
# echec
#
#
# MH étape : 875
# modification de la fonction d'activation du generator
# fit took 21.908807 seconds
# echec
#
#
# MH étape : 876
# suppression d'une couche du generator
# fit took 20.772561 seconds
# echec
#
#
# MH étape : 877
# suppression d'une couche du generator
# fit took 20.753059 seconds
# echec
#
#
# MH étape : 878
# suppression d'une couche du generator
# fit took 20.720536 seconds
# echec
#
#
# MH étape : 879
# modification des paramètres
# fit took 21.991774 seconds
# echec
#
#
# MH étape : 880
# suppression d'une couche du generator
# fit took 20.549218 seconds
# echec
#
#
# MH étape : 881
# modification des paramètres
# fit took 22.071850 seconds
# echec
#
#
# MH étape : 882
# modification des paramètres
# fit took 20.207170 seconds
# echec
#
#
# MH étape : 883
# modification des paramètres
# fit took 21.995152 seconds
# echec
#
#
# MH étape : 884
# ajout d'une couche au discriminator
# fit took 23.903128 seconds
# echec
#
#
# MH étape : 885
# modification des paramètres
# fit took 22.026360 seconds
# echec
#
#
# MH étape : 886
# modification des paramètres
# fit took 21.920136 seconds
# echec
#
#
# MH étape : 887
# modification des paramètres
# fit took 22.038745 seconds
# echec
#
#
# MH étape : 888
# suppression d'une couche du generator
# fit took 20.619338 seconds
# echec
#
#
# MH étape : 889
# ajout d'une couche au generator
# fit took 23.325347 seconds
# echec
#
#
# MH étape : 890
# modification des paramètres
# fit took 22.296516 seconds
# echec
#
#
# MH étape : 891
# modification des paramètres
# fit took 20.980847 seconds
# echec
#
#
# MH étape : 892
# modification des paramètres
# fit took 15.797261 seconds
# echec
#
#
# MH étape : 893
# modification des paramètres
# fit took 22.330475 seconds
# echec
#
#
# MH étape : 894
# ajout d'une couche au discriminator
# fit took 23.983055 seconds
# echec
#
#
# MH étape : 895
# suppression d'une couche du generator
# fit took 20.695824 seconds
# echec
#
#
# MH étape : 896
# modification des paramètres
# fit took 22.305437 seconds
# echec
#
#
# MH étape : 897
# suppression d'une couche du generator
# fit took 20.608001 seconds
# echec
#
#
# MH étape : 898
# modification des paramètres
# fit took 22.301945 seconds
# echec
#
#
# MH étape : 899
# modification des paramètres
# fit took 22.013115 seconds
# echec
#
#
# MH étape : 900
# ajout d'une couche au discriminator
# fit took 24.436062 seconds
# echec
#
#
# MH étape : 901
# suppression d'une couche du discriminator
# fit took 20.232421 seconds
# echec
#
#
# MH étape : 902
# ajout d'une couche au discriminator
# fit took 23.670745 seconds
# echec
#
#
# MH étape : 903
# ajout d'une couche au discriminator
# fit took 24.214810 seconds
# echec
#
#
# MH étape : 904
# modification des paramètres
# fit took 17.930708 seconds
# echec
#
#
# MH étape : 905
# modification des paramètres
# fit took 22.400802 seconds
# echec
#
#
# MH étape : 906
# modification des paramètres
# fit took 22.329919 seconds
# echec
#
#
# MH étape : 907
# modification des paramètres
# fit took 22.185135 seconds
# echec
#
#
# MH étape : 908
# suppression d'une couche du discriminator
# fit took 20.307555 seconds
# echec
#
#
# MH étape : 909
# modification des paramètres
# fit took 22.282160 seconds
# echec
#
#
# MH étape : 910
# modification des paramètres
# fit took 22.188519 seconds
# echec
#
#
# MH étape : 911
# modification des paramètres
# fit took 21.983975 seconds
# echec
#
#
# MH étape : 912
# modification des paramètres
# fit took 20.610683 seconds
# echec
#
#
# MH étape : 913
# suppression d'une couche du discriminator
# fit took 20.312785 seconds
# echec
#
#
# MH étape : 914
# suppression d'une couche du discriminator
# fit took 20.440425 seconds
# echec
#
#
# MH étape : 915
# suppression d'une couche du generator
# fit took 20.641008 seconds
# echec
#
#
# MH étape : 916
# suppression d'une couche du discriminator
# fit took 20.365114 seconds
# echec
#
#
# MH étape : 917
# suppression d'une couche du discriminator
# fit took 20.366577 seconds
# echec
#
#
# MH étape : 918
# modification des paramètres
# fit took 13.089024 seconds
# echec
#
#
# MH étape : 919
# ajout d'une couche au discriminator
# fit took 23.988711 seconds
# echec
#
#
# MH étape : 920
# modification des paramètres
# fit took 22.046741 seconds
# echec
#
#
# MH étape : 921
# suppression d'une couche du discriminator
# fit took 20.406359 seconds
# echec
#
#
# MH étape : 922
# modification des paramètres
# fit took 22.078067 seconds
# echec
#
#
# MH étape : 923
# modification des paramètres
# fit took 14.980143 seconds
# echec
#
#
# MH étape : 924
# modification des paramètres
# fit took 21.967853 seconds
# echec
#
#
# MH étape : 925
# modification des paramètres
# fit took 22.214452 seconds
# echec
#
#
# MH étape : 926
# ajout d'une couche au discriminator
# fit took 23.554588 seconds
# echec
#
#
# MH étape : 927
# ajout d'une couche au discriminator
# fit took 24.325022 seconds
# echec
#
#
# MH étape : 928
# modification des paramètres
# fit took 16.920391 seconds
# echec
#
#
# MH étape : 929
# suppression d'une couche du discriminator
# fit took 20.239661 seconds
# echec
#
#
# MH étape : 930
# modification des paramètres
# fit took 12.936485 seconds
# echec
#
#
# MH étape : 931
# modification des paramètres
# fit took 22.106213 seconds
# echec
#
#
# MH étape : 932
# modification des paramètres
# fit took 19.969966 seconds
# echec
#
#
# MH étape : 933
# modification des paramètres
# fit took 15.672179 seconds
# echec
#
#
# MH étape : 934
# modification des paramètres
# fit took 21.976725 seconds
# echec
#
#
# MH étape : 935
# ajout d'une couche au discriminator
# fit took 24.367734 seconds
# echec
#
#
# MH étape : 936
# modification des paramètres
# fit took 18.382550 seconds
# echec
#
#
# MH étape : 937
# suppression d'une couche du generator
# fit took 20.708053 seconds
# echec
#
#
# MH étape : 938
# modification de la fonction d'activation du discriminator
# fit took 21.848365 seconds
# echec
#
#
# MH étape : 939
# modification des paramètres
# fit took 13.004940 seconds
# echec
#
#
# MH étape : 940
# suppression d'une couche du discriminator
# fit took 19.985517 seconds
# echec
#
#
# MH étape : 941
# modification des paramètres
# fit took 22.252279 seconds
# echec
#
#
# MH étape : 942
# suppression d'une couche du generator
# fit took 20.533065 seconds
# echec
#
#
# MH étape : 943
# ajout d'une couche au generator
# fit took 23.311315 seconds
# echec
#
#
# MH étape : 944
# modification des paramètres
# fit took 21.906569 seconds
# echec
#
#
# MH étape : 945
# ajout d'une couche au discriminator
# fit took 23.894253 seconds
# echec
#
#
# MH étape : 946
# modification des paramètres
# fit took 17.922771 seconds
# echec
#
#
# MH étape : 947
# modification des paramètres
# fit took 21.963917 seconds
# echec
#
#
# MH étape : 948
# modification des paramètres
# fit took 22.284691 seconds
# echec
#
#
# MH étape : 949
# ajout d'une couche au generator
# fit took 23.425430 seconds
# echec
#
#
# MH étape : 950
# suppression d'une couche du generator
# fit took 22.179301 seconds
# echec
#
#
# MH étape : 951
# suppression d'une couche du generator
# fit took 20.957197 seconds
# echec
#
#
# MH étape : 952
# modification des paramètres
# fit took 21.978096 seconds
# echec
#
#
# MH étape : 953
# modification des paramètres
# fit took 14.645753 seconds
# echec
#
#
# MH étape : 954
# modification des paramètres
# fit took 18.587287 seconds
# echec
#
#
# MH étape : 955
# suppression d'une couche du discriminator
# fit took 20.377158 seconds
# echec
#
#
# MH étape : 956
# ajout d'une couche au generator
# fit took 22.971495 seconds
# echec
#
#
# MH étape : 957
# ajout d'une couche au discriminator
# fit took 23.702379 seconds
# echec
#
#
# MH étape : 958
# ajout d'une couche au generator
# fit took 22.965665 seconds
# echec
#
#
# MH étape : 959
# modification des paramètres
# fit took 22.033396 seconds
# echec
#
#
# MH étape : 960
# ajout d'une couche au discriminator
# fit took 24.034756 seconds
# echec
#
#
# MH étape : 961
# modification des paramètres
# fit took 21.908570 seconds
# echec
#
#
# MH étape : 962
# modification des paramètres
# fit took 22.221983 seconds
# echec
#
#
# MH étape : 963
# suppression d'une couche du generator
# fit took 20.629922 seconds
# echec
#
#
# MH étape : 964
# modification des paramètres
# fit took 16.718764 seconds
# echec
#
#
# MH étape : 965
# suppression d'une couche du generator
# fit took 20.564879 seconds
# echec
#
#
# MH étape : 966
# ajout d'une couche au discriminator
# fit took 23.901802 seconds
# echec
#
#
# MH étape : 967
# modification des paramètres
# fit took 22.300957 seconds
# echec
#
#
# MH étape : 968
# ajout d'une couche au generator
# fit took 23.415531 seconds
# echec
#
#
# MH étape : 969
# ajout d'une couche au discriminator
# fit took 23.907017 seconds
# echec
#
#
# MH étape : 970
# modification des paramètres
# fit took 22.416878 seconds
# echec
#
#
# MH étape : 971
# suppression d'une couche du discriminator
# fit took 20.118008 seconds
# echec
#
#
# MH étape : 972
# modification des paramètres
# fit took 19.020273 seconds
# echec
#
#
# MH étape : 973
# suppression d'une couche du generator
# fit took 20.546085 seconds
# echec
#
#
# MH étape : 974
# suppression d'une couche du generator
# fit took 20.829422 seconds
# echec
#
#
# MH étape : 975
# modification de la fonction d'activation du discriminator
# fit took 21.914263 seconds
# echec
#
#
# MH étape : 976
# modification des paramètres
# fit took 14.481665 seconds
# echec
#
#
# MH étape : 977
# modification des paramètres
# fit took 18.936591 seconds
# echec
#
#
# MH étape : 978
# modification des paramètres
# fit took 21.900947 seconds
# echec
#
#
# MH étape : 979
# modification des paramètres
# fit took 21.829731 seconds
# echec
#
#
# MH étape : 980
# modification des paramètres
# fit took 22.040448 seconds
# echec
#
#
# MH étape : 981
# ajout d'une couche au discriminator
# fit took 24.299378 seconds
# echec
#
#
# MH étape : 982
# modification des paramètres
# fit took 22.005359 seconds
# echec
#
#
# MH étape : 983
# modification des paramètres
# fit took 13.660852 seconds
# echec
#
#
# MH étape : 984
# modification des paramètres
# fit took 14.137793 seconds
# echec
#
#
# MH étape : 985
# modification des paramètres
# fit took 17.981710 seconds
# echec
#
#
# MH étape : 986
# suppression d'une couche du generator
# fit took 20.679349 seconds
# echec
#
#
# MH étape : 987
# modification des paramètres
# fit took 21.967474 seconds
# echec
#
#
# MH étape : 988
# ajout d'une couche au discriminator
# fit took 24.008434 seconds
# echec
#
#
# MH étape : 989
# modification de la fonction d'activation du discriminator
# fit took 21.913601 seconds
# echec
#
#
# MH étape : 990
# suppression d'une couche du generator
# fit took 20.833201 seconds
# echec
#
#
# MH étape : 991
# modification des paramètres
# fit took 20.476464 seconds
# echec
#
#
# MH étape : 992
# ajout d'une couche au generator
# fit took 25.814448 seconds
# echec
#
#
# MH étape : 993
# suppression d'une couche du generator
# fit took 20.725124 seconds
# echec
#
#
# MH étape : 994
# modification des paramètres
# fit took 18.002239 seconds
# echec
#
#
# MH étape : 995
# modification des paramètres
# fit took 22.175457 seconds
# echec
#
#
# MH étape : 996
# modification des paramètres
# fit took 22.163606 seconds
# echec
#
#
# MH étape : 997
# ajout d'une couche au discriminator
# fit took 24.324977 seconds
# echec
#
#
# MH étape : 998
# modification des paramètres
# fit took 20.770662 seconds
# echec
#
#
# MH étape : 999
# modification des paramètres
# fit took 14.865602 seconds
# echec

# %%
print(archi)
# Out:
# {'generator': {'architecture': 'MLP', 'layer_sizes': [74, 63, 4], 'activation': 'ReLU'}, 'discriminator': {'architecture': 'MLP', 'layer_sizes': [72, 55, 66, 1], 'activation': Sigmoid()}}

# %%
model = GAN()
model.set_data(data)
model.fit(architectures = archi)
model.fit_hyperparameters({"lr_g": [5e-6, 5e-3], "lr_d": [5e-6, 5e-3], "epochs": [50, 150], "batch_size": [8,300], "latent_dim": [1,150]}, n_trials = 100)
# Out:
# [I 2025-04-17 05:45:57,731] A new study created in memory with name: no-name-1280a1fb-8a32-4017-963b-73db3e4027c8
# fit took 9.760582 seconds
# fit took 24.077113 seconds
# [I 2025-04-17 05:46:22,489] Trial 0 finished with value: 161.66443743966826 and parameters: {'lr_g': 0.0035258463741204824, 'lr_d': 0.003113734034989327, 'epochs': 120, 'batch_size': 62, 'latent_dim': 4}. Best is trial 0 with value: 161.66443743966826.
# fit took 18.959862 seconds
# [I 2025-04-17 05:46:42,043] Trial 1 finished with value: 58.23771626924011 and parameters: {'lr_g': 0.004373342916888578, 'lr_d': 0.00012154654077646783, 'epochs': 93, 'batch_size': 55, 'latent_dim': 10}. Best is trial 1 with value: 58.23771626924011.
# fit took 15.483760 seconds
# [I 2025-04-17 05:46:58,091] Trial 2 finished with value: 183.55329964276405 and parameters: {'lr_g': 0.0009956164774336653, 'lr_d': 0.0037122339633225516, 'epochs': 74, 'batch_size': 159, 'latent_dim': 105}. Best is trial 1 with value: 58.23771626924011.
# fit took 17.853164 seconds
# [I 2025-04-17 05:47:16,571] Trial 3 finished with value: 869.9157082558343 and parameters: {'lr_g': 0.004587537266933075, 'lr_d': 0.001703487329247376, 'epochs': 84, 'batch_size': 259, 'latent_dim': 131}. Best is trial 1 with value: 58.23771626924011.
# fit took 30.763592 seconds
# [I 2025-04-17 05:47:47,966] Trial 4 finished with value: 334.02128482904607 and parameters: {'lr_g': 0.004794426653695019, 'lr_d': 0.0018254518180505237, 'epochs': 147, 'batch_size': 99, 'latent_dim': 114}. Best is trial 1 with value: 58.23771626924011.
# fit took 16.099002 seconds
# [I 2025-04-17 05:48:04,638] Trial 5 finished with value: 48.07058521688611 and parameters: {'lr_g': 0.0047587261945343405, 'lr_d': 0.0006457483167813221, 'epochs': 76, 'batch_size': 86, 'latent_dim': 54}. Best is trial 5 with value: 48.07058521688611.
# fit took 11.960989 seconds
# [I 2025-04-17 05:48:17,221] Trial 6 finished with value: 23.60999385181484 and parameters: {'lr_g': 0.00027103761296517375, 'lr_d': 0.0005175920552138656, 'epochs': 57, 'batch_size': 117, 'latent_dim': 99}. Best is trial 6 with value: 23.60999385181484.
# fit took 21.208459 seconds
# [I 2025-04-17 05:48:38,997] Trial 7 finished with value: 52.94463371220176 and parameters: {'lr_g': 0.0028333603790279445, 'lr_d': 0.0002873502790418724, 'epochs': 100, 'batch_size': 108, 'latent_dim': 107}. Best is trial 6 with value: 23.60999385181484.
# fit took 20.763142 seconds
# [I 2025-04-17 05:49:00,335] Trial 8 finished with value: 50.29817228853203 and parameters: {'lr_g': 0.003987728721703055, 'lr_d': 0.0005653231014009511, 'epochs': 99, 'batch_size': 130, 'latent_dim': 99}. Best is trial 6 with value: 23.60999385181484.
# fit took 19.185103 seconds
# [I 2025-04-17 05:49:20,168] Trial 9 finished with value: 140.2657234035495 and parameters: {'lr_g': 0.003472471637324571, 'lr_d': 0.004932129479466496, 'epochs': 92, 'batch_size': 228, 'latent_dim': 98}. Best is trial 6 with value: 23.60999385181484.
# fit took 10.808665 seconds
# [I 2025-04-17 05:49:31,650] Trial 10 finished with value: 9.939402368323504 and parameters: {'lr_g': 6.736583397391185e-05, 'lr_d': 0.0015517808859570256, 'epochs': 52, 'batch_size': 14, 'latent_dim': 54}. Best is trial 10 with value: 9.939402368323504.
# fit took 10.538235 seconds
# [I 2025-04-17 05:49:42,770] Trial 11 finished with value: 14.914589261214521 and parameters: {'lr_g': 3.216099826345523e-05, 'lr_d': 0.0016074955298373333, 'epochs': 50, 'batch_size': 18, 'latent_dim': 65}. Best is trial 10 with value: 9.939402368323504.
# fit took 10.314247 seconds
# [I 2025-04-17 05:49:53,691] Trial 12 finished with value: 23.66853707082227 and parameters: {'lr_g': 0.0016479801239071893, 'lr_d': 0.0017204757844915823, 'epochs': 50, 'batch_size': 11, 'latent_dim': 51}. Best is trial 10 with value: 9.939402368323504.
# fit took 13.133604 seconds
# [I 2025-04-17 05:50:07,444] Trial 13 finished with value: 181.36421544868924 and parameters: {'lr_g': 1.4333914878958236e-05, 'lr_d': 0.0024129152517499996, 'epochs': 63, 'batch_size': 14, 'latent_dim': 65}. Best is trial 10 with value: 9.939402368323504.
# fit took 24.597782 seconds
# [I 2025-04-17 05:50:32,630] Trial 14 finished with value: 45.31639396902578 and parameters: {'lr_g': 0.001070955596354225, 'lr_d': 0.0013325059312568964, 'epochs': 121, 'batch_size': 174, 'latent_dim': 35}. Best is trial 10 with value: 9.939402368323504.
# fit took 14.154923 seconds
# [I 2025-04-17 05:50:47,457] Trial 15 finished with value: 269.0437353201852 and parameters: {'lr_g': 0.0020424893855211772, 'lr_d': 0.0025295670167197115, 'epochs': 65, 'batch_size': 43, 'latent_dim': 74}. Best is trial 10 with value: 9.939402368323504.
# fit took 10.082997 seconds
# [I 2025-04-17 05:50:58,183] Trial 16 finished with value: 22.227639249481104 and parameters: {'lr_g': 0.000686286987722026, 'lr_d': 0.0010191010896501342, 'epochs': 50, 'batch_size': 207, 'latent_dim': 29}. Best is trial 10 with value: 9.939402368323504.
# fit took 23.312803 seconds
# [I 2025-04-17 05:51:22,094] Trial 17 finished with value: 35.955022594988854 and parameters: {'lr_g': 0.001596168997933287, 'lr_d': 0.002506654175899249, 'epochs': 113, 'batch_size': 29, 'latent_dim': 81}. Best is trial 10 with value: 9.939402368323504.
# fit took 14.282356 seconds
# [I 2025-04-17 05:51:36,983] Trial 18 finished with value: 123.1247619314628 and parameters: {'lr_g': 0.0005478125511711623, 'lr_d': 0.003614900301256601, 'epochs': 68, 'batch_size': 289, 'latent_dim': 34}. Best is trial 10 with value: 9.939402368323504.
# fit took 31.033965 seconds
# [I 2025-04-17 05:52:08,646] Trial 19 finished with value: 129.7637597732585 and parameters: {'lr_g': 0.002604058178973968, 'lr_d': 0.0011734966697511966, 'epochs': 150, 'batch_size': 64, 'latent_dim': 79}. Best is trial 10 with value: 9.939402368323504.
# fit took 17.134497 seconds
# [I 2025-04-17 05:52:26,380] Trial 20 finished with value: 21.4761361855906 and parameters: {'lr_g': 0.0012799018451380379, 'lr_d': 0.0021097117058919905, 'epochs': 80, 'batch_size': 78, 'latent_dim': 150}. Best is trial 10 with value: 9.939402368323504.
# fit took 12.469205 seconds
# [I 2025-04-17 05:52:39,445] Trial 21 finished with value: 30.31359030074422 and parameters: {'lr_g': 0.0012656120024996762, 'lr_d': 0.0020959454223539904, 'epochs': 58, 'batch_size': 80, 'latent_dim': 148}. Best is trial 10 with value: 9.939402368323504.
# fit took 17.468642 seconds
# [I 2025-04-17 05:52:57,506] Trial 22 finished with value: 178.52408024033576 and parameters: {'lr_g': 3.9209564167850474e-05, 'lr_d': 0.0029863923888937298, 'epochs': 78, 'batch_size': 39, 'latent_dim': 49}. Best is trial 10 with value: 9.939402368323504.
# fit took 11.888445 seconds
# [I 2025-04-17 05:53:10,044] Trial 23 finished with value: 27.900904752279835 and parameters: {'lr_g': 0.0004882737623138674, 'lr_d': 0.0010192371522788376, 'epochs': 56, 'batch_size': 9, 'latent_dim': 63}. Best is trial 10 with value: 9.939402368323504.
# fit took 14.618219 seconds
# [I 2025-04-17 05:53:25,256] Trial 24 finished with value: 31.739786480109075 and parameters: {'lr_g': 0.0008453561760679831, 'lr_d': 0.0013762720027834727, 'epochs': 69, 'batch_size': 30, 'latent_dim': 149}. Best is trial 10 with value: 9.939402368323504.
# fit took 17.701202 seconds
# [I 2025-04-17 05:53:43,585] Trial 25 finished with value: 64.99681492562247 and parameters: {'lr_g': 0.0020966481163009827, 'lr_d': 0.001960843778071296, 'epochs': 83, 'batch_size': 75, 'latent_dim': 127}. Best is trial 10 with value: 9.939402368323504.
# fit took 10.514116 seconds
# [I 2025-04-17 05:53:54,715] Trial 26 finished with value: 46.986100735463 and parameters: {'lr_g': 0.0014797395680558687, 'lr_d': 0.002786471736242864, 'epochs': 50, 'batch_size': 134, 'latent_dim': 90}. Best is trial 10 with value: 9.939402368323504.
# fit took 12.350827 seconds
# [I 2025-04-17 05:54:07,642] Trial 27 finished with value: 380.2097320737534 and parameters: {'lr_g': 0.00043283593547157874, 'lr_d': 0.0021877264052886512, 'epochs': 60, 'batch_size': 48, 'latent_dim': 43}. Best is trial 10 with value: 9.939402368323504.
# fit took 27.320675 seconds
# [I 2025-04-17 05:54:35,548] Trial 28 finished with value: 1015.593480111828 and parameters: {'lr_g': 0.0018637772450973405, 'lr_d': 0.001510467781414791, 'epochs': 135, 'batch_size': 26, 'latent_dim': 19}. Best is trial 10 with value: 9.939402368323504.
# fit took 24.113853 seconds
# [I 2025-04-17 05:55:00,282] Trial 29 finished with value: 445.4783098450693 and parameters: {'lr_g': 0.0011993230543753033, 'lr_d': 0.003331751725583575, 'epochs': 114, 'batch_size': 66, 'latent_dim': 62}. Best is trial 10 with value: 9.939402368323504.
# fit took 17.281720 seconds
# [I 2025-04-17 05:55:18,238] Trial 30 finished with value: 53.57750096030137 and parameters: {'lr_g': 0.0002450485312037182, 'lr_d': 0.000845679643818781, 'epochs': 85, 'batch_size': 87, 'latent_dim': 3}. Best is trial 10 with value: 9.939402368323504.
# fit took 10.306249 seconds
# [I 2025-04-17 05:55:29,150] Trial 31 finished with value: 19.84125335779629 and parameters: {'lr_g': 0.000598217691102043, 'lr_d': 0.0009998918346613222, 'epochs': 50, 'batch_size': 200, 'latent_dim': 24}. Best is trial 10 with value: 9.939402368323504.
# fit took 14.546709 seconds
# [I 2025-04-17 05:55:44,329] Trial 32 finished with value: 13.686465985351964 and parameters: {'lr_g': 2.2226439252151335e-05, 'lr_d': 0.001599934872903959, 'epochs': 71, 'batch_size': 193, 'latent_dim': 19}. Best is trial 10 with value: 9.939402368323504.
# fit took 11.376282 seconds
# [I 2025-04-17 05:55:56,412] Trial 33 finished with value: 20.93032088036002 and parameters: {'lr_g': 0.0008161530428281928, 'lr_d': 0.0014687082149750313, 'epochs': 56, 'batch_size': 192, 'latent_dim': 17}. Best is trial 10 with value: 9.939402368323504.
# fit took 15.068304 seconds
# [I 2025-04-17 05:56:12,089] Trial 34 finished with value: 26.124238173983322 and parameters: {'lr_g': 0.00021864606205440962, 'lr_d': 0.00012540799702659671, 'epochs': 71, 'batch_size': 222, 'latent_dim': 24}. Best is trial 10 with value: 9.939402368323504.
# fit took 13.101200 seconds
# [I 2025-04-17 05:56:25,807] Trial 35 finished with value: 24.38689816527806 and parameters: {'lr_g': 0.0006383281012132338, 'lr_d': 0.001653122236886768, 'epochs': 64, 'batch_size': 161, 'latent_dim': 12}. Best is trial 10 with value: 9.939402368323504.
# fit took 10.972605 seconds
# [I 2025-04-17 05:56:37,407] Trial 36 finished with value: 19.203734738813047 and parameters: {'lr_g': 2.953278748065256e-05, 'lr_d': 0.0008257997719552486, 'epochs': 54, 'batch_size': 246, 'latent_dim': 8}. Best is trial 10 with value: 9.939402368323504.
# fit took 14.473584 seconds
# [I 2025-04-17 05:56:52,491] Trial 37 finished with value: 55.194453522469004 and parameters: {'lr_g': 0.00011752189584210701, 'lr_d': 0.0007651850040915837, 'epochs': 72, 'batch_size': 250, 'latent_dim': 1}. Best is trial 10 with value: 9.939402368323504.
# fit took 11.516763 seconds
# [I 2025-04-17 05:57:04,637] Trial 38 finished with value: 182.88637515817356 and parameters: {'lr_g': 0.0003776784517956488, 'lr_d': 0.004524394334302503, 'epochs': 55, 'batch_size': 299, 'latent_dim': 40}. Best is trial 10 with value: 9.939402368323504.
# fit took 12.456697 seconds
# [I 2025-04-17 05:57:17,726] Trial 39 finished with value: 35.879272045500656 and parameters: {'lr_g': 0.0009122620509863195, 'lr_d': 0.00033507290105489786, 'epochs': 62, 'batch_size': 238, 'latent_dim': 8}. Best is trial 10 with value: 9.939402368323504.
# fit took 18.820960 seconds
# [I 2025-04-17 05:57:37,144] Trial 40 finished with value: 57.92129056822473 and parameters: {'lr_g': 0.0029449493512012964, 'lr_d': 6.9643793508512245e-06, 'epochs': 91, 'batch_size': 276, 'latent_dim': 71}. Best is trial 10 with value: 9.939402368323504.
# fit took 11.041128 seconds
# [I 2025-04-17 05:57:48,796] Trial 41 finished with value: 20.204841188980737 and parameters: {'lr_g': 5.3610473403884775e-05, 'lr_d': 0.001155240772114839, 'epochs': 54, 'batch_size': 194, 'latent_dim': 22}. Best is trial 10 with value: 9.939402368323504.
# fit took 10.279203 seconds
# [I 2025-04-17 05:57:59,698] Trial 42 finished with value: 29.13685524269921 and parameters: {'lr_g': 0.0003710420948091662, 'lr_d': 0.001845988598086279, 'epochs': 50, 'batch_size': 179, 'latent_dim': 13}. Best is trial 10 with value: 9.939402368323504.
# fit took 13.948114 seconds
# [I 2025-04-17 05:58:14,272] Trial 43 finished with value: 37.74724215930205 and parameters: {'lr_g': 0.00062304029640454, 'lr_d': 0.0004837894475487516, 'epochs': 67, 'batch_size': 217, 'latent_dim': 55}. Best is trial 10 with value: 9.939402368323504.
# fit took 13.372138 seconds
# [I 2025-04-17 05:58:28,245] Trial 44 finished with value: 13.353149513500414 and parameters: {'lr_g': 1.1916589549471855e-05, 'lr_d': 0.000905657949724832, 'epochs': 61, 'batch_size': 268, 'latent_dim': 25}. Best is trial 10 with value: 9.939402368323504.
# fit took 12.775383 seconds
# [I 2025-04-17 05:58:41,630] Trial 45 finished with value: 15.286203455753471 and parameters: {'lr_g': 0.00022210872499670823, 'lr_d': 0.0006841345887661902, 'epochs': 61, 'batch_size': 268, 'latent_dim': 33}. Best is trial 10 with value: 9.939402368323504.
# fit took 12.563447 seconds
# [I 2025-04-17 05:58:54,883] Trial 46 finished with value: 5894.037114408654 and parameters: {'lr_g': 0.003793805324303199, 'lr_d': 0.0016432888050767745, 'epochs': 61, 'batch_size': 266, 'latent_dim': 43}. Best is trial 10 with value: 9.939402368323504.
# fit took 15.576334 seconds
# [I 2025-04-17 05:59:11,060] Trial 47 finished with value: 177.31180878755868 and parameters: {'lr_g': 0.00030655113413369884, 'lr_d': 0.0012983372770464523, 'epochs': 75, 'batch_size': 275, 'latent_dim': 34}. Best is trial 10 with value: 9.939402368323504.
# fit took 13.472351 seconds
# [I 2025-04-17 05:59:25,136] Trial 48 finished with value: 37.286910887924634 and parameters: {'lr_g': 0.0010557524420246316, 'lr_d': 0.0005975035965264221, 'epochs': 65, 'batch_size': 139, 'latent_dim': 57}. Best is trial 10 with value: 9.939402368323504.
# fit took 20.651700 seconds
# [I 2025-04-17 05:59:46,417] Trial 49 finished with value: 16.288674920271703 and parameters: {'lr_g': 0.0002547149175396111, 'lr_d': 0.0023255155151739038, 'epochs': 101, 'batch_size': 107, 'latent_dim': 49}. Best is trial 10 with value: 9.939402368323504.
# fit took 13.400708 seconds
# [I 2025-04-17 06:00:00,437] Trial 50 finished with value: 35.92544731601656 and parameters: {'lr_g': 0.0007799320527866228, 'lr_d': 0.0003770760109772348, 'epochs': 60, 'batch_size': 234, 'latent_dim': 31}. Best is trial 10 with value: 9.939402368323504.
# fit took 20.692333 seconds
# [I 2025-04-17 06:00:21,793] Trial 51 finished with value: 15.680052410005903 and parameters: {'lr_g': 0.000260947751220857, 'lr_d': 0.0015660859663108445, 'epochs': 100, 'batch_size': 151, 'latent_dim': 47}. Best is trial 10 with value: 9.939402368323504.
# fit took 21.828780 seconds
# [I 2025-04-17 06:00:44,242] Trial 52 finished with value: 18.552711377690915 and parameters: {'lr_g': 0.00046197714677966554, 'lr_d': 0.0018888134387557661, 'epochs': 106, 'batch_size': 147, 'latent_dim': 40}. Best is trial 10 with value: 9.939402368323504.
# fit took 26.172092 seconds
# [I 2025-04-17 06:01:11,029] Trial 53 finished with value: 25.49288712580254 and parameters: {'lr_g': 0.00018888056492513092, 'lr_d': 0.0011610220716129207, 'epochs': 129, 'batch_size': 252, 'latent_dim': 26}. Best is trial 10 with value: 9.939402368323504.
# fit took 18.363469 seconds
# [I 2025-04-17 06:01:30,038] Trial 54 finished with value: 89.49048504571381 and parameters: {'lr_g': 0.0032265960222189883, 'lr_d': 0.0016570730549544392, 'epochs': 89, 'batch_size': 124, 'latent_dim': 47}. Best is trial 10 with value: 9.939402368323504.
# fit took 15.314240 seconds
# [I 2025-04-17 06:01:45,958] Trial 55 finished with value: 51532.40644042358 and parameters: {'lr_g': 0.004286947583515873, 'lr_d': 0.0007329043643064155, 'epochs': 74, 'batch_size': 285, 'latent_dim': 67}. Best is trial 10 with value: 9.939402368323504.
# fit took 29.502731 seconds
# [I 2025-04-17 06:02:16,150] Trial 56 finished with value: 11.310965460295211 and parameters: {'lr_g': 1.2008611026324966e-05, 'lr_d': 0.000938418392126587, 'epochs': 142, 'batch_size': 22, 'latent_dim': 58}. Best is trial 10 with value: 9.939402368323504.
# fit took 29.367053 seconds
# [I 2025-04-17 06:02:46,128] Trial 57 finished with value: 11.05939285125263 and parameters: {'lr_g': 4.033419012512835e-05, 'lr_d': 0.000943384462293505, 'epochs': 142, 'batch_size': 20, 'latent_dim': 84}. Best is trial 10 with value: 9.939402368323504.
# fit took 29.179538 seconds
# [I 2025-04-17 06:03:15,895] Trial 58 finished with value: 26.349823043923838 and parameters: {'lr_g': 0.0006630234814008969, 'lr_d': 0.000977734083066267, 'epochs': 139, 'batch_size': 20, 'latent_dim': 88}. Best is trial 10 with value: 9.939402368323504.
# fit took 30.312520 seconds
# [I 2025-04-17 06:03:46,863] Trial 59 finished with value: 12.914681441872908 and parameters: {'lr_g': 3.5322258292665e-05, 'lr_d': 0.001324994960780213, 'epochs': 146, 'batch_size': 52, 'latent_dim': 76}. Best is trial 10 with value: 9.939402368323504.
# fit took 30.031163 seconds
# [I 2025-04-17 06:04:17,502] Trial 60 finished with value: 23.641439614168444 and parameters: {'lr_g': 0.00044614684515080494, 'lr_d': 0.0012472753300356105, 'epochs': 144, 'batch_size': 52, 'latent_dim': 89}. Best is trial 10 with value: 9.939402368323504.
# fit took 30.093909 seconds
# [I 2025-04-17 06:04:48,238] Trial 61 finished with value: 14.184364526027316 and parameters: {'lr_g': 8.241493180352803e-05, 'lr_d': 0.0009041434897132924, 'epochs': 146, 'batch_size': 38, 'latent_dim': 81}. Best is trial 10 with value: 9.939402368323504.
# fit took 30.762755 seconds
# [I 2025-04-17 06:05:19,693] Trial 62 finished with value: 13.38583346175962 and parameters: {'lr_g': 2.58975475487718e-05, 'lr_d': 0.0009160200417060528, 'epochs': 144, 'batch_size': 40, 'latent_dim': 79}. Best is trial 10 with value: 9.939402368323504.
# fit took 29.397996 seconds
# [I 2025-04-17 06:05:49,698] Trial 63 finished with value: 11.831194972192439 and parameters: {'lr_g': 5.810135958478471e-06, 'lr_d': 0.0011301671617573244, 'epochs': 141, 'batch_size': 31, 'latent_dim': 73}. Best is trial 10 with value: 9.939402368323504.
# fit took 29.140576 seconds
# [I 2025-04-17 06:06:19,442] Trial 64 finished with value: 140.04521755663038 and parameters: {'lr_g': 0.0005081483827164395, 'lr_d': 0.0010997092581103737, 'epochs': 139, 'batch_size': 60, 'latent_dim': 76}. Best is trial 10 with value: 9.939402368323504.
# fit took 27.866741 seconds
# [I 2025-04-17 06:06:47,903] Trial 65 finished with value: 11.565715515175963 and parameters: {'lr_g': 9.811425746517662e-06, 'lr_d': 0.0006071443689299597, 'epochs': 129, 'batch_size': 34, 'latent_dim': 106}. Best is trial 10 with value: 9.939402368323504.
# fit took 27.166109 seconds
# [I 2025-04-17 06:07:15,687] Trial 66 finished with value: 20.176023676387928 and parameters: {'lr_g': 0.0003639677689943994, 'lr_d': 0.0004831422277394896, 'epochs': 129, 'batch_size': 9, 'latent_dim': 112}. Best is trial 10 with value: 9.939402368323504.
# fit took 27.669483 seconds
# [I 2025-04-17 06:07:43,967] Trial 67 finished with value: 27.15993706000356 and parameters: {'lr_g': 0.0007561556024799342, 'lr_d': 0.0013915261714389047, 'epochs': 132, 'batch_size': 25, 'latent_dim': 94}. Best is trial 10 with value: 9.939402368323504.
# fit took 25.759952 seconds
# [I 2025-04-17 06:08:10,368] Trial 68 finished with value: 33.50613550364565 and parameters: {'lr_g': 0.0009372755726292624, 'lr_d': 0.0005926287341801919, 'epochs': 123, 'batch_size': 36, 'latent_dim': 103}. Best is trial 10 with value: 9.939402368323504.
# fit took 31.881558 seconds
# [I 2025-04-17 06:08:42,877] Trial 69 finished with value: 20.250928059501554 and parameters: {'lr_g': 0.00017964267518438365, 'lr_d': 0.0013072389608916055, 'epochs': 150, 'batch_size': 48, 'latent_dim': 127}. Best is trial 10 with value: 9.939402368323504.
# fit took 28.792911 seconds
# [I 2025-04-17 06:09:12,380] Trial 70 finished with value: 31.558783835630976 and parameters: {'lr_g': 0.002279338675982661, 'lr_d': 0.000250940891696138, 'epochs': 140, 'batch_size': 23, 'latent_dim': 58}. Best is trial 10 with value: 9.939402368323504.
# fit took 30.067897 seconds
# [I 2025-04-17 06:09:43,050] Trial 71 finished with value: 11.71284305718919 and parameters: {'lr_g': 2.422232024411595e-05, 'lr_d': 0.0009447403738020073, 'epochs': 144, 'batch_size': 36, 'latent_dim': 85}. Best is trial 10 with value: 9.939402368323504.
# fit took 27.919069 seconds
# [I 2025-04-17 06:10:11,575] Trial 72 finished with value: 31.71676372210399 and parameters: {'lr_g': 0.00015808013896413214, 'lr_d': 0.0010505453140067203, 'epochs': 135, 'batch_size': 34, 'latent_dim': 70}. Best is trial 10 with value: 9.939402368323504.
# fit took 29.327886 seconds
# [I 2025-04-17 06:10:41,568] Trial 73 finished with value: 17.175261570676827 and parameters: {'lr_g': 0.00035199731021946925, 'lr_d': 0.0008050593639747622, 'epochs': 142, 'batch_size': 17, 'latent_dim': 84}. Best is trial 10 with value: 9.939402368323504.
# fit took 30.747956 seconds
# [I 2025-04-17 06:11:12,914] Trial 74 finished with value: 179.50096922343266 and parameters: {'lr_g': 0.0004716539384617501, 'lr_d': 0.0013961054911458895, 'epochs': 148, 'batch_size': 69, 'latent_dim': 97}. Best is trial 10 with value: 9.939402368323504.
# fit took 28.553248 seconds
# [I 2025-04-17 06:11:42,144] Trial 75 finished with value: 183123.05778088438 and parameters: {'lr_g': 0.00495419091109537, 'lr_d': 0.0011905892350178582, 'epochs': 137, 'batch_size': 56, 'latent_dim': 85}. Best is trial 10 with value: 9.939402368323504.
# fit took 25.948722 seconds
# [I 2025-04-17 06:12:08,718] Trial 76 finished with value: 12.727853225135611 and parameters: {'lr_g': 1.9384207663962353e-05, 'lr_d': 0.0006975232268996987, 'epochs': 126, 'batch_size': 45, 'latent_dim': 75}. Best is trial 10 with value: 9.939402368323504.
# fit took 25.619312 seconds
# [I 2025-04-17 06:12:34,947] Trial 77 finished with value: 28.588666098908462 and parameters: {'lr_g': 0.0005508155441192431, 'lr_d': 0.00017993463229442475, 'epochs': 124, 'batch_size': 45, 'latent_dim': 68}. Best is trial 10 with value: 9.939402368323504.
# fit took 27.630821 seconds
# [I 2025-04-17 06:13:03,179] Trial 78 finished with value: 15.12894524804282 and parameters: {'lr_g': 0.00015957668431846475, 'lr_d': 0.00038535305410452615, 'epochs': 132, 'batch_size': 88, 'latent_dim': 74}. Best is trial 10 with value: 9.939402368323504.
# fit took 30.862484 seconds
# [I 2025-04-17 06:13:34,633] Trial 79 finished with value: 22.218755652823965 and parameters: {'lr_g': 0.0003353839482194366, 'lr_d': 0.0006919939841172755, 'epochs': 145, 'batch_size': 15, 'latent_dim': 119}. Best is trial 10 with value: 9.939402368323504.
# fit took 24.909018 seconds
# [I 2025-04-17 06:14:00,163] Trial 80 finished with value: 22.369690301664406 and parameters: {'lr_g': 0.00016047668227982327, 'lr_d': 0.0005318537511459925, 'epochs': 118, 'batch_size': 33, 'latent_dim': 63}. Best is trial 10 with value: 9.939402368323504.
# fit took 29.537112 seconds
# [I 2025-04-17 06:14:30,331] Trial 81 finished with value: 8.95373768515085 and parameters: {'lr_g': 2.667582824453984e-05, 'lr_d': 0.0009322735135453107, 'epochs': 143, 'batch_size': 8, 'latent_dim': 74}. Best is trial 81 with value: 8.95373768515085.
# fit took 29.370852 seconds
# [I 2025-04-17 06:15:00,288] Trial 82 finished with value: 11.183717862206331 and parameters: {'lr_g': 1.0237217882590493e-05, 'lr_d': 0.000762321332025225, 'epochs': 142, 'batch_size': 9, 'latent_dim': 76}. Best is trial 81 with value: 8.95373768515085.
# fit took 28.264684 seconds
# [I 2025-04-17 06:15:29,163] Trial 83 finished with value: 14.258841984543942 and parameters: {'lr_g': 0.000311199006975337, 'lr_d': 0.0007715585418806771, 'epochs': 136, 'batch_size': 8, 'latent_dim': 60}. Best is trial 81 with value: 8.95373768515085.
# fit took 29.241376 seconds
# [I 2025-04-17 06:15:59,056] Trial 84 finished with value: 18.761949185113878 and parameters: {'lr_g': 0.0001473964449967357, 'lr_d': 0.0010075237187063444, 'epochs': 142, 'batch_size': 26, 'latent_dim': 72}. Best is trial 81 with value: 8.95373768515085.
# fit took 27.241524 seconds
# [I 2025-04-17 06:16:26,977] Trial 85 finished with value: 54.52633158914172 and parameters: {'lr_g': 0.0005879398618899169, 'lr_d': 8.776798520411739e-06, 'epochs': 131, 'batch_size': 16, 'latent_dim': 93}. Best is trial 81 with value: 8.95373768515085.
# fit took 30.448761 seconds
# [I 2025-04-17 06:16:58,056] Trial 86 finished with value: 11.055592014033325 and parameters: {'lr_g': 1.4043030417967813e-05, 'lr_d': 0.0004548036490351482, 'epochs': 148, 'batch_size': 29, 'latent_dim': 53}. Best is trial 81 with value: 8.95373768515085.
# fit took 32.297050 seconds
# [I 2025-04-17 06:17:31,003] Trial 87 finished with value: 24.881710860192197 and parameters: {'lr_g': 0.0003057739300044791, 'lr_d': 0.0004830762876350541, 'epochs': 149, 'batch_size': 29, 'latent_dim': 107}. Best is trial 81 with value: 8.95373768515085.
# fit took 29.026672 seconds
# [I 2025-04-17 06:18:00,627] Trial 88 finished with value: 192.16507101642944 and parameters: {'lr_g': 0.0007430809517320592, 'lr_d': 0.004135978064523503, 'epochs': 140, 'batch_size': 18, 'latent_dim': 66}. Best is trial 81 with value: 8.95373768515085.
# fit took 29.338681 seconds
# [I 2025-04-17 06:18:30,571] Trial 89 finished with value: 27.531126669088508 and parameters: {'lr_g': 0.00041782378043421086, 'lr_d': 0.00030734094882464724, 'epochs': 142, 'batch_size': 9, 'latent_dim': 53}. Best is trial 81 with value: 8.95373768515085.
# fit took 28.043925 seconds
# [I 2025-04-17 06:18:59,213] Trial 90 finished with value: 56.265689333505065 and parameters: {'lr_g': 0.00014345019890920737, 'lr_d': 0.0010996606796493554, 'epochs': 134, 'batch_size': 23, 'latent_dim': 82}. Best is trial 81 with value: 8.95373768515085.
# fit took 26.257863 seconds
# [I 2025-04-17 06:19:26,077] Trial 91 finished with value: 15.984234216524715 and parameters: {'lr_g': 1.0050316972533074e-05, 'lr_d': 0.0006245333155815504, 'epochs': 127, 'batch_size': 43, 'latent_dim': 77}. Best is trial 81 with value: 8.95373768515085.
# fit took 28.773906 seconds
# [I 2025-04-17 06:19:55,516] Trial 92 finished with value: 24.69318052343766 and parameters: {'lr_g': 0.0002493065513609742, 'lr_d': 0.0008897821778021459, 'epochs': 138, 'batch_size': 31, 'latent_dim': 85}. Best is trial 81 with value: 8.95373768515085.
# fit took 30.686272 seconds
# [I 2025-04-17 06:20:26,802] Trial 93 finished with value: 14.62701986713682 and parameters: {'lr_g': 0.00011828111416435707, 'lr_d': 0.0007222092439602113, 'epochs': 147, 'batch_size': 15, 'latent_dim': 102}. Best is trial 81 with value: 8.95373768515085.
# fit took 29.140992 seconds
# [I 2025-04-17 06:20:56,575] Trial 94 finished with value: 190.81564289915005 and parameters: {'lr_g': 0.00024812699128901874, 'lr_d': 0.0026973386715007596, 'epochs': 142, 'batch_size': 59, 'latent_dim': 61}. Best is trial 81 with value: 8.95373768515085.
# fit took 24.318070 seconds
# [I 2025-04-17 06:21:21,539] Trial 95 finished with value: 27.184486737377163 and parameters: {'lr_g': 0.0005306322123122748, 'lr_d': 0.0004241056897331442, 'epochs': 118, 'batch_size': 41, 'latent_dim': 53}. Best is trial 81 with value: 8.95373768515085.
# fit took 30.794890 seconds
# [I 2025-04-17 06:21:52,993] Trial 96 finished with value: 11.868278031328298 and parameters: {'lr_g': 9.993804779316742e-05, 'lr_d': 0.0006255529785927044, 'epochs': 150, 'batch_size': 29, 'latent_dim': 71}. Best is trial 81 with value: 8.95373768515085.
# fit took 29.765676 seconds
# [I 2025-04-17 06:22:23,418] Trial 97 finished with value: 22.315805213008947 and parameters: {'lr_g': 0.00037954562242634333, 'lr_d': 0.0002009317601679857, 'epochs': 144, 'batch_size': 29, 'latent_dim': 69}. Best is trial 81 with value: 8.95373768515085.
# fit took 30.514539 seconds
# [I 2025-04-17 06:22:54,531] Trial 98 finished with value: 19.08867997886014 and parameters: {'lr_g': 0.00012029253890516394, 'lr_d': 0.0005693266167599943, 'epochs': 148, 'batch_size': 21, 'latent_dim': 57}. Best is trial 81 with value: 8.95373768515085.
# fit took 31.177734 seconds
# [I 2025-04-17 06:23:26,357] Trial 99 finished with value: 15.123733704541767 and parameters: {'lr_g': 0.00025572826470086267, 'lr_d': 0.0014879897875572418, 'epochs': 150, 'batch_size': 13, 'latent_dim': 64}. Best is trial 81 with value: 8.95373768515085.

# %%
print(model.parameters)
# Out:
# {'lr_g': 2.667582824453984e-05, 'lr_d': 0.0009322735135453107, 'epochs': 143, 'batch_size': 8, 'latent_dim': 74}

# %%
model.fit(verbose = True)
# Out:
# Epoch [1/143], C Loss: 1.3097, G Loss: 3.0901,
# Epoch [2/143], C Loss: 2.3588, G Loss: 1.4757,
# Epoch [3/143], C Loss: 0.7003, G Loss: 1.3468,
# Epoch [4/143], C Loss: 1.0725, G Loss: 1.0160,
# Epoch [5/143], C Loss: 1.0737, G Loss: 0.8569,
# Epoch [6/143], C Loss: 1.3207, G Loss: 0.2640,
# Epoch [7/143], C Loss: 0.9447, G Loss: 1.0531,
# Epoch [8/143], C Loss: 0.9894, G Loss: 0.6418,
# Epoch [9/143], C Loss: 0.9658, G Loss: 0.8515,
# Epoch [10/143], C Loss: 0.9327, G Loss: 0.7727,
# Epoch [11/143], C Loss: 1.1362, G Loss: 0.5650,
# Epoch [12/143], C Loss: 1.1429, G Loss: 0.9110,
# Epoch [13/143], C Loss: 1.0255, G Loss: 0.7484,
# Epoch [14/143], C Loss: 1.0239, G Loss: 0.7986,
# Epoch [15/143], C Loss: 1.1037, G Loss: 0.6838,
# Epoch [16/143], C Loss: 1.1131, G Loss: 1.0878,
# Epoch [17/143], C Loss: 1.1177, G Loss: 1.0561,
# Epoch [18/143], C Loss: 1.1708, G Loss: 1.2918,
# Epoch [19/143], C Loss: 1.2337, G Loss: 0.8555,
# Epoch [20/143], C Loss: 1.3896, G Loss: 2.0767,
# Epoch [21/143], C Loss: 1.2955, G Loss: 0.7919,
# Epoch [22/143], C Loss: 1.1768, G Loss: 0.7389,
# Epoch [23/143], C Loss: 1.1465, G Loss: 1.5588,
# Epoch [24/143], C Loss: 1.3418, G Loss: 0.9075,
# Epoch [25/143], C Loss: 1.1509, G Loss: 0.8140,
# Epoch [26/143], C Loss: 1.3386, G Loss: 0.9896,
# Epoch [27/143], C Loss: 1.3506, G Loss: 0.6180,
# Epoch [28/143], C Loss: 1.4374, G Loss: 0.8619,
# Epoch [29/143], C Loss: 1.2624, G Loss: 0.8134,
# Epoch [30/143], C Loss: 1.3255, G Loss: 0.7981,
# Epoch [31/143], C Loss: 1.3818, G Loss: 0.7879,
# Epoch [32/143], C Loss: 1.4356, G Loss: 0.8747,
# Epoch [33/143], C Loss: 1.3067, G Loss: 0.7713,
# Epoch [34/143], C Loss: 1.4775, G Loss: 0.8209,
# Epoch [35/143], C Loss: 1.3845, G Loss: 0.7011,
# Epoch [36/143], C Loss: 1.3300, G Loss: 0.7267,
# Epoch [37/143], C Loss: 1.3090, G Loss: 0.7802,
# Epoch [38/143], C Loss: 1.4116, G Loss: 0.8003,
# Epoch [39/143], C Loss: 1.3480, G Loss: 0.9025,
# Epoch [40/143], C Loss: 1.3273, G Loss: 0.7645,
# Epoch [41/143], C Loss: 1.3779, G Loss: 0.7466,
# Epoch [42/143], C Loss: 1.4221, G Loss: 0.7447,
# Epoch [43/143], C Loss: 1.3683, G Loss: 0.7392,
# Epoch [44/143], C Loss: 1.4794, G Loss: 0.7988,
# Epoch [45/143], C Loss: 1.3751, G Loss: 0.6658,
# Epoch [46/143], C Loss: 1.3989, G Loss: 0.7428,
# Epoch [47/143], C Loss: 1.3782, G Loss: 0.7441,
# Epoch [48/143], C Loss: 1.4388, G Loss: 0.9087,
# Epoch [49/143], C Loss: 1.3280, G Loss: 0.6346,
# Epoch [50/143], C Loss: 1.3636, G Loss: 0.7638,
# Epoch [51/143], C Loss: 1.3400, G Loss: 0.7454,
# Epoch [52/143], C Loss: 1.3596, G Loss: 0.6675,
# Epoch [53/143], C Loss: 1.3474, G Loss: 1.0289,
# Epoch [54/143], C Loss: 1.3855, G Loss: 0.7135,
# Epoch [55/143], C Loss: 1.4527, G Loss: 0.7629,
# Epoch [56/143], C Loss: 1.3764, G Loss: 0.7434,
# Epoch [57/143], C Loss: 1.4151, G Loss: 0.6823,
# Epoch [58/143], C Loss: 1.4061, G Loss: 0.6502,
# Epoch [59/143], C Loss: 1.4194, G Loss: 0.6238,
# Epoch [60/143], C Loss: 1.3845, G Loss: 0.7165,
# Epoch [61/143], C Loss: 1.3581, G Loss: 0.7017,
# Epoch [62/143], C Loss: 1.3548, G Loss: 0.7550,
# Epoch [63/143], C Loss: 1.4208, G Loss: 0.8327,
# Epoch [64/143], C Loss: 1.3544, G Loss: 0.7686,
# Epoch [65/143], C Loss: 1.3980, G Loss: 0.7040,
# Epoch [66/143], C Loss: 1.3714, G Loss: 0.7027,
# Epoch [67/143], C Loss: 1.3452, G Loss: 0.7212,
# Epoch [68/143], C Loss: 1.3463, G Loss: 0.6597,
# Epoch [69/143], C Loss: 1.3587, G Loss: 0.6690,
# Epoch [70/143], C Loss: 1.4006, G Loss: 0.5341,
# Epoch [71/143], C Loss: 1.3673, G Loss: 0.6742,
# Epoch [72/143], C Loss: 1.3463, G Loss: 0.7125,
# Epoch [73/143], C Loss: 1.3612, G Loss: 0.7166,
# Epoch [74/143], C Loss: 1.3868, G Loss: 0.7133,
# Epoch [75/143], C Loss: 1.3488, G Loss: 0.7019,
# Epoch [76/143], C Loss: 1.2963, G Loss: 0.7101,
# Epoch [77/143], C Loss: 1.3732, G Loss: 0.6964,
# Epoch [78/143], C Loss: 1.3249, G Loss: 0.7308,
# Epoch [79/143], C Loss: 1.3345, G Loss: 0.7515,
# Epoch [80/143], C Loss: 1.3437, G Loss: 0.6903,
# Epoch [81/143], C Loss: 1.3793, G Loss: 0.7454,
# Epoch [82/143], C Loss: 1.3807, G Loss: 0.6382,
# Epoch [83/143], C Loss: 1.4003, G Loss: 0.8390,
# Epoch [84/143], C Loss: 1.4207, G Loss: 0.8678,
# Epoch [85/143], C Loss: 1.3922, G Loss: 0.6988,
# Epoch [86/143], C Loss: 1.4072, G Loss: 0.6515,
# Epoch [87/143], C Loss: 1.3619, G Loss: 0.8631,
# Epoch [88/143], C Loss: 1.3733, G Loss: 0.7076,
# Epoch [89/143], C Loss: 1.3923, G Loss: 0.6767,
# Epoch [90/143], C Loss: 1.3889, G Loss: 0.7459,
# Epoch [91/143], C Loss: 1.3580, G Loss: 0.7548,
# Epoch [92/143], C Loss: 1.3809, G Loss: 0.8017,
# Epoch [93/143], C Loss: 1.3071, G Loss: 0.6836,
# Epoch [94/143], C Loss: 1.3537, G Loss: 0.7141,
# Epoch [95/143], C Loss: 1.3944, G Loss: 0.7125,
# Epoch [96/143], C Loss: 1.4124, G Loss: 0.7134,
# Epoch [97/143], C Loss: 1.4278, G Loss: 0.6984,
# Epoch [98/143], C Loss: 1.4270, G Loss: 0.6401,
# Epoch [99/143], C Loss: 1.3691, G Loss: 0.7449,
# Epoch [100/143], C Loss: 1.4222, G Loss: 0.7076,
# Epoch [101/143], C Loss: 1.3794, G Loss: 0.7072,
# Epoch [102/143], C Loss: 1.3874, G Loss: 0.6652,
# Epoch [103/143], C Loss: 1.3771, G Loss: 0.7525,
# Epoch [104/143], C Loss: 1.3652, G Loss: 0.6364,
# Epoch [105/143], C Loss: 1.4021, G Loss: 0.6793,
# Epoch [106/143], C Loss: 1.3633, G Loss: 0.6878,
# Epoch [107/143], C Loss: 1.3531, G Loss: 0.8009,
# Epoch [108/143], C Loss: 1.3919, G Loss: 0.7453,
# Epoch [109/143], C Loss: 1.3727, G Loss: 0.7253,
# Epoch [110/143], C Loss: 1.3567, G Loss: 0.6892,
# Epoch [111/143], C Loss: 1.3623, G Loss: 0.6308,
# Epoch [112/143], C Loss: 1.3820, G Loss: 0.6830,
# Epoch [113/143], C Loss: 1.4076, G Loss: 0.6857,
# Epoch [114/143], C Loss: 1.3707, G Loss: 0.7820,
# Epoch [115/143], C Loss: 1.3923, G Loss: 0.7535,
# Epoch [116/143], C Loss: 1.3883, G Loss: 0.6552,
# Epoch [117/143], C Loss: 1.3814, G Loss: 0.7193,
# Epoch [118/143], C Loss: 1.3854, G Loss: 0.6844,
# Epoch [119/143], C Loss: 1.3835, G Loss: 0.8366,
# Epoch [120/143], C Loss: 1.3939, G Loss: 0.7016,
# Epoch [121/143], C Loss: 1.3698, G Loss: 0.7669,
# Epoch [122/143], C Loss: 1.3611, G Loss: 0.7038,
# Epoch [123/143], C Loss: 1.3821, G Loss: 0.7617,
# Epoch [124/143], C Loss: 1.3874, G Loss: 0.6308,
# Epoch [125/143], C Loss: 1.3700, G Loss: 0.6990,
# Epoch [126/143], C Loss: 1.4053, G Loss: 0.7104,
# Epoch [127/143], C Loss: 1.3948, G Loss: 0.6099,
# Epoch [128/143], C Loss: 1.3768, G Loss: 0.7649,
# Epoch [129/143], C Loss: 1.4006, G Loss: 0.6836,
# Epoch [130/143], C Loss: 1.5154, G Loss: 0.6439,
# Epoch [131/143], C Loss: 1.3783, G Loss: 0.6824,
# Epoch [132/143], C Loss: 1.3773, G Loss: 0.6555,
# Epoch [133/143], C Loss: 1.3827, G Loss: 0.7641,
# Epoch [134/143], C Loss: 1.3783, G Loss: 0.7328,
# Epoch [135/143], C Loss: 1.3533, G Loss: 0.6245,
# Epoch [136/143], C Loss: 1.4169, G Loss: 0.7866,
# Epoch [137/143], C Loss: 1.3899, G Loss: 0.6316,
# Epoch [138/143], C Loss: 1.3823, G Loss: 0.6934,
# Epoch [139/143], C Loss: 1.3945, G Loss: 0.5946,
# Epoch [140/143], C Loss: 1.3758, G Loss: 0.7181,
# Epoch [141/143], C Loss: 1.4187, G Loss: 0.5664,
# Epoch [142/143], C Loss: 1.3856, G Loss: 0.7302,
# Epoch [143/143], C Loss: 1.3689, G Loss: 0.6627,
# fit took 32.834259 seconds
# {}

# %%
n = 30

w = [model.compute_val_metric(dWasserstein, {}) for _ in range(n)]
f = [model.compute_val_metric(dFrechet, {}) for _ in range(n)]
o = [model.compute_val_metric(ONND, {}) for _ in range(n)]
s = [model.compute_val_metric(score, {}) for _ in range(n)]

print("Wasserstein", sum(w)/n)
print("Fréchet", sum(f)/n)
print("ONND", sum(o)/n)
print("Score", sum(s)/n)
# Out:
# Wasserstein 0.2758529412107143
# Fréchet 6.066563122648239
# ONND 1.083012926730136
# Score 11.499391861628292

# %%
import matplotlib.pyplot as plt
plt.plot([30*x for x in w], label = "Wassertein")
plt.plot([x for x in f], label = "Fréchet")
plt.plot([np.power(len(model.train_data), 0.27)*x for x in o], label = "ONND")
plt.plot([x for x in s], label = "Score")
plt.legend()
