# %%
from time_series_gan.GAN import GAN
import numpy as np
import pandas as pd
from time_series_gan.metrics import dWasserstein, dFrechet, ONND, score
from Optimisation_MH import generer_resultats, Metropolis_Hasting

# %%
data = pd.read_csv("data/data_gdp.csv")
archi = Metropolis_Hasting(0.1, data, GAN, ite = 1000, metrique=score, nom_de_la_métrique = "score")
# Out:
# fit took 0.586327 seconds
# MH étape : 0
# suppression d'une couche du discriminator
# fit took 0.747382 seconds
# succes
# 24.973662547339657 ->  17.617417960876477
#
# {'lr_g': 0.001, 'lr_d': 0.001, 'epochs': 100, 'batch_size': 32, 'latent_dim': 20}
# generator : [1]        ReLU
# discriminator : [23, 1]        ReLU
#
#
# MH étape : 1
# modification des paramètres
# fit took 0.371886 seconds
# succes
# 17.617417960876477 ->  13.262662690460113
#
# {'lr_g': 0.002575, 'lr_d': 0.002527, 'epochs': 37, 'batch_size': 31, 'latent_dim': 17}
# generator : [1]        ReLU
# discriminator : [23, 1]        ReLU
#
#
# MH étape : 2
# suppression d'une couche du generator
# fit took 0.449001 seconds
# echec
#
#
# MH étape : 3
# modification des paramètres
# fit took 0.563001 seconds
# echec
#
#
# MH étape : 4
# modification des paramètres
# fit took 0.572494 seconds
# echec
#
#
# MH étape : 5
# ajout d'une couche au generator
# fit took 0.490801 seconds
# echec
#
#
# MH étape : 6
# modification des paramètres
# fit took 0.532989 seconds
# echec
#
#
# MH étape : 7
# suppression d'une couche du generator
# fit took 0.376850 seconds
# echec
#
#
# MH étape : 8
# modification des paramètres
# fit took 0.387554 seconds
# echec
#
#
# MH étape : 9
# modification de la fonction d'activation du generator
# fit took 0.418849 seconds
# echec
#
#
# MH étape : 10
# modification des paramètres
# fit took 0.529144 seconds
# echec
#
#
# MH étape : 11
# suppression d'une couche du discriminator
# fit took 0.315759 seconds
# echec
#
#
# MH étape : 12
# modification des paramètres
# fit took 0.248344 seconds
# echec
#
#
# MH étape : 13
# modification des paramètres
# fit took 0.281920 seconds
# echec
#
#
# MH étape : 14
# suppression d'une couche du discriminator
# fit took 0.318957 seconds
# echec
#
#
# MH étape : 15
# ajout d'une couche au discriminator
# fit took 0.447889 seconds
# echec
#
#
# MH étape : 16
# ajout d'une couche au discriminator
# fit took 0.398136 seconds
# echec
#
#
# MH étape : 17
# modification de la fonction d'activation du discriminator
# fit took 0.333899 seconds
# echec
#
#
# MH étape : 18
# suppression d'une couche du discriminator
# fit took 0.306413 seconds
# echec
#
#
# MH étape : 19
# modification des paramètres
# fit took 0.493427 seconds
# echec
#
#
# MH étape : 20
# suppression d'une couche du generator
# fit took 0.464900 seconds
# echec
#
#
# MH étape : 21
# suppression d'une couche du discriminator
# fit took 0.363577 seconds
# echec
#
#
# MH étape : 22
# modification des paramètres
# fit took 0.359371 seconds
# echec
#
#
# MH étape : 23
# suppression d'une couche du discriminator
# fit took 0.339945 seconds
# echec
#
#
# MH étape : 24
# ajout d'une couche au discriminator
# fit took 0.407981 seconds
# echec
#
#
# MH étape : 25
# modification des paramètres
# fit took 0.346563 seconds
# echec
#
#
# MH étape : 26
# suppression d'une couche du discriminator
# fit took 0.368706 seconds
# echec
#
#
# MH étape : 27
# ajout d'une couche au generator
# fit took 0.424550 seconds
# echec
#
#
# MH étape : 28
# ajout d'une couche au discriminator
# fit took 0.388512 seconds
# echec
#
#
# MH étape : 29
# modification des paramètres
# fit took 0.264199 seconds
# echec
#
#
# MH étape : 30
# modification des paramètres
# fit took 0.252808 seconds
# echec
#
#
# MH étape : 31
# modification des paramètres
# fit took 0.311692 seconds
# echec
#
#
# MH étape : 32
# suppression d'une couche du generator
# fit took 0.368707 seconds
# echec
#
#
# MH étape : 33
# ajout d'une couche au generator
# fit took 0.420579 seconds
# echec
#
#
# MH étape : 34
# modification des paramètres
# fit took 0.313838 seconds
# echec
#
#
# MH étape : 35
# modification des paramètres
# fit took 0.432253 seconds
# echec
#
#
# MH étape : 36
# suppression d'une couche du generator
# fit took 0.664929 seconds
# echec
#
#
# MH étape : 37
# ajout d'une couche au discriminator
# fit took 0.895958 seconds
# succes
# 13.262662690460113 ->  8.969969879676983
#
# {'lr_g': 0.002575, 'lr_d': 0.002527, 'epochs': 37, 'batch_size': 31, 'latent_dim': 17}
# generator : [1]        ReLU
# discriminator : [39, 23, 1]        ReLU
#
#
# MH étape : 38
# ajout d'une couche au discriminator
# fit took 0.765305 seconds
# echec
#
#
# MH étape : 39
# modification des paramètres
# fit took 0.778861 seconds
# echec
#
#
# MH étape : 40
# suppression d'une couche du generator
# fit took 0.875722 seconds
# echec
#
#
# MH étape : 41
# modification des paramètres
# fit took 0.541600 seconds
# echec
#
#
# MH étape : 42
# suppression d'une couche du discriminator
# fit took 0.792652 seconds
# echec
#
#
# MH étape : 43
# suppression d'une couche du discriminator
# fit took 0.635366 seconds
# echec
#
#
# MH étape : 44
# suppression d'une couche du generator
# fit took 0.842126 seconds
# echec
#
#
# MH étape : 45
# modification des paramètres
# fit took 1.437395 seconds
# echec
#
#
# MH étape : 46
# suppression d'une couche du generator
# fit took 0.965080 seconds
# echec
#
#
# MH étape : 47
# modification des paramètres
# fit took 0.668977 seconds
# echec
#
#
# MH étape : 48
# suppression d'une couche du generator
# fit took 0.883250 seconds
# echec
#
#
# MH étape : 49
# modification des paramètres
# fit took 0.862437 seconds
# echec
#
#
# MH étape : 50
# ajout d'une couche au discriminator
# fit took 0.779641 seconds
# echec
#
#
# MH étape : 51
# suppression d'une couche du generator
# fit took 0.716016 seconds
# echec
#
#
# MH étape : 52
# ajout d'une couche au discriminator
# fit took 0.681579 seconds
# echec
#
#
# MH étape : 53
# modification des paramètres
# fit took 0.523773 seconds
# echec
#
#
# MH étape : 54
# suppression d'une couche du generator
# fit took 0.695609 seconds
# echec
#
#
# MH étape : 55
# modification des paramètres
# fit took 0.570973 seconds
# echec
#
#
# MH étape : 56
# suppression d'une couche du discriminator
# fit took 0.734907 seconds
# echec
#
#
# MH étape : 57
# suppression d'une couche du generator
# fit took 0.868108 seconds
# echec
#
#
# MH étape : 58
# ajout d'une couche au generator
# fit took 0.683935 seconds
# echec
#
#
# MH étape : 59
# suppression d'une couche du generator
# fit took 0.827188 seconds
# echec
#
#
# MH étape : 60
# modification des paramètres
# fit took 0.869425 seconds
# echec
#
#
# MH étape : 61
# ajout d'une couche au generator
# fit took 0.759071 seconds
# echec
#
#
# MH étape : 62
# suppression d'une couche du discriminator
# fit took 0.694044 seconds
# echec
#
#
# MH étape : 63
# modification des paramètres
# fit took 1.068228 seconds
# echec
#
#
# MH étape : 64
# modification de la fonction d'activation du discriminator
# fit took 0.867870 seconds
# echec
#
#
# MH étape : 65
# modification des paramètres
# fit took 0.509413 seconds
# echec
#
#
# MH étape : 66
# suppression d'une couche du generator
# fit took 0.793915 seconds
# echec
#
#
# MH étape : 67
# modification des paramètres
# fit took 0.605415 seconds
# echec
#
#
# MH étape : 68
# ajout d'une couche au generator
# fit took 0.734515 seconds
# echec
#
#
# MH étape : 69
# modification des paramètres
# fit took 0.769803 seconds
# echec
#
#
# MH étape : 70
# modification des paramètres
# fit took 0.785507 seconds
# echec
#
#
# MH étape : 71
# modification des paramètres
# fit took 0.627892 seconds
# echec
#
#
# MH étape : 72
# modification de la fonction d'activation du generator
# fit took 0.811255 seconds
# echec
#
#
# MH étape : 73
# ajout d'une couche au generator
# fit took 0.968237 seconds
# echec
#
#
# MH étape : 74
# modification des paramètres
# fit took 0.569334 seconds
# echec
#
#
# MH étape : 75
# suppression d'une couche du generator
# fit took 0.872577 seconds
# echec
#
#
# MH étape : 76
# modification des paramètres
# fit took 0.725092 seconds
# echec
#
#
# MH étape : 77
# modification des paramètres
# fit took 1.455770 seconds
# echec
#
#
# MH étape : 78
# modification des paramètres
# fit took 0.665974 seconds
# echec
#
#
# MH étape : 79
# modification des paramètres
# fit took 0.957197 seconds
# echec
#
#
# MH étape : 80
# suppression d'une couche du generator
# fit took 0.894465 seconds
# echec
#
#
# MH étape : 81
# modification des paramètres
# fit took 0.618986 seconds
# echec
#
#
# MH étape : 82
# suppression d'une couche du discriminator
# fit took 0.733333 seconds
# echec
#
#
# MH étape : 83
# ajout d'une couche au discriminator
# fit took 0.762399 seconds
# echec
#
#
# MH étape : 84
# suppression d'une couche du generator
# fit took 0.858304 seconds
# echec
#
#
# MH étape : 85
# suppression d'une couche du generator
# fit took 0.795357 seconds
# echec
#
#
# MH étape : 86
# modification des paramètres
# fit took 0.612306 seconds
# echec
#
#
# MH étape : 87
# modification des paramètres
# fit took 0.844132 seconds
# echec
#
#
# MH étape : 88
# modification des paramètres
# fit took 0.605931 seconds
# echec
#
#
# MH étape : 89
# modification des paramètres
# fit took 1.201530 seconds
# echec
#
#
# MH étape : 90
# modification des paramètres
# fit took 1.022707 seconds
# echec
#
#
# MH étape : 91
# modification des paramètres
# fit took 1.278266 seconds
# echec
#
#
# MH étape : 92
# ajout d'une couche au generator
# fit took 0.762537 seconds
# echec
#
#
# MH étape : 93
# ajout d'une couche au generator
# fit took 0.815411 seconds
# echec
#
#
# MH étape : 94
# modification de la fonction d'activation du generator
# fit took 0.734055 seconds
# echec
#
#
# MH étape : 95
# modification des paramètres
# fit took 1.337755 seconds
# echec
#
#
# MH étape : 96
# ajout d'une couche au discriminator
# fit took 0.943906 seconds
# echec
#
#
# MH étape : 97
# suppression d'une couche du discriminator
# fit took 0.665032 seconds
# echec
#
#
# MH étape : 98
# modification des paramètres
# fit took 1.127876 seconds
# echec
#
#
# MH étape : 99
# suppression d'une couche du generator
# fit took 0.747685 seconds
# echec
#
#
# MH étape : 100
# suppression d'une couche du discriminator
# fit took 0.700051 seconds
# echec
#
#
# MH étape : 101
# suppression d'une couche du discriminator
# fit took 0.618716 seconds
# echec
#
#
# MH étape : 102
# modification des paramètres
# fit took 1.095159 seconds
# echec
#
#
# MH étape : 103
# suppression d'une couche du discriminator
# fit took 0.791238 seconds
# echec
#
#
# MH étape : 104
# modification de la fonction d'activation du generator
# fit took 0.732712 seconds
# echec
#
#
# MH étape : 105
# modification des paramètres
# fit took 0.413016 seconds
# echec
#
#
# MH étape : 106
# modification des paramètres
# fit took 0.829344 seconds
# echec
#
#
# MH étape : 107
# ajout d'une couche au generator
# fit took 0.856825 seconds
# echec
#
#
# MH étape : 108
# ajout d'une couche au generator
# fit took 0.699951 seconds
# echec
#
#
# MH étape : 109
# modification des paramètres
# fit took 0.604887 seconds
# echec
#
#
# MH étape : 110
# modification des paramètres
# fit took 0.694388 seconds
# echec
#
#
# MH étape : 111
# modification des paramètres
# fit took 0.558256 seconds
# echec
#
#
# MH étape : 112
# modification des paramètres
# fit took 1.176615 seconds
# echec
#
#
# MH étape : 113
# ajout d'une couche au discriminator
# fit took 0.696860 seconds
# echec
#
#
# MH étape : 114
# modification des paramètres
# fit took 0.764329 seconds
# echec
#
#
# MH étape : 115
# suppression d'une couche du generator
# fit took 0.817642 seconds
# echec
#
#
# MH étape : 116
# modification des paramètres
# fit took 0.568372 seconds
# echec
#
#
# MH étape : 117
# modification des paramètres
# fit took 0.660803 seconds
# echec
#
#
# MH étape : 118
# modification de la fonction d'activation du generator
# fit took 0.996732 seconds
# echec
#
#
# MH étape : 119
# modification de la fonction d'activation du discriminator
# fit took 0.806833 seconds
# echec
#
#
# MH étape : 120
# modification des paramètres
# fit took 1.033750 seconds
# echec
#
#
# MH étape : 121
# modification des paramètres
# fit took 1.234520 seconds
# echec
#
#
# MH étape : 122
# suppression d'une couche du generator
# fit took 0.922162 seconds
# echec
#
#
# MH étape : 123
# modification des paramètres
# fit took 0.675122 seconds
# echec
#
#
# MH étape : 124
# modification des paramètres
# fit took 0.716408 seconds
# echec
#
#
# MH étape : 125
# suppression d'une couche du generator
# fit took 0.989131 seconds
# echec
#
#
# MH étape : 126
# suppression d'une couche du generator
# fit took 0.949538 seconds
# echec
#
#
# MH étape : 127
# suppression d'une couche du generator
# fit took 1.238507 seconds
# echec
#
#
# MH étape : 128
# suppression d'une couche du discriminator
# fit took 0.953747 seconds
# echec
#
#
# MH étape : 129
# suppression d'une couche du generator
# fit took 0.770985 seconds
# echec
#
#
# MH étape : 130
# suppression d'une couche du discriminator
# fit took 0.938211 seconds
# echec
#
#
# MH étape : 131
# suppression d'une couche du discriminator
# fit took 0.582816 seconds
# echec
#
#
# MH étape : 132
# modification des paramètres
# fit took 0.983509 seconds
# echec
#
#
# MH étape : 133
# suppression d'une couche du generator
# fit took 0.506491 seconds
# echec
#
#
# MH étape : 134
# modification des paramètres
# fit took 0.571844 seconds
# echec
#
#
# MH étape : 135
# modification des paramètres
# fit took 0.439159 seconds
# echec
#
#
# MH étape : 136
# suppression d'une couche du discriminator
# fit took 0.386518 seconds
# echec
#
#
# MH étape : 137
# modification des paramètres
# fit took 0.333704 seconds
# echec
#
#
# MH étape : 138
# ajout d'une couche au generator
# fit took 0.550547 seconds
# echec
#
#
# MH étape : 139
# ajout d'une couche au discriminator
# fit took 0.496147 seconds
# echec
#
#
# MH étape : 140
# modification des paramètres
# fit took 0.497577 seconds
# echec
#
#
# MH étape : 141
# suppression d'une couche du generator
# fit took 0.472362 seconds
# echec
#
#
# MH étape : 142
# ajout d'une couche au discriminator
# fit took 0.489776 seconds
# echec
#
#
# MH étape : 143
# modification des paramètres
# fit took 0.426489 seconds
# echec
#
#
# MH étape : 144
# ajout d'une couche au generator
# fit took 0.407988 seconds
# echec
#
#
# MH étape : 145
# modification des paramètres
# fit took 0.515239 seconds
# echec
#
#
# MH étape : 146
# suppression d'une couche du generator
# fit took 0.481835 seconds
# echec
#
#
# MH étape : 147
# modification des paramètres
# fit took 0.597726 seconds
# echec
#
#
# MH étape : 148
# suppression d'une couche du discriminator
# fit took 0.447139 seconds
# echec
#
#
# MH étape : 149
# suppression d'une couche du generator
# fit took 0.425086 seconds
# echec
#
#
# MH étape : 150
# modification des paramètres
# fit took 0.576269 seconds
# echec
#
#
# MH étape : 151
# modification des paramètres
# fit took 0.561788 seconds
# echec
#
#
# MH étape : 152
# ajout d'une couche au generator
# fit took 0.590308 seconds
# echec
#
#
# MH étape : 153
# suppression d'une couche du discriminator
# fit took 0.441547 seconds
# echec
#
#
# MH étape : 154
# modification des paramètres
# fit took 1.755451 seconds
# echec
#
#
# MH étape : 155
# modification des paramètres
# fit took 2.094918 seconds
# echec
#
#
# MH étape : 156
# suppression d'une couche du discriminator
# fit took 0.905071 seconds
# echec
#
#
# MH étape : 157
# suppression d'une couche du discriminator
# fit took 0.988347 seconds
# echec
#
#
# MH étape : 158
# suppression d'une couche du generator
# fit took 0.932822 seconds
# echec
#
#
# MH étape : 159
# modification des paramètres
# fit took 0.714782 seconds
# echec
#
#
# MH étape : 160
# modification des paramètres
# fit took 1.200181 seconds
# echec
#
#
# MH étape : 161
# modification des paramètres
# fit took 1.199353 seconds
# echec
#
#
# MH étape : 162
# suppression d'une couche du generator
# fit took 0.802812 seconds
# echec
#
#
# MH étape : 163
# suppression d'une couche du discriminator
# fit took 0.797110 seconds
# echec
#
#
# MH étape : 164
# modification des paramètres
# fit took 0.888164 seconds
# echec
#
#
# MH étape : 165
# modification des paramètres
# fit took 1.424832 seconds
# echec
#
#
# MH étape : 166
# modification des paramètres
# fit took 0.980430 seconds
# echec
#
#
# MH étape : 167
# modification des paramètres
# fit took 0.969675 seconds
# echec
#
#
# MH étape : 168
# modification des paramètres
# fit took 0.690788 seconds
# echec
#
#
# MH étape : 169
# suppression d'une couche du discriminator
# fit took 0.781327 seconds
# echec
#
#
# MH étape : 170
# modification des paramètres
# fit took 0.791710 seconds
# echec
#
#
# MH étape : 171
# suppression d'une couche du discriminator
# fit took 0.843134 seconds
# echec
#
#
# MH étape : 172
# modification des paramètres
# fit took 0.938150 seconds
# echec
#
#
# MH étape : 173
# modification des paramètres
# fit took 0.889417 seconds
# echec
#
#
# MH étape : 174
# suppression d'une couche du generator
# fit took 0.733140 seconds
# echec
#
#
# MH étape : 175
# suppression d'une couche du generator
# fit took 0.744698 seconds
# echec
#
#
# MH étape : 176
# modification des paramètres
# fit took 1.049639 seconds
# echec
#
#
# MH étape : 177
# modification des paramètres
# fit took 0.733506 seconds
# echec
#
#
# MH étape : 178
# modification des paramètres
# fit took 1.202181 seconds
# echec
#
#
# MH étape : 179
# modification de la fonction d'activation du generator
# fit took 0.763166 seconds
# echec
#
#
# MH étape : 180
# modification des paramètres
# fit took 0.712951 seconds
# echec
#
#
# MH étape : 181
# suppression d'une couche du discriminator
# fit took 0.889580 seconds
# echec
#
#
# MH étape : 182
# modification des paramètres
# fit took 0.588690 seconds
# echec
#
#
# MH étape : 183
# modification des paramètres
# fit took 0.968464 seconds
# echec
#
#
# MH étape : 184
# modification des paramètres
# fit took 0.868819 seconds
# echec
#
#
# MH étape : 185
# modification des paramètres
# fit took 1.505239 seconds
# echec
#
#
# MH étape : 186
# modification des paramètres
# fit took 0.709052 seconds
# echec
#
#
# MH étape : 187
# suppression d'une couche du discriminator
# fit took 0.925379 seconds
# echec
#
#
# MH étape : 188
# suppression d'une couche du generator
# fit took 0.997699 seconds
# echec
#
#
# MH étape : 189
# ajout d'une couche au generator
# fit took 0.983962 seconds
# echec
#
#
# MH étape : 190
# modification des paramètres
# fit took 0.792721 seconds
# echec
#
#
# MH étape : 191
# modification des paramètres
# fit took 0.635814 seconds
# echec
#
#
# MH étape : 192
# modification des paramètres
# fit took 0.584832 seconds
# echec
#
#
# MH étape : 193
# ajout d'une couche au generator
# fit took 0.487984 seconds
# echec
#
#
# MH étape : 194
# modification des paramètres
# fit took 0.602015 seconds
# echec
#
#
# MH étape : 195
# ajout d'une couche au generator
# fit took 0.406940 seconds
# echec
#
#
# MH étape : 196
# suppression d'une couche du generator
# fit took 0.416250 seconds
# echec
#
#
# MH étape : 197
# suppression d'une couche du discriminator
# fit took 0.346762 seconds
# echec
#
#
# MH étape : 198
# modification des paramètres
# fit took 0.664355 seconds
# echec
#
#
# MH étape : 199
# ajout d'une couche au discriminator
# fit took 0.444110 seconds
# echec
#
#
# MH étape : 200
# ajout d'une couche au generator
# fit took 0.539505 seconds
# echec
#
#
# MH étape : 201
# ajout d'une couche au generator
# fit took 0.502273 seconds
# echec
#
#
# MH étape : 202
# suppression d'une couche du generator
# fit took 0.408510 seconds
# echec
#
#
# MH étape : 203
# suppression d'une couche du discriminator
# fit took 0.382956 seconds
# echec
#
#
# MH étape : 204
# ajout d'une couche au discriminator
# fit took 0.406092 seconds
# echec
#
#
# MH étape : 205
# modification des paramètres
# fit took 0.340229 seconds
# echec
#
#
# MH étape : 206
# modification des paramètres
# fit took 0.724801 seconds
# echec
#
#
# MH étape : 207
# modification des paramètres
# fit took 0.643577 seconds
# echec
#
#
# MH étape : 208
# suppression d'une couche du generator
# fit took 0.468801 seconds
# echec
#
#
# MH étape : 209
# ajout d'une couche au discriminator
# fit took 0.605290 seconds
# echec
#
#
# MH étape : 210
# modification des paramètres
# fit took 0.573457 seconds
# echec
#
#
# MH étape : 211
# modification des paramètres
# fit took 0.334368 seconds
# echec
#
#
# MH étape : 212
# modification des paramètres
# fit took 0.486098 seconds
# echec
#
#
# MH étape : 213
# modification des paramètres
# fit took 0.490994 seconds
# echec
#
#
# MH étape : 214
# modification des paramètres
# fit took 0.292072 seconds
# echec
#
#
# MH étape : 215
# ajout d'une couche au generator
# fit took 0.427397 seconds
# echec
#
#
# MH étape : 216
# ajout d'une couche au discriminator
# fit took 0.436958 seconds
# echec
#
#
# MH étape : 217
# ajout d'une couche au discriminator
# fit took 0.478987 seconds
# echec
#
#
# MH étape : 218
# ajout d'une couche au discriminator
# fit took 0.451684 seconds
# echec
#
#
# MH étape : 219
# suppression d'une couche du generator
# fit took 0.463701 seconds
# echec
#
#
# MH étape : 220
# suppression d'une couche du generator
# fit took 0.439344 seconds
# echec
#
#
# MH étape : 221
# modification des paramètres
# fit took 0.350737 seconds
# echec
#
#
# MH étape : 222
# modification des paramètres
# fit took 0.324273 seconds
# echec
#
#
# MH étape : 223
# ajout d'une couche au generator
# fit took 0.577580 seconds
# echec
#
#
# MH étape : 224
# suppression d'une couche du discriminator
# fit took 0.355463 seconds
# echec
#
#
# MH étape : 225
# modification des paramètres
# fit took 0.598668 seconds
# echec
#
#
# MH étape : 226
# modification des paramètres
# fit took 0.439652 seconds
# echec
#
#
# MH étape : 227
# suppression d'une couche du generator
# fit took 0.441803 seconds
# echec
#
#
# MH étape : 228
# modification des paramètres
# fit took 0.484866 seconds
# echec
#
#
# MH étape : 229
# suppression d'une couche du generator
# fit took 0.386387 seconds
# echec
#
#
# MH étape : 230
# modification des paramètres
# fit took 0.367226 seconds
# echec
#
#
# MH étape : 231
# modification des paramètres
# fit took 0.429759 seconds
# echec
#
#
# MH étape : 232
# suppression d'une couche du generator
# fit took 0.469783 seconds
# echec
#
#
# MH étape : 233
# modification des paramètres
# fit took 0.330455 seconds
# echec
#
#
# MH étape : 234
# modification des paramètres
# fit took 0.502569 seconds
# echec
#
#
# MH étape : 235
# modification des paramètres
# fit took 0.616731 seconds
# echec
#
#
# MH étape : 236
# suppression d'une couche du generator
# fit took 0.398180 seconds
# echec
#
#
# MH étape : 237
# modification des paramètres
# fit took 0.410981 seconds
# echec
#
#
# MH étape : 238
# modification des paramètres
# fit took 0.514266 seconds
# echec
#
#
# MH étape : 239
# modification des paramètres
# fit took 0.401254 seconds
# echec
#
#
# MH étape : 240
# ajout d'une couche au discriminator
# fit took 0.529391 seconds
# echec
#
#
# MH étape : 241
# modification des paramètres
# fit took 0.749293 seconds
# echec
#
#
# MH étape : 242
# suppression d'une couche du generator
# fit took 0.649944 seconds
# echec
#
#
# MH étape : 243
# suppression d'une couche du discriminator
# fit took 0.383173 seconds
# echec
#
#
# MH étape : 244
# modification des paramètres
# fit took 0.437897 seconds
# echec
#
#
# MH étape : 245
# modification des paramètres
# fit took 0.292956 seconds
# echec
#
#
# MH étape : 246
# modification des paramètres
# fit took 0.783870 seconds
# echec
#
#
# MH étape : 247
# modification des paramètres
# fit took 0.649732 seconds
# echec
#
#
# MH étape : 248
# modification des paramètres
# fit took 0.432692 seconds
# echec
#
#
# MH étape : 249
# suppression d'une couche du generator
# fit took 0.395131 seconds
# echec
#
#
# MH étape : 250
# suppression d'une couche du discriminator
# fit took 0.381155 seconds
# echec
#
#
# MH étape : 251
# modification des paramètres
# fit took 0.317694 seconds
# echec
#
#
# MH étape : 252
# modification des paramètres
# fit took 0.316940 seconds
# echec
#
#
# MH étape : 253
# suppression d'une couche du discriminator
# fit took 0.624430 seconds
# echec
#
#
# MH étape : 254
# modification des paramètres
# fit took 0.954190 seconds
# echec
#
#
# MH étape : 255
# suppression d'une couche du discriminator
# fit took 0.683074 seconds
# echec
#
#
# MH étape : 256
# ajout d'une couche au generator
# fit took 0.567751 seconds
# echec
#
#
# MH étape : 257
# suppression d'une couche du generator
# fit took 0.780425 seconds
# echec
#
#
# MH étape : 258
# modification des paramètres
# fit took 0.538388 seconds
# echec
#
#
# MH étape : 259
# suppression d'une couche du generator
# fit took 0.714634 seconds
# echec
#
#
# MH étape : 260
# modification des paramètres
# fit took 0.973183 seconds
# echec
#
#
# MH étape : 261
# modification des paramètres
# fit took 0.561646 seconds
# echec
#
#
# MH étape : 262
# suppression d'une couche du generator
# fit took 0.764266 seconds
# echec
#
#
# MH étape : 263
# modification des paramètres
# fit took 0.317166 seconds
# echec
#
#
# MH étape : 264
# modification des paramètres
# fit took 0.540626 seconds
# echec
#
#
# MH étape : 265
# modification de la fonction d'activation du generator
# fit took 0.634856 seconds
# echec
#
#
# MH étape : 266
# modification des paramètres
# fit took 0.796097 seconds
# echec
#
#
# MH étape : 267
# suppression d'une couche du generator
# fit took 0.782057 seconds
# echec
#
#
# MH étape : 268
# modification des paramètres
# fit took 0.632191 seconds
# echec
#
#
# MH étape : 269
# modification des paramètres
# fit took 0.907174 seconds
# echec
#
#
# MH étape : 270
# modification des paramètres
# fit took 0.878091 seconds
# echec
#
#
# MH étape : 271
# modification des paramètres
# fit took 0.698897 seconds
# echec
#
#
# MH étape : 272
# modification de la fonction d'activation du discriminator
# fit took 0.642937 seconds
# echec
#
#
# MH étape : 273
# suppression d'une couche du generator
# fit took 0.660951 seconds
# echec
#
#
# MH étape : 274
# suppression d'une couche du discriminator
# fit took 0.585708 seconds
# echec
#
#
# MH étape : 275
# suppression d'une couche du generator
# fit took 0.618812 seconds
# echec
#
#
# MH étape : 276
# modification des paramètres
# fit took 0.683809 seconds
# echec
#
#
# MH étape : 277
# modification des paramètres
# fit took 0.573153 seconds
# echec
#
#
# MH étape : 278
# modification des paramètres
# fit took 0.860422 seconds
# echec
#
#
# MH étape : 279
# suppression d'une couche du generator
# fit took 0.819911 seconds
# echec
#
#
# MH étape : 280
# ajout d'une couche au generator
# fit took 0.622413 seconds
# echec
#
#
# MH étape : 281
# modification de la fonction d'activation du generator
# fit took 0.746086 seconds
# echec
#
#
# MH étape : 282
# suppression d'une couche du generator
# fit took 0.557287 seconds
# echec
#
#
# MH étape : 283
# modification des paramètres
# fit took 0.431559 seconds
# echec
#
#
# MH étape : 284
# suppression d'une couche du discriminator
# fit took 0.711803 seconds
# echec
#
#
# MH étape : 285
# suppression d'une couche du generator
# fit took 0.604794 seconds
# echec
#
#
# MH étape : 286
# suppression d'une couche du generator
# fit took 0.784409 seconds
# echec
#
#
# MH étape : 287
# modification des paramètres
# fit took 0.835809 seconds
# echec
#
#
# MH étape : 288
# modification des paramètres
# fit took 0.752085 seconds
# echec
#
#
# MH étape : 289
# modification des paramètres
# fit took 0.551160 seconds
# echec
#
#
# MH étape : 290
# suppression d'une couche du discriminator
# fit took 0.554442 seconds
# echec
#
#
# MH étape : 291
# ajout d'une couche au discriminator
# fit took 0.747727 seconds
# echec
#
#
# MH étape : 292
# modification des paramètres
# fit took 0.729809 seconds
# echec
#
#
# MH étape : 293
# modification des paramètres
# fit took 0.686387 seconds
# echec
#
#
# MH étape : 294
# modification de la fonction d'activation du discriminator
# fit took 0.665591 seconds
# echec
#
#
# MH étape : 295
# suppression d'une couche du generator
# fit took 0.623295 seconds
# echec
#
#
# MH étape : 296
# ajout d'une couche au generator
# fit took 0.667077 seconds
# echec
#
#
# MH étape : 297
# suppression d'une couche du discriminator
# fit took 0.742883 seconds
# echec
#
#
# MH étape : 298
# modification des paramètres
# fit took 0.685377 seconds
# echec
#
#
# MH étape : 299
# modification des paramètres
# fit took 0.393021 seconds
# echec
#
#
# MH étape : 300
# modification des paramètres
# fit took 0.850836 seconds
# echec
#
#
# MH étape : 301
# ajout d'une couche au generator
# fit took 0.693845 seconds
# echec
#
#
# MH étape : 302
# suppression d'une couche du generator
# fit took 0.714287 seconds
# echec
#
#
# MH étape : 303
# modification des paramètres
# fit took 0.601491 seconds
# echec
#
#
# MH étape : 304
# suppression d'une couche du generator
# fit took 0.733738 seconds
# echec
#
#
# MH étape : 305
# modification des paramètres
# fit took 0.724376 seconds
# echec
#
#
# MH étape : 306
# suppression d'une couche du discriminator
# fit took 0.766268 seconds
# echec
#
#
# MH étape : 307
# ajout d'une couche au discriminator
# fit took 0.747747 seconds
# echec
#
#
# MH étape : 308
# suppression d'une couche du generator
# fit took 0.733572 seconds
# echec
#
#
# MH étape : 309
# modification des paramètres
# fit took 0.867964 seconds
# echec
#
#
# MH étape : 310
# modification des paramètres
# fit took 0.516932 seconds
# echec
#
#
# MH étape : 311
# suppression d'une couche du generator
# fit took 0.644313 seconds
# echec
#
#
# MH étape : 312
# modification des paramètres
# fit took 0.702273 seconds
# echec
#
#
# MH étape : 313
# suppression d'une couche du generator
# fit took 0.717147 seconds
# echec
#
#
# MH étape : 314
# ajout d'une couche au generator
# fit took 0.760875 seconds
# echec
#
#
# MH étape : 315
# modification des paramètres
# fit took 0.967911 seconds
# succes
# 8.969969879676983 ->  7.901498699284282
#
# {'lr_g': 0.004004, 'lr_d': 0.002134, 'epochs': 79, 'batch_size': 12, 'latent_dim': 8}
# generator : [1]        ReLU
# discriminator : [39, 23, 1]        ReLU
#
#
# MH étape : 316
# modification de la fonction d'activation du discriminator
# fit took 1.077836 seconds
# echec
#
#
# MH étape : 317
# suppression d'une couche du discriminator
# fit took 0.906660 seconds
# echec
#
#
# MH étape : 318
# suppression d'une couche du discriminator
# fit took 0.739321 seconds
# echec
#
#
# MH étape : 319
# suppression d'une couche du generator
# fit took 1.136476 seconds
# echec
#
#
# MH étape : 320
# ajout d'une couche au generator
# fit took 1.035682 seconds
# echec
#
#
# MH étape : 321
# suppression d'une couche du generator
# fit took 1.263468 seconds
# echec
#
#
# MH étape : 322
# modification des paramètres
# fit took 0.876831 seconds
# echec
#
#
# MH étape : 323
# suppression d'une couche du generator
# fit took 1.325892 seconds
# echec
#
#
# MH étape : 324
# suppression d'une couche du generator
# fit took 1.442848 seconds
# echec
#
#
# MH étape : 325
# suppression d'une couche du generator
# fit took 1.288132 seconds
# echec
#
#
# MH étape : 326
# suppression d'une couche du generator
# fit took 1.386826 seconds
# echec
#
#
# MH étape : 327
# modification des paramètres
# fit took 0.779508 seconds
# echec
#
#
# MH étape : 328
# modification des paramètres
# fit took 1.317117 seconds
# echec
#
#
# MH étape : 329
# suppression d'une couche du generator
# fit took 0.954134 seconds
# echec
#
#
# MH étape : 330
# modification de la fonction d'activation du generator
# fit took 0.796976 seconds
# echec
#
#
# MH étape : 331
# modification de la fonction d'activation du generator
# fit took 0.986638 seconds
# echec
#
#
# MH étape : 332
# suppression d'une couche du discriminator
# fit took 0.953614 seconds
# echec
#
#
# MH étape : 333
# modification des paramètres
# fit took 0.950986 seconds
# echec
#
#
# MH étape : 334
# ajout d'une couche au discriminator
# fit took 1.191570 seconds
# echec
#
#
# MH étape : 335
# modification des paramètres
# fit took 0.696382 seconds
# echec
#
#
# MH étape : 336
# ajout d'une couche au discriminator
# fit took 1.064945 seconds
# echec
#
#
# MH étape : 337
# modification de la fonction d'activation du discriminator
# fit took 1.112529 seconds
# echec
#
#
# MH étape : 338
# modification des paramètres
# fit took 0.729675 seconds
# echec
#
#
# MH étape : 339
# modification des paramètres
# fit took 0.978164 seconds
# echec
#
#
# MH étape : 340
# suppression d'une couche du generator
# fit took 1.074470 seconds
# echec
#
#
# MH étape : 341
# suppression d'une couche du generator
# fit took 1.030411 seconds
# echec
#
#
# MH étape : 342
# ajout d'une couche au discriminator
# fit took 1.297403 seconds
# echec
#
#
# MH étape : 343
# modification des paramètres
# fit took 1.024599 seconds
# echec
#
#
# MH étape : 344
# suppression d'une couche du discriminator
# fit took 0.910078 seconds
# echec
#
#
# MH étape : 345
# modification des paramètres
# fit took 1.062711 seconds
# echec
#
#
# MH étape : 346
# suppression d'une couche du generator
# fit took 1.109270 seconds
# echec
#
#
# MH étape : 347
# modification de la fonction d'activation du discriminator
# fit took 0.968345 seconds
# echec
#
#
# MH étape : 348
# suppression d'une couche du generator
# fit took 1.021143 seconds
# echec
#
#
# MH étape : 349
# modification des paramètres
# fit took 0.855063 seconds
# echec
#
#
# MH étape : 350
# suppression d'une couche du generator
# fit took 1.142310 seconds
# echec
#
#
# MH étape : 351
# suppression d'une couche du discriminator
# fit took 0.840638 seconds
# echec
#
#
# MH étape : 352
# ajout d'une couche au discriminator
# fit took 1.015373 seconds
# echec
#
#
# MH étape : 353
# ajout d'une couche au generator
# fit took 1.366452 seconds
# echec
#
#
# MH étape : 354
# suppression d'une couche du discriminator
# fit took 0.841669 seconds
# echec
#
#
# MH étape : 355
# suppression d'une couche du discriminator
# fit took 0.840317 seconds
# echec
#
#
# MH étape : 356
# modification des paramètres
# fit took 0.606751 seconds
# echec
#
#
# MH étape : 357
# suppression d'une couche du generator
# fit took 1.067662 seconds
# echec
#
#
# MH étape : 358
# modification des paramètres
# fit took 0.933074 seconds
# echec
#
#
# MH étape : 359
# suppression d'une couche du generator
# fit took 1.159818 seconds
# echec
#
#
# MH étape : 360
# suppression d'une couche du generator
# fit took 1.142430 seconds
# echec
#
#
# MH étape : 361
# ajout d'une couche au discriminator
# fit took 1.018467 seconds
# echec
#
#
# MH étape : 362
# modification des paramètres
# fit took 1.110487 seconds
# echec
#
#
# MH étape : 363
# modification des paramètres
# fit took 1.306709 seconds
# echec
#
#
# MH étape : 364
# suppression d'une couche du generator
# fit took 1.501375 seconds
# echec
#
#
# MH étape : 365
# modification des paramètres
# fit took 1.212432 seconds
# echec
#
#
# MH étape : 366
# modification des paramètres
# fit took 0.833187 seconds
# echec
#
#
# MH étape : 367
# ajout d'une couche au generator
# fit took 1.062147 seconds
# echec
#
#
# MH étape : 368
# ajout d'une couche au discriminator
# fit took 1.095183 seconds
# echec
#
#
# MH étape : 369
# modification de la fonction d'activation du generator
# fit took 1.079859 seconds
# echec
#
#
# MH étape : 370
# ajout d'une couche au generator
# fit took 1.097081 seconds
# echec
#
#
# MH étape : 371
# ajout d'une couche au discriminator
# fit took 0.993746 seconds
# echec
#
#
# MH étape : 372
# modification des paramètres
# fit took 1.269940 seconds
# echec
#
#
# MH étape : 373
# modification des paramètres
# fit took 1.269799 seconds
# echec
#
#
# MH étape : 374
# modification des paramètres
# fit took 1.000307 seconds
# echec
#
#
# MH étape : 375
# modification des paramètres
# fit took 1.109829 seconds
# echec
#
#
# MH étape : 376
# modification des paramètres
# fit took 1.186519 seconds
# echec
#
#
# MH étape : 377
# suppression d'une couche du generator
# fit took 1.032282 seconds
# echec
#
#
# MH étape : 378
# ajout d'une couche au discriminator
# fit took 1.415872 seconds
# echec
#
#
# MH étape : 379
# suppression d'une couche du discriminator
# fit took 1.015120 seconds
# echec
#
#
# MH étape : 380
# suppression d'une couche du generator
# fit took 1.122665 seconds
# echec
#
#
# MH étape : 381
# suppression d'une couche du discriminator
# fit took 0.954335 seconds
# echec
#
#
# MH étape : 382
# suppression d'une couche du discriminator
# fit took 0.855624 seconds
# echec
#
#
# MH étape : 383
# modification des paramètres
# fit took 0.868751 seconds
# echec
#
#
# MH étape : 384
# modification des paramètres
# fit took 1.592642 seconds
# echec
#
#
# MH étape : 385
# suppression d'une couche du discriminator
# fit took 1.344081 seconds
# echec
#
#
# MH étape : 386
# modification des paramètres
# fit took 1.325699 seconds
# echec
#
#
# MH étape : 387
# suppression d'une couche du discriminator
# fit took 1.272441 seconds
# echec
#
#
# MH étape : 388
# modification des paramètres
# fit took 1.263944 seconds
# echec
#
#
# MH étape : 389
# modification des paramètres
# fit took 1.385141 seconds
# echec
#
#
# MH étape : 390
# suppression d'une couche du discriminator
# fit took 1.454436 seconds
# echec
#
#
# MH étape : 391
# suppression d'une couche du discriminator
# fit took 1.092053 seconds
# echec
#
#
# MH étape : 392
# modification des paramètres
# fit took 1.530679 seconds
# echec
#
#
# MH étape : 393
# suppression d'une couche du discriminator
# fit took 1.143528 seconds
# echec
#
#
# MH étape : 394
# modification de la fonction d'activation du discriminator
# fit took 1.115741 seconds
# echec
#
#
# MH étape : 395
# suppression d'une couche du discriminator
# fit took 0.916571 seconds
# echec
#
#
# MH étape : 396
# modification des paramètres
# fit took 1.177248 seconds
# echec
#
#
# MH étape : 397
# modification des paramètres
# fit took 1.430834 seconds
# echec
#
#
# MH étape : 398
# ajout d'une couche au discriminator
# fit took 1.426020 seconds
# echec
#
#
# MH étape : 399
# modification des paramètres
# fit took 0.745676 seconds
# echec
#
#
# MH étape : 400
# ajout d'une couche au generator
# fit took 1.076066 seconds
# echec
#
#
# MH étape : 401
# modification des paramètres
# fit took 0.699130 seconds
# echec
#
#
# MH étape : 402
# modification des paramètres
# fit took 0.672791 seconds
# echec
#
#
# MH étape : 403
# modification des paramètres
# fit took 0.654394 seconds
# echec
#
#
# MH étape : 404
# modification des paramètres
# fit took 0.471448 seconds
# echec
#
#
# MH étape : 405
# modification des paramètres
# fit took 0.764779 seconds
# echec
#
#
# MH étape : 406
# modification des paramètres
# fit took 0.768926 seconds
# echec
#
#
# MH étape : 407
# modification des paramètres
# fit took 0.946791 seconds
# echec
#
#
# MH étape : 408
# suppression d'une couche du generator
# fit took 0.923141 seconds
# echec
#
#
# MH étape : 409
# ajout d'une couche au generator
# fit took 1.063541 seconds
# echec
#
#
# MH étape : 410
# suppression d'une couche du generator
# fit took 1.318458 seconds
# echec
#
#
# MH étape : 411
# ajout d'une couche au generator
# fit took 1.171267 seconds
# echec
#
#
# MH étape : 412
# suppression d'une couche du generator
# fit took 1.107649 seconds
# echec
#
#
# MH étape : 413
# modification des paramètres
# fit took 0.981902 seconds
# echec
#
#
# MH étape : 414
# suppression d'une couche du discriminator
# fit took 0.882871 seconds
# echec
#
#
# MH étape : 415
# modification des paramètres
# fit took 1.290370 seconds
# echec
#
#
# MH étape : 416
# modification des paramètres
# fit took 1.374012 seconds
# echec
#
#
# MH étape : 417
# modification des paramètres
# fit took 1.333021 seconds
# echec
#
#
# MH étape : 418
# modification des paramètres
# fit took 1.369638 seconds
# echec
#
#
# MH étape : 419
# suppression d'une couche du discriminator
# fit took 0.800715 seconds
# echec
#
#
# MH étape : 420
# modification des paramètres
# fit took 0.853151 seconds
# echec
#
#
# MH étape : 421
# modification des paramètres
# fit took 0.437334 seconds
# echec
#
#
# MH étape : 422
# modification des paramètres
# fit took 1.344297 seconds
# echec
#
#
# MH étape : 423
# modification des paramètres
# fit took 1.226707 seconds
# echec
#
#
# MH étape : 424
# suppression d'une couche du generator
# fit took 1.216442 seconds
# echec
#
#
# MH étape : 425
# modification des paramètres
# fit took 0.584257 seconds
# echec
#
#
# MH étape : 426
# suppression d'une couche du discriminator
# fit took 0.934718 seconds
# echec
#
#
# MH étape : 427
# suppression d'une couche du generator
# fit took 1.177886 seconds
# echec
#
#
# MH étape : 428
# modification des paramètres
# fit took 1.208148 seconds
# echec
#
#
# MH étape : 429
# modification des paramètres
# fit took 1.242739 seconds
# echec
#
#
# MH étape : 430
# ajout d'une couche au discriminator
# fit took 1.212213 seconds
# echec
#
#
# MH étape : 431
# ajout d'une couche au generator
# fit took 1.069857 seconds
# echec
#
#
# MH étape : 432
# ajout d'une couche au discriminator
# fit took 1.078465 seconds
# echec
#
#
# MH étape : 433
# suppression d'une couche du generator
# fit took 1.089508 seconds
# echec
#
#
# MH étape : 434
# modification de la fonction d'activation du discriminator
# fit took 0.862632 seconds
# echec
#
#
# MH étape : 435
# suppression d'une couche du generator
# fit took 1.141127 seconds
# echec
#
#
# MH étape : 436
# modification des paramètres
# fit took 1.046230 seconds
# echec
#
#
# MH étape : 437
# modification des paramètres
# fit took 1.082424 seconds
# echec
#
#
# MH étape : 438
# suppression d'une couche du generator
# fit took 1.173277 seconds
# succes
# 7.901498699284282 ->  7.237646755476237
#
# {'lr_g': 0.004004, 'lr_d': 0.002134, 'epochs': 79, 'batch_size': 12, 'latent_dim': 8}
# generator : [25, 1]        ReLU
# discriminator : [39, 23, 1]        ReLU
#
#
# MH étape : 439
# ajout d'une couche au generator
# fit took 0.968009 seconds
# echec
#
#
# MH étape : 440
# suppression d'une couche du generator
# fit took 1.029065 seconds
# echec
#
#
# MH étape : 441
# suppression d'une couche du discriminator
# fit took 0.960526 seconds
# echec
#
#
# MH étape : 442
# modification des paramètres
# fit took 1.394811 seconds
# echec
#
#
# MH étape : 443
# suppression d'une couche du discriminator
# fit took 0.971733 seconds
# echec
#
#
# MH étape : 444
# modification des paramètres
# fit took 1.222019 seconds
# echec
#
#
# MH étape : 445
# modification des paramètres
# fit took 0.857198 seconds
# echec
#
#
# MH étape : 446
# ajout d'une couche au generator
# fit took 0.987198 seconds
# echec
#
#
# MH étape : 447
# suppression d'une couche du discriminator
# fit took 1.032348 seconds
# echec
#
#
# MH étape : 448
# modification des paramètres
# fit took 0.843310 seconds
# echec
#
#
# MH étape : 449
# suppression d'une couche du generator
# fit took 1.017271 seconds
# echec
#
#
# MH étape : 450
# suppression d'une couche du generator
# fit took 0.889770 seconds
# echec
#
#
# MH étape : 451
# modification des paramètres
# fit took 1.297376 seconds
# echec
#
#
# MH étape : 452
# ajout d'une couche au discriminator
# fit took 0.999507 seconds
# echec
#
#
# MH étape : 453
# suppression d'une couche du discriminator
# fit took 0.983201 seconds
# echec
#
#
# MH étape : 454
# ajout d'une couche au discriminator
# fit took 1.145594 seconds
# echec
#
#
# MH étape : 455
# ajout d'une couche au generator
# fit took 1.064288 seconds
# echec
#
#
# MH étape : 456
# modification des paramètres
# fit took 1.191480 seconds
# echec
#
#
# MH étape : 457
# modification de la fonction d'activation du generator
# fit took 1.110052 seconds
# echec
#
#
# MH étape : 458
# modification des paramètres
# fit took 0.599478 seconds
# echec
#
#
# MH étape : 459
# modification des paramètres
# fit took 1.245209 seconds
# echec
#
#
# MH étape : 460
# modification des paramètres
# fit took 1.189508 seconds
# echec
#
#
# MH étape : 461
# suppression d'une couche du generator
# fit took 0.910360 seconds
# echec
#
#
# MH étape : 462
# modification des paramètres
# fit took 0.997348 seconds
# echec
#
#
# MH étape : 463
# modification des paramètres
# fit took 1.182263 seconds
# echec
#
#
# MH étape : 464
# modification des paramètres
# fit took 0.557419 seconds
# echec
#
#
# MH étape : 465
# suppression d'une couche du generator
# fit took 0.999122 seconds
# echec
#
#
# MH étape : 466
# modification des paramètres
# fit took 0.653100 seconds
# echec
#
#
# MH étape : 467
# ajout d'une couche au discriminator
# fit took 1.078416 seconds
# echec
#
#
# MH étape : 468
# suppression d'une couche du generator
# fit took 0.955462 seconds
# echec
#
#
# MH étape : 469
# modification des paramètres
# fit took 0.686522 seconds
# echec
#
#
# MH étape : 470
# modification des paramètres
# fit took 1.000098 seconds
# echec
#
#
# MH étape : 471
# modification des paramètres
# fit took 1.364144 seconds
# echec
#
#
# MH étape : 472
# modification des paramètres
# fit took 0.780792 seconds
# echec
#
#
# MH étape : 473
# modification des paramètres
# fit took 1.339884 seconds
# echec
#
#
# MH étape : 474
# modification des paramètres
# fit took 1.219004 seconds
# echec
#
#
# MH étape : 475
# modification des paramètres
# fit took 0.684123 seconds
# echec
#
#
# MH étape : 476
# modification de la fonction d'activation du generator
# fit took 0.890222 seconds
# echec
#
#
# MH étape : 477
# modification des paramètres
# fit took 0.798367 seconds
# echec
#
#
# MH étape : 478
# suppression d'une couche du discriminator
# fit took 0.919359 seconds
# echec
#
#
# MH étape : 479
# modification des paramètres
# fit took 1.101390 seconds
# echec
#
#
# MH étape : 480
# suppression d'une couche du discriminator
# fit took 0.977512 seconds
# echec
#
#
# MH étape : 481
# modification des paramètres
# fit took 0.687266 seconds
# echec
#
#
# MH étape : 482
# modification des paramètres
# fit took 0.573613 seconds
# echec
#
#
# MH étape : 483
# ajout d'une couche au discriminator
# fit took 1.101847 seconds
# echec
#
#
# MH étape : 484
# modification des paramètres
# fit took 0.905649 seconds
# echec
#
#
# MH étape : 485
# modification des paramètres
# fit took 1.359461 seconds
# echec
#
#
# MH étape : 486
# modification des paramètres
# fit took 2.175190 seconds
# echec
#
#
# MH étape : 487
# suppression d'une couche du generator
# fit took 1.680038 seconds
# echec
#
#
# MH étape : 488
# ajout d'une couche au discriminator
# fit took 1.669210 seconds
# echec
#
#
# MH étape : 489
# modification des paramètres
# fit took 1.014824 seconds
# echec
#
#
# MH étape : 490
# ajout d'une couche au generator
# fit took 1.726414 seconds
# echec
#
#
# MH étape : 491
# modification des paramètres
# fit took 1.123624 seconds
# echec
#
#
# MH étape : 492
# modification des paramètres
# fit took 1.263940 seconds
# echec
#
#
# MH étape : 493
# modification des paramètres
# fit took 1.058079 seconds
# echec
#
#
# MH étape : 494
# suppression d'une couche du generator
# fit took 1.625066 seconds
# echec
#
#
# MH étape : 495
# modification des paramètres
# fit took 1.338785 seconds
# echec
#
#
# MH étape : 496
# modification des paramètres
# fit took 2.083825 seconds
# echec
#
#
# MH étape : 497
# modification des paramètres
# fit took 1.793002 seconds
# echec
#
#
# MH étape : 498
# modification des paramètres
# fit took 1.970766 seconds
# echec
#
#
# MH étape : 499
# ajout d'une couche au discriminator
# fit took 1.855023 seconds
# echec
#
#
# MH étape : 500
# ajout d'une couche au generator
# fit took 1.676043 seconds
# echec
#
#
# MH étape : 501
# modification des paramètres
# fit took 1.638469 seconds
# echec
#
#
# MH étape : 502
# ajout d'une couche au discriminator
# fit took 1.769080 seconds
# echec
#
#
# MH étape : 503
# modification des paramètres
# fit took 1.192327 seconds
# echec
#
#
# MH étape : 504
# modification des paramètres
# fit took 1.140987 seconds
# echec
#
#
# MH étape : 505
# modification des paramètres
# fit took 1.570873 seconds
# echec
#
#
# MH étape : 506
# modification des paramètres
# fit took 1.531213 seconds
# echec
#
#
# MH étape : 507
# suppression d'une couche du generator
# fit took 1.129719 seconds
# echec
#
#
# MH étape : 508
# suppression d'une couche du generator
# fit took 1.251425 seconds
# echec
#
#
# MH étape : 509
# suppression d'une couche du discriminator
# fit took 1.009845 seconds
# echec
#
#
# MH étape : 510
# suppression d'une couche du discriminator
# fit took 1.045225 seconds
# echec
#
#
# MH étape : 511
# suppression d'une couche du discriminator
# fit took 1.459167 seconds
# echec
#
#
# MH étape : 512
# modification des paramètres
# fit took 1.768580 seconds
# echec
#
#
# MH étape : 513
# ajout d'une couche au discriminator
# fit took 1.620000 seconds
# echec
#
#
# MH étape : 514
# suppression d'une couche du generator
# fit took 1.417387 seconds
# echec
#
#
# MH étape : 515
# modification des paramètres
# fit took 1.776804 seconds
# echec
#
#
# MH étape : 516
# suppression d'une couche du discriminator
# fit took 1.299983 seconds
# echec
#
#
# MH étape : 517
# modification des paramètres
# fit took 1.094486 seconds
# echec
#
#
# MH étape : 518
# modification des paramètres
# fit took 2.106442 seconds
# echec
#
#
# MH étape : 519
# modification des paramètres
# fit took 1.957109 seconds
# echec
#
#
# MH étape : 520
# modification des paramètres
# fit took 1.621090 seconds
# echec
#
#
# MH étape : 521
# modification des paramètres
# fit took 1.122066 seconds
# echec
#
#
# MH étape : 522
# suppression d'une couche du generator
# fit took 1.096695 seconds
# echec
#
#
# MH étape : 523
# ajout d'une couche au generator
# fit took 1.457546 seconds
# echec
#
#
# MH étape : 524
# suppression d'une couche du generator
# fit took 1.563382 seconds
# echec
#
#
# MH étape : 525
# modification des paramètres
# fit took 1.175057 seconds
# echec
#
#
# MH étape : 526
# suppression d'une couche du generator
# fit took 1.156847 seconds
# echec
#
#
# MH étape : 527
# ajout d'une couche au discriminator
# fit took 1.205173 seconds
# echec
#
#
# MH étape : 528
# suppression d'une couche du generator
# fit took 1.141122 seconds
# echec
#
#
# MH étape : 529
# modification des paramètres
# fit took 1.044527 seconds
# echec
#
#
# MH étape : 530
# modification des paramètres
# fit took 0.802041 seconds
# echec
#
#
# MH étape : 531
# suppression d'une couche du discriminator
# fit took 0.954397 seconds
# echec
#
#
# MH étape : 532
# ajout d'une couche au generator
# fit took 1.345614 seconds
# echec
#
#
# MH étape : 533
# modification des paramètres
# fit took 1.509136 seconds
# echec
#
#
# MH étape : 534
# ajout d'une couche au discriminator
# fit took 1.578430 seconds
# echec
#
#
# MH étape : 535
# modification des paramètres
# fit took 1.445900 seconds
# echec
#
#
# MH étape : 536
# ajout d'une couche au discriminator
# fit took 1.139772 seconds
# echec
#
#
# MH étape : 537
# suppression d'une couche du generator
# fit took 1.045831 seconds
# echec
#
#
# MH étape : 538
# suppression d'une couche du discriminator
# fit took 1.001700 seconds
# echec
#
#
# MH étape : 539
# modification des paramètres
# fit took 1.157612 seconds
# echec
#
#
# MH étape : 540
# modification des paramètres
# fit took 1.350321 seconds
# echec
#
#
# MH étape : 541
# modification des paramètres
# fit took 0.821236 seconds
# echec
#
#
# MH étape : 542
# suppression d'une couche du discriminator
# fit took 0.903423 seconds
# echec
#
#
# MH étape : 543
# modification des paramètres
# fit took 1.319036 seconds
# echec
#
#
# MH étape : 544
# modification des paramètres
# fit took 0.825760 seconds
# echec
#
#
# MH étape : 545
# modification des paramètres
# fit took 1.066362 seconds
# echec
#
#
# MH étape : 546
# suppression d'une couche du discriminator
# fit took 0.982724 seconds
# echec
#
#
# MH étape : 547
# suppression d'une couche du generator
# fit took 0.925935 seconds
# echec
#
#
# MH étape : 548
# ajout d'une couche au generator
# fit took 1.313409 seconds
# echec
#
#
# MH étape : 549
# suppression d'une couche du discriminator
# fit took 1.003970 seconds
# echec
#
#
# MH étape : 550
# modification des paramètres
# fit took 1.052931 seconds
# echec
#
#
# MH étape : 551
# modification de la fonction d'activation du discriminator
# fit took 1.079261 seconds
# echec
#
#
# MH étape : 552
# modification des paramètres
# fit took 0.586153 seconds
# echec
#
#
# MH étape : 553
# modification des paramètres
# fit took 0.712584 seconds
# echec
#
#
# MH étape : 554
# ajout d'une couche au discriminator
# fit took 1.224973 seconds
# echec
#
#
# MH étape : 555
# suppression d'une couche du discriminator
# fit took 1.108029 seconds
# echec
#
#
# MH étape : 556
# ajout d'une couche au discriminator
# fit took 1.296101 seconds
# echec
#
#
# MH étape : 557
# modification des paramètres
# fit took 1.489514 seconds
# echec
#
#
# MH étape : 558
# modification des paramètres
# fit took 0.664303 seconds
# echec
#
#
# MH étape : 559
# modification de la fonction d'activation du generator
# fit took 0.917386 seconds
# echec
#
#
# MH étape : 560
# suppression d'une couche du generator
# fit took 1.036016 seconds
# echec
#
#
# MH étape : 561
# modification des paramètres
# fit took 0.801274 seconds
# echec
#
#
# MH étape : 562
# suppression d'une couche du generator
# fit took 0.862220 seconds
# echec
#
#
# MH étape : 563
# modification des paramètres
# fit took 1.157137 seconds
# echec
#
#
# MH étape : 564
# modification des paramètres
# fit took 1.274999 seconds
# echec
#
#
# MH étape : 565
# suppression d'une couche du generator
# fit took 0.933757 seconds
# echec
#
#
# MH étape : 566
# modification des paramètres
# fit took 1.095410 seconds
# echec
#
#
# MH étape : 567
# suppression d'une couche du generator
# fit took 1.122951 seconds
# ...
# echec
#
#
# MH étape : 809
# modification des paramètres
# fit took 1.017314 seconds
# echec
#
#
# MH étape : 810
# modification des paramètres
# fit took 1.191254 seconds
# echec
#
#
# MH étape : 811
# suppression d'une couche du generator
# fit took 1.095582 seconds
# echec
#
#
# MH étape : 812
# modification des paramètres
# fit took 1.350177 seconds
# echec
#
#
# MH étape : 813
# ajout d'une couche au generator
# fit took 1.393270 seconds
# echec
#
#
# MH étape : 814
# suppression d'une couche du generator
# fit took 0.995092 seconds
# echec
#
#
# MH étape : 815
# modification des paramètres
# fit took 0.951158 seconds
# echec
#
#
# MH étape : 816
# suppression d'une couche du generator
# fit took 1.262442 seconds
# echec
#
#
# MH étape : 817
# modification des paramètres
# fit took 1.366626 seconds
# echec
#
#
# MH étape : 818
# modification des paramètres
# fit took 1.090673 seconds
# echec
#
#
# MH étape : 819
# ajout d'une couche au discriminator
# fit took 1.414550 seconds
# echec
#
#
# MH étape : 820
# modification de la fonction d'activation du discriminator
# fit took 1.631974 seconds
# echec
#
#
# MH étape : 821
# modification des paramètres
# fit took 0.946748 seconds
# echec
#
#
# MH étape : 822
# suppression d'une couche du generator
# fit took 1.079987 seconds
# echec
#
#
# MH étape : 823
# suppression d'une couche du generator
# fit took 0.984866 seconds
# echec
#
#
# MH étape : 824
# suppression d'une couche du discriminator
# fit took 0.987950 seconds
# echec
#
#
# MH étape : 825
# suppression d'une couche du discriminator
# fit took 1.032960 seconds
# echec
#
#
# MH étape : 826
# ajout d'une couche au discriminator
# fit took 1.343693 seconds
# echec
#
#
# MH étape : 827
# modification de la fonction d'activation du discriminator
# fit took 1.052134 seconds
# echec
#
#
# MH étape : 828
# modification des paramètres
# fit took 1.189754 seconds
# echec
#
#
# MH étape : 829
# suppression d'une couche du generator
# fit took 0.983315 seconds
# echec
#
#
# MH étape : 830
# modification des paramètres
# fit took 0.962985 seconds
# echec
#
#
# MH étape : 831
# modification des paramètres
# fit took 1.229549 seconds
# echec
#
#
# MH étape : 832
# modification des paramètres
# fit took 1.206124 seconds
# echec
#
#
# MH étape : 833
# suppression d'une couche du discriminator
# fit took 1.161362 seconds
# echec
#
#
# MH étape : 834
# suppression d'une couche du discriminator
# fit took 1.159121 seconds
# echec
#
#
# MH étape : 835
# ajout d'une couche au generator
# fit took 1.157606 seconds
# echec
#
#
# MH étape : 836
# ajout d'une couche au generator
# fit took 1.916047 seconds
# echec
#
#
# MH étape : 837
# suppression d'une couche du discriminator
# fit took 1.422857 seconds
# echec
#
#
# MH étape : 838
# suppression d'une couche du discriminator
# fit took 1.048748 seconds
# echec
#
#
# MH étape : 839
# modification des paramètres
# fit took 0.824970 seconds
# echec
#
#
# MH étape : 840
# suppression d'une couche du discriminator
# fit took 1.095716 seconds
# echec
#
#
# MH étape : 841
# modification des paramètres
# fit took 1.017861 seconds
# echec
#
#
# MH étape : 842
# modification des paramètres
# fit took 1.079683 seconds
# echec
#
#
# MH étape : 843
# suppression d'une couche du generator
# fit took 0.918492 seconds
# echec
#
#
# MH étape : 844
# modification des paramètres
# fit took 0.683970 seconds
# echec
#
#
# MH étape : 845
# modification des paramètres
# fit took 1.146405 seconds
# echec
#
#
# MH étape : 846
# suppression d'une couche du generator
# fit took 1.108199 seconds
# echec
#
#
# MH étape : 847
# ajout d'une couche au generator
# fit took 1.340523 seconds
# echec
#
#
# MH étape : 848
# suppression d'une couche du generator
# fit took 1.477636 seconds
# echec
#
#
# MH étape : 849
# modification des paramètres
# fit took 1.503769 seconds
# echec
#
#
# MH étape : 850
# suppression d'une couche du generator
# fit took 1.285363 seconds
# echec
#
#
# MH étape : 851
# modification des paramètres
# fit took 0.881513 seconds
# echec
#
#
# MH étape : 852
# suppression d'une couche du generator
# fit took 1.003033 seconds
# echec
#
#
# MH étape : 853
# ajout d'une couche au discriminator
# fit took 1.264474 seconds
# echec
#
#
# MH étape : 854
# modification des paramètres
# fit took 0.931224 seconds
# echec
#
#
# MH étape : 855
# modification de la fonction d'activation du generator
# fit took 1.073282 seconds
# echec
#
#
# MH étape : 856
# modification des paramètres
# fit took 1.055386 seconds
# echec
#
#
# MH étape : 857
# modification des paramètres
# fit took 1.265552 seconds
# echec
#
#
# MH étape : 858
# ajout d'une couche au discriminator
# fit took 1.403275 seconds
# echec
#
#
# MH étape : 859
# modification des paramètres
# fit took 1.233556 seconds
# echec
#
#
# MH étape : 860
# modification des paramètres
# fit took 0.986268 seconds
# echec
#
#
# MH étape : 861
# modification des paramètres
# fit took 0.891301 seconds
# echec
#
#
# MH étape : 862
# modification des paramètres
# fit took 1.037420 seconds
# echec
#
#
# MH étape : 863
# modification des paramètres
# fit took 1.460645 seconds
# echec
#
#
# MH étape : 864
# suppression d'une couche du discriminator
# fit took 1.043182 seconds
# echec
#
#
# MH étape : 865
# modification de la fonction d'activation du generator
# fit took 1.207660 seconds
# echec
#
#
# MH étape : 866
# suppression d'une couche du discriminator
# fit took 1.104051 seconds
# echec
#
#
# MH étape : 867
# modification des paramètres
# fit took 1.116217 seconds
# echec
#
#
# MH étape : 868
# ajout d'une couche au generator
# fit took 1.196648 seconds
# echec
#
#
# MH étape : 869
# suppression d'une couche du discriminator
# fit took 1.302198 seconds
# echec
#
#
# MH étape : 870
# suppression d'une couche du discriminator
# fit took 0.940184 seconds
# echec
#
#
# MH étape : 871
# modification des paramètres
# fit took 1.269429 seconds
# echec
#
#
# MH étape : 872
# suppression d'une couche du generator
# fit took 1.148187 seconds
# echec
#
#
# MH étape : 873
# suppression d'une couche du discriminator
# fit took 1.044742 seconds
# echec
#
#
# MH étape : 874
# modification des paramètres
# fit took 0.659048 seconds
# echec
#
#
# MH étape : 875
# ajout d'une couche au generator
# fit took 1.324208 seconds
# echec
#
#
# MH étape : 876
# modification des paramètres
# fit took 1.225245 seconds
# echec
#
#
# MH étape : 877
# modification des paramètres
# fit took 1.333159 seconds
# echec
#
#
# MH étape : 878
# modification des paramètres
# fit took 1.321916 seconds
# echec
#
#
# MH étape : 879
# modification des paramètres
# fit took 1.124734 seconds
# echec
#
#
# MH étape : 880
# suppression d'une couche du discriminator
# fit took 1.284643 seconds
# echec
#
#
# MH étape : 881
# ajout d'une couche au generator
# fit took 1.259647 seconds
# echec
#
#
# MH étape : 882
# modification de la fonction d'activation du discriminator
# fit took 1.118791 seconds
# echec
#
#
# MH étape : 883
# suppression d'une couche du discriminator
# fit took 1.089002 seconds
# echec
#
#
# MH étape : 884
# ajout d'une couche au discriminator
# fit took 1.420391 seconds
# echec
#
#
# MH étape : 885
# modification des paramètres
# fit took 1.206201 seconds
# echec
#
#
# MH étape : 886
# modification des paramètres
# fit took 1.348176 seconds
# echec
#
#
# MH étape : 887
# modification de la fonction d'activation du discriminator
# fit took 1.252355 seconds
# echec
#
#
# MH étape : 888
# modification de la fonction d'activation du generator
# fit took 1.296054 seconds
# echec
#
#
# MH étape : 889
# suppression d'une couche du generator
# fit took 1.077874 seconds
# echec
#
#
# MH étape : 890
# suppression d'une couche du generator
# fit took 1.238575 seconds
# echec
#
#
# MH étape : 891
# suppression d'une couche du generator
# fit took 1.239927 seconds
# echec
#
#
# MH étape : 892
# ajout d'une couche au generator
# fit took 1.406356 seconds
# echec
#
#
# MH étape : 893
# suppression d'une couche du generator
# fit took 1.049138 seconds
# echec
#
#
# MH étape : 894
# suppression d'une couche du discriminator
# fit took 0.979558 seconds
# echec
#
#
# MH étape : 895
# modification des paramètres
# fit took 0.597610 seconds
# echec
#
#
# MH étape : 896
# suppression d'une couche du generator
# fit took 1.305810 seconds
# echec
#
#
# MH étape : 897
# suppression d'une couche du generator
# fit took 1.063984 seconds
# echec
#
#
# MH étape : 898
# modification des paramètres
# fit took 1.107181 seconds
# echec
#
#
# MH étape : 899
# modification des paramètres
# fit took 1.313936 seconds
# echec
#
#
# MH étape : 900
# suppression d'une couche du discriminator
# fit took 1.073103 seconds
# echec
#
#
# MH étape : 901
# modification de la fonction d'activation du generator
# fit took 1.246000 seconds
# echec
#
#
# MH étape : 902
# suppression d'une couche du discriminator
# fit took 1.144368 seconds
# echec
#
#
# MH étape : 903
# modification des paramètres
# fit took 1.188046 seconds
# echec
#
#
# MH étape : 904
# modification des paramètres
# fit took 1.195854 seconds
# echec
#
#
# MH étape : 905
# ajout d'une couche au generator
# fit took 1.417091 seconds
# echec
#
#
# MH étape : 906
# modification des paramètres
# fit took 1.334624 seconds
# echec
#
#
# MH étape : 907
# modification de la fonction d'activation du discriminator
# fit took 1.194701 seconds
# echec
#
#
# MH étape : 908
# ajout d'une couche au discriminator
# fit took 1.418002 seconds
# echec
#
#
# MH étape : 909
# modification des paramètres
# fit took 1.127050 seconds
# echec
#
#
# MH étape : 910
# modification des paramètres
# fit took 1.346177 seconds
# echec
#
#
# MH étape : 911
# modification des paramètres
# fit took 1.351623 seconds
# echec
#
#
# MH étape : 912
# ajout d'une couche au discriminator
# fit took 1.873645 seconds
# echec
#
#
# MH étape : 913
# modification des paramètres
# fit took 1.167388 seconds
# echec
#
#
# MH étape : 914
# modification des paramètres
# fit took 1.431723 seconds
# echec
#
#
# MH étape : 915
# suppression d'une couche du generator
# fit took 1.163417 seconds
# echec
#
#
# MH étape : 916
# suppression d'une couche du discriminator
# fit took 1.261099 seconds
# echec
#
#
# MH étape : 917
# modification des paramètres
# fit took 1.236823 seconds
# echec
#
#
# MH étape : 918
# ajout d'une couche au generator
# fit took 1.341544 seconds
# echec
#
#
# MH étape : 919
# modification des paramètres
# fit took 1.095609 seconds
# echec
#
#
# MH étape : 920
# modification des paramètres
# fit took 1.395236 seconds
# echec
#
#
# MH étape : 921
# modification des paramètres
# fit took 0.884577 seconds
# echec
#
#
# MH étape : 922
# modification de la fonction d'activation du generator
# fit took 1.210501 seconds
# echec
#
#
# MH étape : 923
# suppression d'une couche du discriminator
# fit took 1.210336 seconds
# echec
#
#
# MH étape : 924
# ajout d'une couche au generator
# fit took 1.418355 seconds
# echec
#
#
# MH étape : 925
# ajout d'une couche au generator
# fit took 1.282492 seconds
# echec
#
#
# MH étape : 926
# suppression d'une couche du generator
# fit took 1.211416 seconds
# echec
#
#
# MH étape : 927
# modification des paramètres
# fit took 0.850958 seconds
# echec
#
#
# MH étape : 928
# ajout d'une couche au generator
# fit took 1.179315 seconds
# echec
#
#
# MH étape : 929
# modification des paramètres
# fit took 1.673715 seconds
# echec
#
#
# MH étape : 930
# ajout d'une couche au generator
# fit took 1.564201 seconds
# echec
#
#
# MH étape : 931
# modification des paramètres
# fit took 0.727535 seconds
# echec
#
#
# MH étape : 932
# suppression d'une couche du generator
# fit took 1.249302 seconds
# echec
#
#
# MH étape : 933
# modification des paramètres
# fit took 0.906660 seconds
# echec
#
#
# MH étape : 934
# modification des paramètres
# fit took 0.762321 seconds
# echec
#
#
# MH étape : 935
# modification des paramètres
# fit took 1.153007 seconds
# echec
#
#
# MH étape : 936
# modification des paramètres
# fit took 1.555951 seconds
# echec
#
#
# MH étape : 937
# modification des paramètres
# fit took 1.134003 seconds
# echec
#
#
# MH étape : 938
# modification des paramètres
# fit took 1.239601 seconds
# echec
#
#
# MH étape : 939
# suppression d'une couche du generator
# fit took 1.262494 seconds
# echec
#
#
# MH étape : 940
# ajout d'une couche au generator
# fit took 1.344788 seconds
# echec
#
#
# MH étape : 941
# suppression d'une couche du discriminator
# fit took 1.094553 seconds
# echec
#
#
# MH étape : 942
# suppression d'une couche du discriminator
# fit took 1.097047 seconds
# echec
#
#
# MH étape : 943
# modification des paramètres
# fit took 1.186776 seconds
# echec
#
#
# MH étape : 944
# suppression d'une couche du discriminator
# fit took 1.116982 seconds
# echec
#
#
# MH étape : 945
# ajout d'une couche au generator
# fit took 1.176352 seconds
# echec
#
#
# MH étape : 946
# modification des paramètres
# fit took 1.143960 seconds
# echec
#
#
# MH étape : 947
# ajout d'une couche au generator
# fit took 1.358974 seconds
# echec
#
#
# MH étape : 948
# suppression d'une couche du generator
# fit took 1.068010 seconds
# echec
#
#
# MH étape : 949
# suppression d'une couche du discriminator
# fit took 1.064863 seconds
# echec
#
#
# MH étape : 950
# ajout d'une couche au discriminator
# fit took 1.144232 seconds
# echec
#
#
# MH étape : 951
# modification des paramètres
# fit took 1.052194 seconds
# echec
#
#
# MH étape : 952
# suppression d'une couche du generator
# fit took 1.189214 seconds
# echec
#
#
# MH étape : 953
# modification des paramètres
# fit took 0.776902 seconds
# echec
#
#
# MH étape : 954
# modification des paramètres
# fit took 0.639641 seconds
# echec
#
#
# MH étape : 955
# modification des paramètres
# fit took 1.087171 seconds
# echec
#
#
# MH étape : 956
# ajout d'une couche au discriminator
# fit took 1.341523 seconds
# echec
#
#
# MH étape : 957
# modification des paramètres
# fit took 1.267504 seconds
# echec
#
#
# MH étape : 958
# suppression d'une couche du discriminator
# fit took 1.144245 seconds
# echec
#
#
# MH étape : 959
# modification des paramètres
# fit took 1.238744 seconds
# echec
#
#
# MH étape : 960
# suppression d'une couche du discriminator
# fit took 0.874665 seconds
# echec
#
#
# MH étape : 961
# modification des paramètres
# fit took 1.170284 seconds
# echec
#
#
# MH étape : 962
# modification de la fonction d'activation du generator
# fit took 1.347930 seconds
# echec
#
#
# MH étape : 963
# suppression d'une couche du discriminator
# fit took 1.172734 seconds
# echec
#
#
# MH étape : 964
# modification des paramètres
# fit took 0.831069 seconds
# echec
#
#
# MH étape : 965
# ajout d'une couche au generator
# fit took 1.344550 seconds
# echec
#
#
# MH étape : 966
# modification des paramètres
# fit took 0.668504 seconds
# echec
#
#
# MH étape : 967
# ajout d'une couche au discriminator
# fit took 1.280195 seconds
# echec
#
#
# MH étape : 968
# modification de la fonction d'activation du discriminator
# fit took 1.225479 seconds
# echec
#
#
# MH étape : 969
# ajout d'une couche au generator
# fit took 1.204560 seconds
# echec
#
#
# MH étape : 970
# suppression d'une couche du generator
# fit took 1.208039 seconds
# echec
#
#
# MH étape : 971
# modification des paramètres
# fit took 1.269531 seconds
# echec
#
#
# MH étape : 972
# suppression d'une couche du discriminator
# fit took 1.036173 seconds
# echec
#
#
# MH étape : 973
# suppression d'une couche du generator
# fit took 1.212821 seconds
# echec
#
#
# MH étape : 974
# ajout d'une couche au generator
# fit took 1.306419 seconds
# echec
#
#
# MH étape : 975
# suppression d'une couche du generator
# fit took 1.188528 seconds
# echec
#
#
# MH étape : 976
# modification des paramètres
# fit took 0.985119 seconds
# echec
#
#
# MH étape : 977
# modification des paramètres
# fit took 0.672967 seconds
# echec
#
#
# MH étape : 978
# ajout d'une couche au discriminator
# fit took 1.472116 seconds
# echec
#
#
# MH étape : 979
# modification des paramètres
# fit took 0.664099 seconds
# echec
#
#
# MH étape : 980
# modification des paramètres
# fit took 0.950411 seconds
# echec
#
#
# MH étape : 981
# modification des paramètres
# fit took 1.109924 seconds
# echec
#
#
# MH étape : 982
# modification des paramètres
# fit took 0.631347 seconds
# echec
#
#
# MH étape : 983
# modification des paramètres
# fit took 1.126734 seconds
# echec
#
#
# MH étape : 984
# suppression d'une couche du generator
# fit took 1.247879 seconds
# echec
#
#
# MH étape : 985
# suppression d'une couche du discriminator
# fit took 0.962281 seconds
# echec
#
#
# MH étape : 986
# suppression d'une couche du discriminator
# fit took 1.090508 seconds
# echec
#
#
# MH étape : 987
# modification de la fonction d'activation du discriminator
# fit took 1.205865 seconds
# echec
#
#
# MH étape : 988
# suppression d'une couche du discriminator
# fit took 1.144507 seconds
# echec
#
#
# MH étape : 989
# modification des paramètres
# fit took 1.324652 seconds
# echec
#
#
# MH étape : 990
# suppression d'une couche du discriminator
# fit took 1.183563 seconds
# echec
#
#
# MH étape : 991
# suppression d'une couche du discriminator
# fit took 1.000647 seconds
# echec
#
#
# MH étape : 992
# ajout d'une couche au discriminator
# fit took 1.367109 seconds
# echec
#
#
# MH étape : 993
# ajout d'une couche au discriminator
# fit took 1.221969 seconds
# echec
#
#
# MH étape : 994
# ajout d'une couche au discriminator
# fit took 1.485279 seconds
# echec
#
#
# MH étape : 995
# modification des paramètres
# fit took 0.938306 seconds
# echec
#
#
# MH étape : 996
# modification des paramètres
# fit took 0.988984 seconds
# echec
#
#
# MH étape : 997
# modification des paramètres
# fit took 0.734425 seconds
# echec
#
#
# MH étape : 998
# modification des paramètres
# fit took 1.334924 seconds
# echec
#
#
# MH étape : 999
# modification des paramètres
# fit took 1.432381 seconds
# echec

# %%
print(archi)
# Out:
# {'generator': {'architecture': 'MLP', 'layer_sizes': [25, 1], 'activation': 'ReLU'}, 'discriminator': {'architecture': 'MLP', 'layer_sizes': [39, 23, 1], 'activation': 'ReLU'}}

# %%
model = GAN()
model.set_data(data)
model.fit(architectures = archi)
model.fit_hyperparameters({"lr_g": [5e-6, 5e-3], "lr_d": [5e-6, 5e-3], "epochs": [50, 150], "batch_size": [8,300], "latent_dim": [1,150]}, n_trials = 100)
# Out:
# [I 2025-04-16 20:15:59,139] A new study created in memory with name: no-name-c2ad648f-94d0-49c0-9e3a-675fd2a17211
# fit took 0.655268 seconds
# [I 2025-04-16 20:16:00,601] Trial 0 finished with value: 436.65689893807155 and parameters: {'lr_g': 0.0019536543717218278, 'lr_d': 0.00493982221467401, 'epochs': 76, 'batch_size': 111, 'latent_dim': 2}. Best is trial 0 with value: 436.65689893807155.
# fit took 1.288813 seconds
# [I 2025-04-16 20:16:02,379] Trial 1 finished with value: 7.742709319611028 and parameters: {'lr_g': 0.00022375184174189098, 'lr_d': 0.003284305168184232, 'epochs': 77, 'batch_size': 122, 'latent_dim': 106}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.601691 seconds
# [I 2025-04-16 20:16:04,270] Trial 2 finished with value: 359.0487233595892 and parameters: {'lr_g': 0.0018200838501772861, 'lr_d': 0.0034498966550646146, 'epochs': 90, 'batch_size': 32, 'latent_dim': 136}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.752722 seconds
# [I 2025-04-16 20:16:06,625] Trial 3 finished with value: 19.277535459394315 and parameters: {'lr_g': 0.001652492818231945, 'lr_d': 0.0032878333662779246, 'epochs': 121, 'batch_size': 206, 'latent_dim': 66}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.241068 seconds
# [I 2025-04-16 20:16:09,012] Trial 4 finished with value: 925.6161664951896 and parameters: {'lr_g': 0.004939145659547826, 'lr_d': 0.0024165797271932785, 'epochs': 99, 'batch_size': 270, 'latent_dim': 64}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.273095 seconds
# [I 2025-04-16 20:16:12,367] Trial 5 finished with value: 487.1118868853368 and parameters: {'lr_g': 0.003780501184665221, 'lr_d': 0.004039001275414687, 'epochs': 135, 'batch_size': 48, 'latent_dim': 50}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.248327 seconds
# [I 2025-04-16 20:16:14,319] Trial 6 finished with value: 519.4161783859774 and parameters: {'lr_g': 0.0034732103148459557, 'lr_d': 0.0025554998116839294, 'epochs': 87, 'batch_size': 250, 'latent_dim': 48}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.823685 seconds
# [I 2025-04-16 20:16:16,356] Trial 7 finished with value: 29.058124252261578 and parameters: {'lr_g': 0.002362629552916459, 'lr_d': 0.0009363075122507898, 'epochs': 94, 'batch_size': 176, 'latent_dim': 132}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.911539 seconds
# [I 2025-04-16 20:16:18,837] Trial 8 finished with value: 18.13411930180909 and parameters: {'lr_g': 0.0005148026885960428, 'lr_d': 0.0022013131938500557, 'epochs': 117, 'batch_size': 26, 'latent_dim': 62}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.332730 seconds
# [I 2025-04-16 20:16:21,172] Trial 9 finished with value: 17713.406124924182 and parameters: {'lr_g': 0.004864912298414569, 'lr_d': 0.003575127225728605, 'epochs': 89, 'batch_size': 23, 'latent_dim': 68}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.170506 seconds
# fit took 1.353489 seconds
# [I 2025-04-16 20:16:22,818] Trial 10 finished with value: 18.425007781679234 and parameters: {'lr_g': 0.00014360992821131364, 'lr_d': 0.0004905121719879046, 'epochs': 50, 'batch_size': 106, 'latent_dim': 110}. Best is trial 1 with value: 7.742709319611028.
# [I 2025-04-16 20:16:26,033] Trial 11 finished with value: 19.941006225781788 and parameters: {'lr_g': 0.00018929669372818241, 'lr_d': 0.0016675713098682032, 'epochs': 119, 'batch_size': 70, 'latent_dim': 98}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.030019 seconds
# [I 2025-04-16 20:16:27,400] Trial 12 finished with value: 14.906926608979331 and parameters: {'lr_g': 0.0008811227312007718, 'lr_d': 0.0021761405227197165, 'epochs': 63, 'batch_size': 124, 'latent_dim': 100}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.217130 seconds
# [I 2025-04-16 20:16:29,296] Trial 13 finished with value: 21.27986787464707 and parameters: {'lr_g': 0.001026642805227194, 'lr_d': 0.0015641654498359209, 'epochs': 59, 'batch_size': 144, 'latent_dim': 99}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.679425 seconds
# [I 2025-04-16 20:16:31,366] Trial 14 finished with value: 13.353209671480839 and parameters: {'lr_g': 0.001031530469306142, 'lr_d': 0.004434002987513787, 'epochs': 70, 'batch_size': 107, 'latent_dim': 116}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.832312 seconds
# [I 2025-04-16 20:16:33,948] Trial 15 finished with value: 26.379200385451856 and parameters: {'lr_g': 0.0011061315770016491, 'lr_d': 0.0049646127504695175, 'epochs': 79, 'batch_size': 182, 'latent_dim': 149}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.343122 seconds
# [I 2025-04-16 20:16:35,991] Trial 16 finished with value: 255.9387739878382 and parameters: {'lr_g': 0.003048908018928264, 'lr_d': 0.004289324107366628, 'epochs': 72, 'batch_size': 73, 'latent_dim': 126}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.867281 seconds
# fit took 2.506345 seconds
# [I 2025-04-16 20:16:38,806] Trial 17 finished with value: 26.484238031936798 and parameters: {'lr_g': 0.0014005402608686095, 'lr_d': 0.004279934370910408, 'epochs': 107, 'batch_size': 218, 'latent_dim': 84}. Best is trial 1 with value: 7.742709319611028.
# [I 2025-04-16 20:16:40,542] Trial 18 finished with value: 21.4099362766071 and parameters: {'lr_g': 0.0005488291372682474, 'lr_d': 0.003101122684816143, 'epochs': 66, 'batch_size': 150, 'latent_dim': 116}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.532862 seconds
# [I 2025-04-16 20:16:41,849] Trial 19 finished with value: 24.716613067130336 and parameters: {'lr_g': 0.0023893624610764087, 'lr_d': 0.0029241640727841033, 'epochs': 51, 'batch_size': 90, 'latent_dim': 85}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.139301 seconds
# [I 2025-04-16 20:16:45,416] Trial 20 finished with value: 11.60697945199606 and parameters: {'lr_g': 2.306053833920664e-05, 'lr_d': 0.003911712147283852, 'epochs': 143, 'batch_size': 130, 'latent_dim': 18}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.358202 seconds
# [I 2025-04-16 20:16:47,260] Trial 21 finished with value: 15.344296712970227 and parameters: {'lr_g': 0.0005631997621863857, 'lr_d': 0.00402545189216295, 'epochs': 81, 'batch_size': 130, 'latent_dim': 3}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.675000 seconds
# [I 2025-04-16 20:16:50,777] Trial 22 finished with value: 17.32287084722745 and parameters: {'lr_g': 8.318947744637145e-05, 'lr_d': 0.0038261912300105584, 'epochs': 143, 'batch_size': 170, 'latent_dim': 34}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.330116 seconds
# [I 2025-04-16 20:16:53,895] Trial 23 finished with value: 24.871541119119804 and parameters: {'lr_g': 0.0007026294465890174, 'lr_d': 0.004562288353149506, 'epochs': 146, 'batch_size': 72, 'latent_dim': 33}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.941266 seconds
# [I 2025-04-16 20:16:56,882] Trial 24 finished with value: 23.55054377412241 and parameters: {'lr_g': 2.4581477858467593e-05, 'lr_d': 0.004554403921374027, 'epochs': 111, 'batch_size': 96, 'latent_dim': 17}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.786719 seconds
# [I 2025-04-16 20:17:00,183] Trial 25 finished with value: 13.73111346905223 and parameters: {'lr_g': 0.0013047402308561575, 'lr_d': 0.0037204771800329163, 'epochs': 136, 'batch_size': 137, 'latent_dim': 115}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.128809 seconds
# [I 2025-04-16 20:17:03,147] Trial 26 finished with value: 15.378389404434307 and parameters: {'lr_g': 0.00047044249971475016, 'lr_d': 0.002690769671480446, 'epochs': 129, 'batch_size': 204, 'latent_dim': 84}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.814248 seconds
# [I 2025-04-16 20:17:04,658] Trial 27 finished with value: 16.938206873749845 and parameters: {'lr_g': 0.0009715588089659357, 'lr_d': 0.004560304407751514, 'epochs': 69, 'batch_size': 52, 'latent_dim': 125}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.336747 seconds
# [I 2025-04-16 20:17:06,457] Trial 28 finished with value: 261.8093640964865 and parameters: {'lr_g': 0.0014719534339341113, 'lr_d': 0.0030781363777727983, 'epochs': 58, 'batch_size': 163, 'latent_dim': 140}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.591241 seconds
# [I 2025-04-16 20:17:08,475] Trial 29 finished with value: 924.3441733201803 and parameters: {'lr_g': 0.002852041668455444, 'lr_d': 0.00474606100904086, 'epochs': 75, 'batch_size': 113, 'latent_dim': 4}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.794522 seconds
# [I 2025-04-16 20:17:11,131] Trial 30 finished with value: 21.199170577580553 and parameters: {'lr_g': 0.002004566408456932, 'lr_d': 0.00406765539552971, 'epochs': 106, 'batch_size': 119, 'latent_dim': 106}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.457346 seconds
# [I 2025-04-16 20:17:14,299] Trial 31 finished with value: 23.478837758732688 and parameters: {'lr_g': 0.0013505420180746112, 'lr_d': 0.003592687795355014, 'epochs': 139, 'batch_size': 132, 'latent_dim': 117}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.978170 seconds
# [I 2025-04-16 20:17:17,456] Trial 32 finished with value: 409.8327625837404 and parameters: {'lr_g': 0.0020640004006761115, 'lr_d': 0.003748570071198112, 'epochs': 127, 'batch_size': 151, 'latent_dim': 90}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.946303 seconds
# [I 2025-04-16 20:17:20,643] Trial 33 finished with value: 15.436917173749205 and parameters: {'lr_g': 0.00033112027291438257, 'lr_d': 0.003388044803436481, 'epochs': 149, 'batch_size': 91, 'latent_dim': 120}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.986753 seconds
# [I 2025-04-16 20:17:23,907] Trial 34 finished with value: 19.439878336880433 and parameters: {'lr_g': 0.0007969214101862521, 'lr_d': 0.003345736554783409, 'epochs': 133, 'batch_size': 138, 'latent_dim': 141}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.067838 seconds
# fit took 2.186815 seconds
# [I 2025-04-16 20:17:26,398] Trial 35 finished with value: 370.08700384677104 and parameters: {'lr_g': 0.0016696141739555937, 'lr_d': 0.0041660953091457, 'epochs': 83, 'batch_size': 106, 'latent_dim': 110}. Best is trial 1 with value: 7.742709319611028.
# [I 2025-04-16 20:17:29,302] Trial 36 finished with value: 29.986327272131014 and parameters: {'lr_g': 0.0011923404880637182, 'lr_d': 0.003799816032651057, 'epochs': 100, 'batch_size': 195, 'latent_dim': 130}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.695486 seconds
# [I 2025-04-16 20:17:32,561] Trial 37 finished with value: 20.724173381941874 and parameters: {'lr_g': 0.0017960424501760697, 'lr_d': 0.002907093572350163, 'epochs': 140, 'batch_size': 221, 'latent_dim': 51}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.067334 seconds
# [I 2025-04-16 20:17:35,875] Trial 38 finished with value: 120.39633626240884 and parameters: {'lr_g': 0.00029368111509954893, 'lr_d': 0.004368067297405487, 'epochs': 125, 'batch_size': 10, 'latent_dim': 94}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.104968 seconds
# [I 2025-04-16 20:17:38,677] Trial 39 finished with value: 693.896570677785 and parameters: {'lr_g': 0.00415046738020193, 'lr_d': 0.003872111256718146, 'epochs': 97, 'batch_size': 54, 'latent_dim': 75}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.580824 seconds
# [I 2025-04-16 20:17:41,876] Trial 40 finished with value: 27.33058848756946 and parameters: {'lr_g': 0.000721916167992455, 'lr_d': 0.0035118157502297036, 'epochs': 133, 'batch_size': 161, 'latent_dim': 109}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.993981 seconds
# [I 2025-04-16 20:17:44,108] Trial 41 finished with value: 15.687936479934217 and parameters: {'lr_g': 0.0009447156229974974, 'lr_d': 0.002151314070998749, 'epochs': 63, 'batch_size': 123, 'latent_dim': 103}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.001654 seconds
# [I 2025-04-16 20:17:45,815] Trial 42 finished with value: 14.502942851717174 and parameters: {'lr_g': 0.0004073155492314471, 'lr_d': 0.0017415392548975565, 'epochs': 59, 'batch_size': 99, 'latent_dim': 75}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.505843 seconds
# [I 2025-04-16 20:17:47,168] Trial 43 finished with value: 37.64105455009074 and parameters: {'lr_g': 0.0003040120166314623, 'lr_d': 0.0016830744226869752, 'epochs': 55, 'batch_size': 84, 'latent_dim': 42}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.154743 seconds
# [I 2025-04-16 20:17:49,381] Trial 44 finished with value: 24.82229044127261 and parameters: {'lr_g': 0.00043719263280161947, 'lr_d': 0.0008860803849052624, 'epochs': 74, 'batch_size': 102, 'latent_dim': 75}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.975945 seconds
# [I 2025-04-16 20:17:51,432] Trial 45 finished with value: 23.72982268201803 and parameters: {'lr_g': 1.2158232499316011e-05, 'lr_d': 0.0012770291691788244, 'epochs': 87, 'batch_size': 272, 'latent_dim': 64}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.855561 seconds
# [I 2025-04-16 20:17:53,318] Trial 46 finished with value: 27.46998957186525 and parameters: {'lr_g': 0.0006460069080895308, 'lr_d': 0.0024197390497180307, 'epochs': 70, 'batch_size': 183, 'latent_dim': 18}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.642239 seconds
# [I 2025-04-16 20:17:54,978] Trial 47 finished with value: 46.99714229636479 and parameters: {'lr_g': 0.0013574901419195196, 'lr_d': 0.0002481745168748388, 'epochs': 63, 'batch_size': 140, 'latent_dim': 58}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.458432 seconds
# [I 2025-04-16 20:17:57,613] Trial 48 finished with value: 284.9730600340308 and parameters: {'lr_g': 0.0011456417139485125, 'lr_d': 0.004788331139860953, 'epochs': 93, 'batch_size': 112, 'latent_dim': 149}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.421166 seconds
# [I 2025-04-16 20:18:00,420] Trial 49 finished with value: 18.75317234891093 and parameters: {'lr_g': 0.00027486922786520084, 'lr_d': 0.002589510235792902, 'epochs': 115, 'batch_size': 62, 'latent_dim': 132}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.614193 seconds
# [I 2025-04-16 20:18:02,288] Trial 50 finished with value: 12.11709274518567 and parameters: {'lr_g': 0.0009147095297452044, 'lr_d': 0.003099826286690631, 'epochs': 78, 'batch_size': 296, 'latent_dim': 123}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.669818 seconds
# [I 2025-04-16 20:18:04,401] Trial 51 finished with value: 47.82028704363649 and parameters: {'lr_g': 0.0007956789728268887, 'lr_d': 0.003161672925139381, 'epochs': 77, 'batch_size': 250, 'latent_dim': 120}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.883893 seconds
# [I 2025-04-16 20:18:06,698] Trial 52 finished with value: 10.87880073594675 and parameters: {'lr_g': 0.00044792860678523826, 'lr_d': 0.0027951876727542735, 'epochs': 85, 'batch_size': 253, 'latent_dim': 113}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.089987 seconds
# [I 2025-04-16 20:18:08,604] Trial 53 finished with value: 12.944574858402808 and parameters: {'lr_g': 0.0015756254731399723, 'lr_d': 0.002870892664706726, 'epochs': 83, 'batch_size': 289, 'latent_dim': 114}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.711039 seconds
# [I 2025-04-16 20:18:11,078] Trial 54 finished with value: 19.11024537863637 and parameters: {'lr_g': 0.0016229829506885745, 'lr_d': 0.0028255221446409446, 'epochs': 85, 'batch_size': 296, 'latent_dim': 126}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.259110 seconds
# [I 2025-04-16 20:18:13,344] Trial 55 finished with value: 22.924664170577373 and parameters: {'lr_g': 0.0009342086036593962, 'lr_d': 0.0022959070239419207, 'epochs': 92, 'batch_size': 288, 'latent_dim': 112}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.064507 seconds
# [I 2025-04-16 20:18:15,486] Trial 56 finished with value: 24.29777802153302 and parameters: {'lr_g': 0.000192701955389796, 'lr_d': 0.0032706450074451087, 'epochs': 79, 'batch_size': 257, 'latent_dim': 96}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.946288 seconds
# [I 2025-04-16 20:18:17,402] Trial 57 finished with value: 14.344234905255387 and parameters: {'lr_g': 0.0006006867245171066, 'lr_d': 0.003057616166344525, 'epochs': 82, 'batch_size': 279, 'latent_dim': 102}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.719318 seconds
# [I 2025-04-16 20:18:19,788] Trial 58 finished with value: 32.47216813628899 and parameters: {'lr_g': 0.0011179174311446156, 'lr_d': 0.0027286203019131956, 'epochs': 87, 'batch_size': 300, 'latent_dim': 137}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.174738 seconds
# [I 2025-04-16 20:18:21,575] Trial 59 finished with value: 329.26402362155346 and parameters: {'lr_g': 0.0021850576432358663, 'lr_d': 0.003520917970714845, 'epochs': 67, 'batch_size': 260, 'latent_dim': 120}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.576402 seconds
# [I 2025-04-16 20:18:23,536] Trial 60 finished with value: 418.2453907641799 and parameters: {'lr_g': 0.002693786491941736, 'lr_d': 0.002047664604195578, 'epochs': 73, 'batch_size': 235, 'latent_dim': 124}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.755694 seconds
# [I 2025-04-16 20:18:25,699] Trial 61 finished with value: 16.220619440882498 and parameters: {'lr_g': 0.001243158682221185, 'lr_d': 0.0036423316412870312, 'epochs': 79, 'batch_size': 290, 'latent_dim': 114}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.931883 seconds
# [I 2025-04-16 20:18:27,992] Trial 62 finished with value: 11.226697577296862 and parameters: {'lr_g': 0.0005393822929858636, 'lr_d': 0.003937716245721282, 'epochs': 90, 'batch_size': 275, 'latent_dim': 104}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.077631 seconds
# [I 2025-04-16 20:18:30,104] Trial 63 finished with value: 13.668523138755635 and parameters: {'lr_g': 0.00015876635455910665, 'lr_d': 0.0039234948533163425, 'epochs': 90, 'batch_size': 282, 'latent_dim': 106}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.856546 seconds
# [I 2025-04-16 20:18:32,776] Trial 64 finished with value: 24.548976664221264 and parameters: {'lr_g': 0.0005024661534217375, 'lr_d': 0.004342530589225433, 'epochs': 98, 'batch_size': 267, 'latent_dim': 129}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.444347 seconds
# [I 2025-04-16 20:18:34,878] Trial 65 finished with value: 18.078190015039002 and parameters: {'lr_g': 0.0008535814272966233, 'lr_d': 0.0031849598817844686, 'epochs': 85, 'batch_size': 232, 'latent_dim': 106}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.883421 seconds
# [I 2025-04-16 20:18:37,181] Trial 66 finished with value: 17.019444239661166 and parameters: {'lr_g': 0.0006438075299966127, 'lr_d': 0.00296647592857241, 'epochs': 77, 'batch_size': 278, 'latent_dim': 136}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.076867 seconds
# [I 2025-04-16 20:18:39,786] Trial 67 finished with value: 11.055734854724697 and parameters: {'lr_g': 0.00017385482639750054, 'lr_d': 0.004199810555628242, 'epochs': 102, 'batch_size': 244, 'latent_dim': 90}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.426468 seconds
# [I 2025-04-16 20:18:42,317] Trial 68 finished with value: 11.343013192849533 and parameters: {'lr_g': 0.00013628072117165328, 'lr_d': 0.004141943057455987, 'epochs': 102, 'batch_size': 247, 'latent_dim': 90}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.324129 seconds
# [I 2025-04-16 20:18:44,854] Trial 69 finished with value: 33.11740443845094 and parameters: {'lr_g': 7.025855655226989e-05, 'lr_d': 0.004073383503551389, 'epochs': 103, 'batch_size': 238, 'latent_dim': 91}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.311822 seconds
# [I 2025-04-16 20:18:47,526] Trial 70 finished with value: 18.599715796118808 and parameters: {'lr_g': 0.00019791441081392898, 'lr_d': 0.004155448931038306, 'epochs': 106, 'batch_size': 219, 'latent_dim': 82}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.471308 seconds
# [I 2025-04-16 20:18:49,926] Trial 71 finished with value: 20.055980433001775 and parameters: {'lr_g': 0.0003993120358040635, 'lr_d': 0.002654465121950087, 'epochs': 94, 'batch_size': 247, 'latent_dim': 89}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.212641 seconds
# [I 2025-04-16 20:18:52,657] Trial 72 finished with value: 8.290244544758568 and parameters: {'lr_g': 4.060593194352553e-05, 'lr_d': 0.0034114091071042523, 'epochs': 102, 'batch_size': 265, 'latent_dim': 99}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.479894 seconds
# [I 2025-04-16 20:18:55,283] Trial 73 finished with value: 17.958135593847246 and parameters: {'lr_g': 2.7960742143026744e-05, 'lr_d': 0.003428127387920794, 'epochs': 109, 'batch_size': 263, 'latent_dim': 99}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.412288 seconds
# [I 2025-04-16 20:18:58,158] Trial 74 finished with value: 16.421494915787246 and parameters: {'lr_g': 0.000205762787118292, 'lr_d': 0.003967707286886755, 'epochs': 114, 'batch_size': 244, 'latent_dim': 94}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.633394 seconds
# [I 2025-04-16 20:19:00,817] Trial 75 finished with value: 38.20790846680015 and parameters: {'lr_g': 0.0005184467899327189, 'lr_d': 0.0036904787186552296, 'epochs': 103, 'batch_size': 272, 'latent_dim': 81}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.458374 seconds
# [I 2025-04-16 20:19:03,096] Trial 76 finished with value: 34.71173874447061 and parameters: {'lr_g': 0.00039434592429693185, 'lr_d': 0.004234351088341859, 'epochs': 90, 'batch_size': 254, 'latent_dim': 69}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.044017 seconds
# [I 2025-04-16 20:19:05,685] Trial 77 finished with value: 770.3721457622535 and parameters: {'lr_g': 0.004753252538376897, 'lr_d': 0.0044911488057512005, 'epochs': 96, 'batch_size': 226, 'latent_dim': 88}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.397590 seconds
# [I 2025-04-16 20:19:08,762] Trial 78 finished with value: 402.71359898473736 and parameters: {'lr_g': 0.0035308201585534183, 'lr_d': 0.004782153182505302, 'epochs': 121, 'batch_size': 207, 'latent_dim': 79}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.865490 seconds
# [I 2025-04-16 20:19:11,355] Trial 79 finished with value: 15.308819943524314 and parameters: {'lr_g': 0.0001390330634030693, 'lr_d': 0.0032657035244909867, 'epochs': 100, 'batch_size': 243, 'latent_dim': 101}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.404716 seconds
# [I 2025-04-16 20:19:14,204] Trial 80 finished with value: 24.313727413770934 and parameters: {'lr_g': 0.0007184113127403022, 'lr_d': 0.003616652134140276, 'epochs': 103, 'batch_size': 265, 'latent_dim': 106}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.610990 seconds
# fit took 2.062371 seconds
# [I 2025-04-16 20:19:16,535] Trial 81 finished with value: 17.400413738576205 and parameters: {'lr_g': 0.000313322970181967, 'lr_d': 0.0024681408335226864, 'epochs': 83, 'batch_size': 282, 'latent_dim': 111}. Best is trial 1 with value: 7.742709319611028.
# [I 2025-04-16 20:19:18,946] Trial 82 finished with value: 36.46711604984229 and parameters: {'lr_g': 0.0005615416663341086, 'lr_d': 0.0028545794037239556, 'epochs': 86, 'batch_size': 286, 'latent_dim': 94}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.140621 seconds
# [I 2025-04-16 20:19:21,731] Trial 83 finished with value: 22.999538495411507 and parameters: {'lr_g': 0.00028228347969606334, 'lr_d': 0.00301291574114314, 'epochs': 90, 'batch_size': 296, 'latent_dim': 117}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.543931 seconds
# [I 2025-04-16 20:19:23,941] Trial 84 finished with value: 16.328982834259605 and parameters: {'lr_g': 1.6495859810995294e-05, 'lr_d': 0.0038337670302234983, 'epochs': 79, 'batch_size': 274, 'latent_dim': 98}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.981939 seconds
# [I 2025-04-16 20:19:26,975] Trial 85 finished with value: 18.30682695345893 and parameters: {'lr_g': 0.0004521098888536017, 'lr_d': 0.003386661067488866, 'epochs': 95, 'batch_size': 257, 'latent_dim': 104}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.842482 seconds
# [I 2025-04-16 20:19:29,739] Trial 86 finished with value: 27.613755334581562 and parameters: {'lr_g': 0.0007854331535333628, 'lr_d': 0.0027830051589104003, 'epochs': 110, 'batch_size': 269, 'latent_dim': 86}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.528722 seconds
# [I 2025-04-16 20:19:31,943] Trial 87 finished with value: 22.857169285209494 and parameters: {'lr_g': 0.00017430349893182755, 'lr_d': 0.0032161856967593164, 'epochs': 81, 'batch_size': 291, 'latent_dim': 122}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.983600 seconds
# fit took 2.204002 seconds
# [I 2025-04-16 20:19:34,442] Trial 88 finished with value: 19.347559300003145 and parameters: {'lr_g': 0.0003750001640756691, 'lr_d': 0.00406529462943538, 'epochs': 92, 'batch_size': 121, 'latent_dim': 108}. Best is trial 1 with value: 7.742709319611028.
# [I 2025-04-16 20:19:36,439] Trial 89 finished with value: 20.436402355691765 and parameters: {'lr_g': 0.0005970190165225046, 'lr_d': 0.0035011893861502676, 'epochs': 71, 'batch_size': 228, 'latent_dim': 70}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.795770 seconds
# [I 2025-04-16 20:19:38,510] Trial 90 finished with value: 19.498446213159966 and parameters: {'lr_g': 0.0010357473271141125, 'lr_d': 0.00375329051268329, 'epochs': 84, 'batch_size': 145, 'latent_dim': 15}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.855065 seconds
# [I 2025-04-16 20:19:40,626] Trial 91 finished with value: 27.92690445136552 and parameters: {'lr_g': 0.001017828304285874, 'lr_d': 0.004464097631795045, 'epochs': 76, 'batch_size': 132, 'latent_dim': 112}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.883517 seconds
# [I 2025-04-16 20:19:42,361] Trial 92 finished with value: 21.687281352463767 and parameters: {'lr_g': 0.0008790557237213176, 'lr_d': 0.004403492887963776, 'epochs': 67, 'batch_size': 86, 'latent_dim': 117}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.532251 seconds
# [I 2025-04-16 20:19:44,309] Trial 93 finished with value: 16.698881056987496 and parameters: {'lr_g': 0.00011837592104370359, 'lr_d': 0.004249109963773689, 'epochs': 74, 'batch_size': 109, 'latent_dim': 92}. Best is trial 1 with value: 7.742709319611028.
# fit took 1.707404 seconds
# [I 2025-04-16 20:19:46,984] Trial 94 finished with value: 352.48811796916107 and parameters: {'lr_g': 0.001573745085077354, 'lr_d': 0.004695032010848232, 'epochs': 88, 'batch_size': 161, 'latent_dim': 98}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.450113 seconds
# [I 2025-04-16 20:19:50,744] Trial 95 finished with value: 14.835615349260664 and parameters: {'lr_g': 0.0007013642981927367, 'lr_d': 0.004644502518177677, 'epochs': 150, 'batch_size': 78, 'latent_dim': 114}. Best is trial 1 with value: 7.742709319611028.
# fit took 3.487352 seconds
# [I 2025-04-16 20:19:53,257] Trial 96 finished with value: 13.093442606089999 and parameters: {'lr_g': 0.0002566502763012369, 'lr_d': 0.002563396668466218, 'epochs': 72, 'batch_size': 277, 'latent_dim': 102}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.240416 seconds
# fit took 3.147518 seconds
# [I 2025-04-16 20:19:56,688] Trial 97 finished with value: 26.257146665303452 and parameters: {'lr_g': 0.00028301264164246124, 'lr_d': 0.0025522832901615717, 'epochs': 101, 'batch_size': 276, 'latent_dim': 103}. Best is trial 1 with value: 7.742709319611028.
# [I 2025-04-16 20:19:59,396] Trial 98 finished with value: 17.728822780388608 and parameters: {'lr_g': 0.0018081151131080992, 'lr_d': 0.002279821493211899, 'epochs': 79, 'batch_size': 300, 'latent_dim': 109}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.453978 seconds
# [I 2025-04-16 20:20:01,821] Trial 99 finished with value: 10.695250097309774 and parameters: {'lr_g': 0.0004897088652558717, 'lr_d': 0.0031355348023432176, 'epochs': 81, 'batch_size': 262, 'latent_dim': 96}. Best is trial 1 with value: 7.742709319611028.
# fit took 2.201500 seconds

# %%
print(model.parameters)
# Out:
# {'lr_g': 0.00022375184174189098, 'lr_d': 0.003284305168184232, 'epochs': 77, 'batch_size': 122, 'latent_dim': 106}

# %%
model.fit(verbose = True)
# Out:
# Epoch [1/77], C Loss: 12.7216, G Loss: 6.8642,
# Epoch [2/77], C Loss: 1.2525, G Loss: 0.3641,
# Epoch [3/77], C Loss: 1.4460, G Loss: 0.5348,
# Epoch [4/77], C Loss: 2.0383, G Loss: 1.1139,
# Epoch [5/77], C Loss: 1.5004, G Loss: 0.4554,
# Epoch [6/77], C Loss: 1.6179, G Loss: 0.8843,
# Epoch [7/77], C Loss: 1.4080, G Loss: 0.5634,
# Epoch [8/77], C Loss: 1.3639, G Loss: 0.7829,
# Epoch [9/77], C Loss: 1.5068, G Loss: 0.6873,
# Epoch [10/77], C Loss: 1.3381, G Loss: 0.4571,
# Epoch [11/77], C Loss: 1.5585, G Loss: 0.5901,
# Epoch [12/77], C Loss: 1.3532, G Loss: 0.5654,
# Epoch [13/77], C Loss: 1.4274, G Loss: 0.7010,
# Epoch [14/77], C Loss: 1.2730, G Loss: 0.5278,
# Epoch [15/77], C Loss: 1.3561, G Loss: 0.9168,
# Epoch [16/77], C Loss: 1.4459, G Loss: 0.4851,
# Epoch [17/77], C Loss: 1.3965, G Loss: 0.6610,
# Epoch [18/77], C Loss: 1.3545, G Loss: 0.5763,
# Epoch [19/77], C Loss: 1.4088, G Loss: 0.6716,
# Epoch [20/77], C Loss: 1.3141, G Loss: 0.5561,
# Epoch [21/77], C Loss: 1.4192, G Loss: 0.6115,
# Epoch [22/77], C Loss: 1.4064, G Loss: 1.0716,
# Epoch [23/77], C Loss: 1.3787, G Loss: 0.7584,
# Epoch [24/77], C Loss: 1.6364, G Loss: 0.7974,
# Epoch [25/77], C Loss: 1.4428, G Loss: 0.5046,
# Epoch [26/77], C Loss: 1.5394, G Loss: 0.6919,
# Epoch [27/77], C Loss: 1.5387, G Loss: 0.6480,
# Epoch [28/77], C Loss: 1.2618, G Loss: 0.6679,
# Epoch [29/77], C Loss: 1.3311, G Loss: 0.6441,
# Epoch [30/77], C Loss: 1.5853, G Loss: 0.9890,
# Epoch [31/77], C Loss: 1.4871, G Loss: 0.8215,
# Epoch [32/77], C Loss: 1.3063, G Loss: 0.6808,
# Epoch [33/77], C Loss: 1.9308, G Loss: 0.5827,
# Epoch [34/77], C Loss: 1.3393, G Loss: 0.8559,
# Epoch [35/77], C Loss: 1.3762, G Loss: 0.7281,
# Epoch [36/77], C Loss: 1.3928, G Loss: 0.8803,
# Epoch [37/77], C Loss: 1.3611, G Loss: 0.7490,
# Epoch [38/77], C Loss: 1.3880, G Loss: 0.7753,
# Epoch [39/77], C Loss: 1.4031, G Loss: 0.6912,
# Epoch [40/77], C Loss: 1.3853, G Loss: 0.7431,
# Epoch [41/77], C Loss: 1.3799, G Loss: 0.7767,
# Epoch [42/77], C Loss: 1.3853, G Loss: 0.7228,
# Epoch [43/77], C Loss: 1.6592, G Loss: 0.8051,
# Epoch [44/77], C Loss: 1.4052, G Loss: 0.8789,
# Epoch [45/77], C Loss: 1.4175, G Loss: 0.7507,
# Epoch [46/77], C Loss: 1.5229, G Loss: 0.7346,
# Epoch [47/77], C Loss: 1.3966, G Loss: 0.7970,
# Epoch [48/77], C Loss: 1.6099, G Loss: 0.6752,
# Epoch [49/77], C Loss: 1.4923, G Loss: 0.7238,
# Epoch [50/77], C Loss: 1.3776, G Loss: 0.8433,
# Epoch [51/77], C Loss: 1.4659, G Loss: 0.6674,
# Epoch [52/77], C Loss: 1.3201, G Loss: 0.7477,
# Epoch [53/77], C Loss: 1.4047, G Loss: 0.7074,
# Epoch [54/77], C Loss: 1.3887, G Loss: 0.7253,
# Epoch [55/77], C Loss: 1.4097, G Loss: 0.6704,
# Epoch [56/77], C Loss: 1.3910, G Loss: 0.7299,
# Epoch [57/77], C Loss: 1.3812, G Loss: 0.6741,
# Epoch [58/77], C Loss: 1.3601, G Loss: 0.8129,
# Epoch [59/77], C Loss: 1.4696, G Loss: 0.8253,
# Epoch [60/77], C Loss: 1.4192, G Loss: 0.6585,
# Epoch [61/77], C Loss: 1.3803, G Loss: 0.7912,
# Epoch [62/77], C Loss: 1.5326, G Loss: 0.7167,
# Epoch [63/77], C Loss: 1.3912, G Loss: 1.0931,
# Epoch [64/77], C Loss: 1.3781, G Loss: 0.6520,
# Epoch [65/77], C Loss: 1.3685, G Loss: 0.6122,
# Epoch [66/77], C Loss: 1.3405, G Loss: 0.9312,
# Epoch [67/77], C Loss: 1.4115, G Loss: 0.6389,
# Epoch [68/77], C Loss: 1.4345, G Loss: 0.8107,
# Epoch [69/77], C Loss: 1.3881, G Loss: 0.8617,
# Epoch [70/77], C Loss: 1.3946, G Loss: 0.6786,
# Epoch [71/77], C Loss: 1.3792, G Loss: 0.7358,
# Epoch [72/77], C Loss: 1.3542, G Loss: 0.7008,
# Epoch [73/77], C Loss: 1.4035, G Loss: 0.7122,
# Epoch [74/77], C Loss: 1.3485, G Loss: 0.8009,
# Epoch [75/77], C Loss: 1.4802, G Loss: 0.7608,
# Epoch [76/77], C Loss: 1.3915, G Loss: 0.7406,
# Epoch [77/77], C Loss: 1.3805, G Loss: 0.6755,
# fit took 3.384706 seconds
# {}

# %%
n = 30

w = [model.compute_val_metric(dWasserstein, {}) for _ in range(n)]
f = [model.compute_val_metric(dFrechet, {}) for _ in range(n)]
o = [model.compute_val_metric(ONND, {}) for _ in range(n)]
s = [model.compute_val_metric(score, {}) for _ in range(n)]

print("Wasserstein", sum(w)/n)
print("Fréchet", sum(f)/n)
print("ONND", sum(o)/n)
print("Score", sum(s)/n)
# Out:
# Wasserstein 0.5479016549889493
# Fréchet 1.8850527504916619
# ONND 0.16481563664338852
# Score 23.47602721916341

# %%
import matplotlib.pyplot as plt
plt.plot([5*x for x in w], label = "Wassertein")
plt.plot([x for x in f], label = "Fréchet")
plt.plot([10*x for x in o], label = "ONND")
plt.plot([0.1*x for x in s], label = "Score")
plt.legend()
