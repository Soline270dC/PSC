# %%
import numpy as np
from statsmodels.tsa.stattools import adfuller, kpss
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
df1 = pd.read_csv("data/1-station_49.csv")[["YEAR", "YIELD"]]
df2 = pd.read_csv("data/2-station_80.csv")[["YEAR", "YIELD"]]
df3 = pd.read_csv("data/3-station_40.csv")[["YEAR", "YIELD"]]
df4 = pd.read_csv("data/4-station_63.csv")[["YEAR", "YIELD"]]

# %%
plt.plot(df1["YEAR"][:100], df1["YIELD"][:100])
plt.plot(df2["YEAR"][:100], df2["YIELD"][:100])
plt.plot(df3["YEAR"][:100], df3["YIELD"][:100])
plt.plot(df4["YEAR"][:100], df4["YIELD"][:100])

# %%
count1 = dict(Counter(df1["YIELD"]))
count2 = dict(Counter(df2["YIELD"]))
count3 = dict(Counter(df3["YIELD"]))
count4 = dict(Counter(df4["YIELD"]))
count3.__delitem__(15.75)
count4.__delitem__(0.0)

# %%
plt.bar(x = count1.keys(), height = count1.values(), alpha = 0.5, width = 0.01)
plt.bar(x = count2.keys(), height = count2.values(), alpha = 0.5, width = 0.01)
plt.bar(x = count3.keys(), height = count3.values(), alpha = 0.5, width = 0.01)
plt.bar(x = count4.keys(), height = count4.values(), alpha = 0.5, width = 0.01)
# Out:
# <BarContainer object of 948 artists>

# %%
series1 = df1["YIELD"]
series2 = df2["YIELD"]
series3 = df3["YIELD"]
series4 = df4["YIELD"]

# %%
def adf_test(series) :
    result = adfuller(series, autolag='AIC')
    print(f'ADF Statistic: {result[0]}')
    print(f'n_lags: {result[1]}')
    print(f'p-value: {result[1]}')
    # for key, value in result[4].items():
    #     print('Critial Values:')
    #     print(f'   {key}, {value}')

# %%
def kpss_test(series, **kw):    
    statistic, p_value, n_lags, critical_values = kpss(series, **kw)
    # Format Output
    print(f'KPSS Statistic: {statistic}')
    print(f'p-value: {p_value}')
    print(f'num lags: {n_lags}')
    # print('Critial Values:')
    # for key, value in critical_values.items():
    #     print(f'   {key} : {value}')
    # print(f'Result: The series is {"not " if p_value < 0.05 else ""}stationary')

# %%
print("series1")
adf_test(series1)
print("\nseries2")
adf_test(series2)
print("\nseries3")
adf_test(series3)
print("\nseries4")
adf_test(series4)
# Out:
# series1
# ADF Statistic: -99.70324677176076
# n_lags: 0.0
# p-value: 0.0
#
# series2
# ADF Statistic: -29.921628746402202
# n_lags: 0.0
# p-value: 0.0
#
# series3
# ADF Statistic: -99.47311474467926
# n_lags: 0.0
# p-value: 0.0
#
# series4
# ADF Statistic: -56.181253842774524
# n_lags: 0.0
# p-value: 0.0

# %%
print("series1")
kpss_test(series1)
print("\nseries2")
kpss_test(series2)
print("\nseries3")
kpss_test(series3)
print("\nseries4")
kpss_test(series4)
# Out:
# series1
# KPSS Statistic: 0.2276109660116662
# p-value: 0.1
# num lags: 4
#
# series2
# KPSS Statistic: 0.32194415838022905
# p-value: 0.1
# num lags: 5
#
# series3
# KPSS Statistic: 0.4212750652877083
# p-value: 0.06798488565184987
# num lags: 2
#
# series4
# KPSS Statistic: 0.20021656749709943
# p-value: 0.1
# num lags: 7
# C:\Users\sducr\AppData\Local\Temp\ipykernel_4044\1773986987.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statistic, p_value, n_lags, critical_values = kpss(series, **kw)
# C:\Users\sducr\AppData\Local\Temp\ipykernel_4044\1773986987.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statistic, p_value, n_lags, critical_values = kpss(series, **kw)
# ...
